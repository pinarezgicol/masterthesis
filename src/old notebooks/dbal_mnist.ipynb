# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
from keras.datasets import mnist
from models import MLP
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
results_path = 'results'

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
    "batch_bald": batch_bald
}

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 28, 28, 1).astype('float32') / 255.
X_test = X_test.reshape(10000, 28, 28, 1).astype('float32') / 255.

# %% [markdown]
# ### Active Learning Procedure

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))
    for func_name, acquisition_func in ACQ_FUNCS.items():  
        X_initial = X_train[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP().to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test,
                                                          y_test,
                                                          X_pool,
                                                          y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, func_name + "_exp_" + str(exp_iter) + ".npy")
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# (2000,)
# Accuracy after query 1: 0.5546
# (2000,)
# Accuracy after query 2: 0.6045
# (2000,)
# Accuracy after query 3: 0.6419
# (2000,)
# Accuracy after query 4: 0.6607
# (2000,)
# Accuracy after query 5: 0.7038
# (2000,)
# Accuracy after query 6: 0.7343
# (2000,)
# Accuracy after query 7: 0.7326
# (2000,)
# Accuracy after query 8: 0.7468
# (2000,)
# Accuracy after query 9: 0.7625
# (2000,)
# Accuracy after query 10: 0.7821
# (2000,)
# Accuracy after query 11: 0.7809
# (2000,)
# Accuracy after query 12: 0.7833
# (2000,)
# Accuracy after query 13: 0.8014
# (2000,)
# Accuracy after query 14: 0.8021
# (2000,)
# Accuracy after query 15: 0.8149
# (2000,)
# Accuracy after query 16: 0.8204
# (2000,)
# Accuracy after query 17: 0.8193
# (2000,)
# Accuracy after query 18: 0.8116
# (2000,)
# Accuracy after query 19: 0.8188
# (2000,)
# Accuracy after query 20: 0.8225
# (2000,)
# Accuracy after query 21: 0.8160
# (2000,)
# Accuracy after query 22: 0.8296
# (2000,)
# Accuracy after query 23: 0.8174
# (2000,)
# Accuracy after query 24: 0.8458
# (2000,)
# Accuracy after query 25: 0.8395
# (2000,)
# Accuracy after query 26: 0.8454
# (2000,)
# Accuracy after query 27: 0.8538
# (2000,)
# Accuracy after query 28: 0.8530
# (2000,)
# Accuracy after query 29: 0.8510
# (2000,)
# Accuracy after query 30: 0.8503
# (2000,)
# Accuracy after query 31: 0.8487
# (2000,)
# Accuracy after query 32: 0.8497
# (2000,)
# Accuracy after query 33: 0.8488
# (2000,)
# Accuracy after query 34: 0.8579
# (2000,)
# Accuracy after query 35: 0.8492
# (2000,)
# Accuracy after query 36: 0.8440
# (2000,)
# Accuracy after query 37: 0.8646
# (2000,)
# Accuracy after query 38: 0.8632
# (2000,)
# Accuracy after query 39: 0.8730
# (2000,)
# Accuracy after query 40: 0.8730
# (2000,)
# Accuracy after query 41: 0.8710
# (2000,)
# Accuracy after query 42: 0.8756
# (2000,)
# Accuracy after query 43: 0.8727
# (2000,)
# Accuracy after query 44: 0.8790
# (2000,)
# Accuracy after query 45: 0.8836
# (2000,)
# Accuracy after query 46: 0.8702
# (2000,)
# Accuracy after query 47: 0.8694
# (2000,)
# Accuracy after query 48: 0.8738
# (2000,)
# Accuracy after query 49: 0.8853
# (2000,)
# Accuracy after query 50: 0.8850
# (2000,)
# Accuracy after query 51: 0.8836
# (2000,)
# Accuracy after query 52: 0.8909
# (2000,)
# Accuracy after query 53: 0.8936
# (2000,)
# Accuracy after query 54: 0.8894
# (2000,)
# Accuracy after query 55: 0.8899
# (2000,)
# Accuracy after query 56: 0.8926
# (2000,)
# Accuracy after query 57: 0.8929
# (2000,)
# Accuracy after query 58: 0.8922
# (2000,)
# Accuracy after query 59: 0.8992
# (2000,)
# Accuracy after query 60: 0.8976
# (2000,)
# Accuracy after query 61: 0.8951
# (2000,)
# Accuracy after query 62: 0.9015
# (2000,)
# Accuracy after query 63: 0.9019
# (2000,)
# Accuracy after query 64: 0.8998
# (2000,)
# Accuracy after query 65: 0.8944
# (2000,)
# Accuracy after query 66: 0.8928
# (2000,)
# Accuracy after query 67: 0.9003
# (2000,)
# Accuracy after query 68: 0.8990
# (2000,)
# Accuracy after query 69: 0.9022
# (2000,)
# Accuracy after query 70: 0.9014
# (2000,)
# Accuracy after query 71: 0.9034
# (2000,)
# Accuracy after query 72: 0.9010
# (2000,)
# Accuracy after query 73: 0.9054
# (2000,)
# Accuracy after query 74: 0.9043
# (2000,)
# Accuracy after query 75: 0.9043
# (2000,)
# Accuracy after query 76: 0.9054
# (2000,)
# Accuracy after query 77: 0.9082
# (2000,)
# Accuracy after query 78: 0.9074
# (2000,)
# Accuracy after query 79: 0.9014
# (2000,)
# Accuracy after query 80: 0.9045
# (2000,)
# Accuracy after query 81: 0.9067
# (2000,)
# Accuracy after query 82: 0.9105
# (2000,)
# Accuracy after query 83: 0.9061
# (2000,)
# Accuracy after query 84: 0.9077
# (2000,)
# Accuracy after query 85: 0.9116
# (2000,)
# Accuracy after query 86: 0.9123
# (2000,)
# Accuracy after query 87: 0.9113
# (2000,)
# Accuracy after query 88: 0.9140
# (2000,)
# Accuracy after query 89: 0.9110
# (2000,)
# Accuracy after query 90: 0.9166
# (2000,)
# Accuracy after query 91: 0.9162
# (2000,)
# Accuracy after query 92: 0.9193
# (2000,)
# Accuracy after query 93: 0.9172
# (2000,)
# Accuracy after query 94: 0.9083
# (2000,)
# Accuracy after query 95: 0.9171
# (2000,)
# Accuracy after query 96: 0.9120
# (2000,)
# Accuracy after query 97: 0.9170
# (2000,)
# Accuracy after query 98: 0.9214
# (2000,)
# Accuracy after query 1: 0.5863
# (2000,)
# Accuracy after query 2: 0.6200
# (2000,)
# Accuracy after query 3: 0.6861
# (2000,)
# Accuracy after query 4: 0.6568
# (2000,)
# Accuracy after query 5: 0.7023
# (2000,)
# Accuracy after query 6: 0.7243
# (2000,)
# Accuracy after query 7: 0.7327
# (2000,)
# Accuracy after query 8: 0.7444
# (2000,)
# Accuracy after query 9: 0.7507
# (2000,)
# Accuracy after query 10: 0.7447
# (2000,)
# Accuracy after query 11: 0.7903
# (2000,)
# Accuracy after query 12: 0.7765
# (2000,)
# Accuracy after query 13: 0.7663
# (2000,)
# Accuracy after query 14: 0.7866
# (2000,)
# Accuracy after query 15: 0.7832
# (2000,)
# Accuracy after query 16: 0.7686
# (2000,)
# Accuracy after query 17: 0.8104
# (2000,)
# Accuracy after query 18: 0.8195
# (2000,)
# Accuracy after query 19: 0.8085
# (2000,)
# Accuracy after query 20: 0.8215
# (2000,)
# Accuracy after query 21: 0.8302
# (2000,)
# Accuracy after query 22: 0.8319
# (2000,)
# Accuracy after query 23: 0.8253
# (2000,)
# Accuracy after query 24: 0.8100
# (2000,)
# Accuracy after query 25: 0.8396
# (2000,)
# Accuracy after query 26: 0.8293
# (2000,)
# Accuracy after query 27: 0.8357
# (2000,)
# Accuracy after query 28: 0.8419
# (2000,)
# Accuracy after query 29: 0.8394
# (2000,)
# Accuracy after query 30: 0.8415
# (2000,)
# Accuracy after query 31: 0.8731
# (2000,)
# Accuracy after query 32: 0.8672
# (2000,)
# Accuracy after query 33: 0.8566
# (2000,)
# Accuracy after query 34: 0.8614
# (2000,)
# Accuracy after query 35: 0.8726
# (2000,)
# Accuracy after query 36: 0.8754
# (2000,)
# Accuracy after query 37: 0.8759
# (2000,)
# Accuracy after query 38: 0.8767
# (2000,)
# Accuracy after query 39: 0.8680
# (2000,)
# Accuracy after query 40: 0.8592
# (2000,)
# Accuracy after query 41: 0.8723
# (2000,)
# Accuracy after query 42: 0.8689
# (2000,)
# Accuracy after query 43: 0.8807
# (2000,)
# Accuracy after query 44: 0.8784
# (2000,)
# Accuracy after query 45: 0.8807
# (2000,)
# Accuracy after query 46: 0.8845
# (2000,)
# Accuracy after query 47: 0.8772
# (2000,)
# Accuracy after query 48: 0.8836
# (2000,)
# Accuracy after query 49: 0.8837
# (2000,)
# Accuracy after query 50: 0.8862
# (2000,)
# Accuracy after query 51: 0.8836
# (2000,)
# Accuracy after query 52: 0.8844
# (2000,)
# Accuracy after query 53: 0.8848
# (2000,)
# Accuracy after query 54: 0.8809
# (2000,)
# Accuracy after query 55: 0.8882
# (2000,)
# Accuracy after query 56: 0.8775
# (2000,)
# Accuracy after query 57: 0.8770
# (2000,)
# Accuracy after query 58: 0.8810
# (2000,)
# Accuracy after query 59: 0.8970
# (2000,)
# Accuracy after query 60: 0.8930
# (2000,)
# Accuracy after query 61: 0.9004
# (2000,)
# Accuracy after query 62: 0.8989
# (2000,)
# Accuracy after query 63: 0.8902
# (2000,)
# Accuracy after query 64: 0.8997
# (2000,)
# Accuracy after query 65: 0.8975
# (2000,)
# Accuracy after query 66: 0.9035
# (2000,)
# Accuracy after query 67: 0.9026
# (2000,)
# Accuracy after query 68: 0.8933
# (2000,)
# Accuracy after query 69: 0.9000
# (2000,)
# Accuracy after query 70: 0.8966
# (2000,)
# Accuracy after query 71: 0.9049
# (2000,)
# Accuracy after query 72: 0.9052
# (2000,)
# Accuracy after query 73: 0.8990
# (2000,)
# Accuracy after query 74: 0.9073
# (2000,)
# Accuracy after query 75: 0.8981
# (2000,)
# Accuracy after query 76: 0.9001
# (2000,)
# Accuracy after query 77: 0.8987
# (2000,)
# Accuracy after query 78: 0.9116
# (2000,)
# Accuracy after query 79: 0.9104
# (2000,)
# Accuracy after query 80: 0.9002
# (2000,)
# Accuracy after query 81: 0.9011
# (2000,)
# Accuracy after query 82: 0.9117
# (2000,)
# Accuracy after query 83: 0.9049
# (2000,)
# Accuracy after query 84: 0.9015
# (2000,)
# Accuracy after query 85: 0.9153
# (2000,)
# Accuracy after query 86: 0.9085
# (2000,)
# Accuracy after query 87: 0.9111
# (2000,)
# Accuracy after query 88: 0.9129
# (2000,)
# Accuracy after query 89: 0.9126
# (2000,)
# Accuracy after query 90: 0.9118
# (2000,)
# Accuracy after query 91: 0.9095
# (2000,)
# Accuracy after query 92: 0.9131
# (2000,)
# Accuracy after query 93: 0.9116
# (2000,)
# Accuracy after query 94: 0.9133
# (2000,)
# Accuracy after query 95: 0.9220
# (2000,)
# Accuracy after query 96: 0.9175
# (2000,)
# Accuracy after query 97: 0.9180
# (2000,)
# Accuracy after query 98: 0.9213
# (2000,)
# Accuracy after query 1: 0.5549
# (2000,)
# Accuracy after query 2: 0.5426
# (2000,)
# Accuracy after query 3: 0.5673
# (2000,)
# Accuracy after query 4: 0.6282
# (2000,)
# Accuracy after query 5: 0.6461
# (2000,)
# Accuracy after query 6: 0.6587
# (2000,)
# Accuracy after query 7: 0.6770
# (2000,)
# Accuracy after query 8: 0.6880
# (2000,)
# Accuracy after query 9: 0.7066
# (2000,)
# Accuracy after query 10: 0.7213
# (2000,)
# Accuracy after query 11: 0.7443
# (2000,)
# Accuracy after query 12: 0.7525
# (2000,)
# Accuracy after query 13: 0.7646
# (2000,)
# Accuracy after query 14: 0.7792
# (2000,)
# Accuracy after query 15: 0.7491
# (2000,)
# Accuracy after query 16: 0.7788
# (2000,)
# Accuracy after query 17: 0.7530
# (2000,)
# Accuracy after query 18: 0.7833
# (2000,)
# Accuracy after query 19: 0.7702
# (2000,)
# Accuracy after query 20: 0.7944
# (2000,)
# Accuracy after query 21: 0.8168
# (2000,)
# Accuracy after query 22: 0.8122
# (2000,)
# Accuracy after query 23: 0.8171
# (2000,)
# Accuracy after query 24: 0.8308
# (2000,)
# Accuracy after query 25: 0.8298
# (2000,)
# Accuracy after query 26: 0.8077
# (2000,)
# Accuracy after query 27: 0.8251
# (2000,)
# Accuracy after query 28: 0.8164
# (2000,)
# Accuracy after query 29: 0.8395
# (2000,)
# Accuracy after query 30: 0.8410
# (2000,)
# Accuracy after query 31: 0.8332
# (2000,)
# Accuracy after query 32: 0.8510
# (2000,)
# Accuracy after query 33: 0.8431
# (2000,)
# Accuracy after query 34: 0.8466
# (2000,)
# Accuracy after query 35: 0.8511
# (2000,)
# Accuracy after query 36: 0.8461
# (2000,)
# Accuracy after query 37: 0.8426
# (2000,)
# Accuracy after query 38: 0.8614
# (2000,)
# Accuracy after query 39: 0.8583
# (2000,)
# Accuracy after query 40: 0.8617
# (2000,)
# Accuracy after query 41: 0.8590
# (2000,)
# Accuracy after query 42: 0.8517
# (2000,)
# Accuracy after query 43: 0.8626
# (2000,)
# Accuracy after query 44: 0.8565
# (2000,)
# Accuracy after query 45: 0.8670
# (2000,)
# Accuracy after query 46: 0.8670
# (2000,)
# Accuracy after query 47: 0.8653
# (2000,)
# Accuracy after query 48: 0.8701
# (2000,)
# Accuracy after query 49: 0.8660
# (2000,)
# Accuracy after query 50: 0.8771
# (2000,)
# Accuracy after query 51: 0.8849
# (2000,)
# Accuracy after query 52: 0.8826
# (2000,)
# Accuracy after query 53: 0.8705
# (2000,)
# Accuracy after query 54: 0.8715
# (2000,)
# Accuracy after query 55: 0.8781
# (2000,)
# Accuracy after query 56: 0.8842
# (2000,)
# Accuracy after query 57: 0.8864
# (2000,)
# Accuracy after query 58: 0.8888
# (2000,)
# Accuracy after query 59: 0.8974
# (2000,)
# Accuracy after query 60: 0.8882
# (2000,)
# Accuracy after query 61: 0.8937
# (2000,)
# Accuracy after query 62: 0.8953
# (2000,)
# Accuracy after query 63: 0.8913
# (2000,)
# Accuracy after query 64: 0.8957
# (2000,)
# Accuracy after query 65: 0.8982
# (2000,)
# Accuracy after query 66: 0.9023
# (2000,)
# Accuracy after query 67: 0.9095
# (2000,)
# Accuracy after query 68: 0.8967
# (2000,)
# Accuracy after query 69: 0.8987
# (2000,)
# Accuracy after query 70: 0.8988
# (2000,)
# Accuracy after query 71: 0.8967
# (2000,)
# Accuracy after query 72: 0.9001
# (2000,)
# Accuracy after query 73: 0.8996
# (2000,)
# Accuracy after query 74: 0.9104
# (2000,)
# Accuracy after query 75: 0.9040
# (2000,)
# Accuracy after query 76: 0.9057
# (2000,)
# Accuracy after query 77: 0.9112
# (2000,)
# Accuracy after query 78: 0.9106
# (2000,)
# Accuracy after query 79: 0.9159
# (2000,)
# Accuracy after query 80: 0.9135
# (2000,)
# Accuracy after query 81: 0.9115
# (2000,)
# Accuracy after query 82: 0.9128
# (2000,)
# Accuracy after query 83: 0.9122
# (2000,)
# Accuracy after query 84: 0.9161
# (2000,)
# Accuracy after query 85: 0.9147
# (2000,)
# Accuracy after query 86: 0.9180
# (2000,)
# Accuracy after query 87: 0.9155
# (2000,)
# Accuracy after query 88: 0.9223
# (2000,)
# Accuracy after query 89: 0.9186
# (2000,)
# Accuracy after query 90: 0.9179
# (2000,)
# Accuracy after query 91: 0.9255
# (2000,)
# Accuracy after query 92: 0.9249
# (2000,)
# Accuracy after query 93: 0.9238
# (2000,)
# Accuracy after query 94: 0.9218
# (2000,)
# Accuracy after query 95: 0.9228
# (2000,)
# Accuracy after query 96: 0.9222
# (2000,)
# Accuracy after query 97: 0.9232
# (2000,)
# Accuracy after query 98: 0.9250
