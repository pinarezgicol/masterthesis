# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import mnist
from consistent_mc_dropout import ConsistentMCDropout
from consistent_mc_dropout import BayesianModule

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
LATENT_DIMS = [64]
LATENT_DIM = 64
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\mnist_aae_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "batch_bald": batch_bald
}

# %%
latent_dim = 64
class BayesianMLP(BayesianModule):
    def __init__(self, num_classes=10):
        super().__init__()
        self.flatten_layer = nn.Flatten()
        self.layer1 = nn.Linear(latent_dim, 512)
        self.layer1_drop = ConsistentMCDropout(p=0.25)
        self.layer2 = nn.Linear(512, 256)
        self.layer2_drop = ConsistentMCDropout(p=0.25)
        self.layer3 = nn.Linear(256, 128)
        self.layer3_drop = ConsistentMCDropout(p=0.5)
        self.fc1 = nn.Linear(128, num_classes)

    def mc_forward_impl(self, input: torch.Tensor):
        input = self.flatten_layer(input)
        input = F.relu(self.layer1_drop(self.layer1(input)))
        input = F.relu(self.layer2_drop(self.layer2(input)))
        input = F.relu(self.layer3_drop(self.layer3(input)))
        input = self.fc1(input)

        return input

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = (X_train.astype(np.float32) - 127.5) / 127.5
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = (X_test.astype(np.float32) - 127.5) / 127.5
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_train_enhanced_aae.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_test_enhanced_aae.npy")

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        print("Length of queries sampled: ", len(query_idx))
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for latent_dim in LATENT_DIMS:
    for exp_iter in range(EXPERIMENT_COUNT):
        np.random.seed(exp_iter)
        initial_idx = np.array([],dtype=int)
        for i in range(10):
            idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
            initial_idx = np.concatenate((initial_idx, idx))

        for func_name, acquisition_func in ACQ_FUNCS.items():  

            X_initial = X_train_enhanced[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = BayesianMLP().to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test_enhanced,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
        for func_name, acquisition_func in ACQ_FUNCS.items():  
            X_initial = X_train[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = MLP_REG(ORIGINAL_DIM).to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join("results\\mnist_dbal", "{func_name}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
# Out:
# mc_output_BK:  torch.Size([2000, 10])
# mc_output_B_K:  torch.Size([20, 100, 10])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12876/1138651161.py in <module>
#      29
#      30
# ---> 31             acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
#      32                                                               X_test_enhanced,
#      33                                                               y_test,
#
# ~\AppData\Local\Temp/ipykernel_12876/3427700730.py in active_learning_procedure(query_strategy, X_test, y_test, X_pool, y_pool, X_initial, y_initial, estimator, n_queries, n_instances)
#       9                               n_queries=98,
#      10                               n_instances=10):
# ---> 11     learner = ActiveLearner(estimator=estimator,
#      12                             X_training=X_initial,
#      13                             y_training=y_initial,
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\learners.py in __init__(self, estimator, query_strategy, X_training, y_training, bootstrap_init, on_transformed, **fit_kwargs)
#      79                  **fit_kwargs
#      80                  ) -> None:
# ---> 81         super().__init__(estimator, query_strategy,
#      82                          X_training, y_training, bootstrap_init, on_transformed, **fit_kwargs)
#      83
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py in __init__(self, estimator, query_strategy, X_training, y_training, bootstrap_init, on_transformed, force_all_finite, **fit_kwargs)
#      69         self.y_training = y_training
#      70         if X_training is not None:
# ---> 71             self._fit_to_known(bootstrap=bootstrap_init, **fit_kwargs)
#      72
#      73         assert isinstance(force_all_finite, bool), 'force_all_finite must be a bool'
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py in _fit_to_known(self, bootstrap, **fit_kwargs)
#     153         """
#     154         if not bootstrap:
# --> 155             self.estimator.fit(self.X_training, self.y_training, **fit_kwargs)
#     156         else:
#     157             n_instances = self.X_training.shape[0]
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py in fit(self, X, y, **fit_params)
#     139         # this is actually a pylint bug:
#     140         # https://github.com/PyCQA/pylint/issues/1085
# --> 141         return super(NeuralNetClassifier, self).fit(X, y, **fit_params)
#     142
#     143     def predict_proba(self, X):
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in fit(self, X, y, **fit_params)
#    1213             self.initialize()
#    1214
# -> 1215         self.partial_fit(X, y, **fit_params)
#    1216         return self
#    1217
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in partial_fit(self, X, y, classes, **fit_params)
#    1172         self.notify('on_train_begin', X=X, y=y)
#    1173         try:
# -> 1174             self.fit_loop(X, y, **fit_params)
#    1175         except KeyboardInterrupt:
#    1176             pass
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in fit_loop(self, X, y, epochs, **fit_params)
#    1085             self.notify('on_epoch_begin', **on_epoch_kwargs)
#    1086
# -> 1087             self.run_single_epoch(dataset_train, training=True, prefix="train",
#    1088                                   step_fn=self.train_step, **fit_params)
#    1089
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in run_single_epoch(self, dataset, training, prefix, step_fn, **fit_params)
#    1120         for batch in self.get_iterator(dataset, training=training):
#    1121             self.notify("on_batch_begin", batch=batch, training=training)
# -> 1122             step = step_fn(batch, **fit_params)
#    1123             self.history.record_batch(prefix + "_loss", step["loss"].item())
#    1124             batch_size = (get_len(batch[0]) if isinstance(batch, (tuple, list))
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in train_step(self, batch, **fit_params)
#    1005             return step['loss']
#    1006
# -> 1007         self._step_optimizer(step_fn)
#    1008         return step_accumulator.get_step()
#    1009
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in _step_optimizer(self, step_fn)
#     961                 optimizer.step()
#     962             else:
# --> 963                 optimizer.step(step_fn)
#     964
#     965     def train_step(self, batch, **fit_params):
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      90         if closure is not None:
#      91             with torch.enable_grad():
# ---> 92                 loss = closure()
#      93
#      94         for group in self.param_groups:
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in step_fn()
#     995         def step_fn():
#     996             self._zero_grad_optimizer()
# --> 997             step = self.train_step_single(batch, **fit_params)
#     998             step_accumulator.store_step(step)
#     999
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in train_step_single(self, batch, **fit_params)
#     895         Xi, yi = unpack_data(batch)
#     896         y_pred = self.infer(Xi, **fit_params)
# --> 897         loss = self.get_loss(y_pred, yi, X=Xi, training=True)
#     898         loss.backward()
#     899         return {
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py in get_loss(self, y_pred, y_true, *args, **kwargs)
#     124             eps = torch.finfo(y_pred.dtype).eps
#     125             y_pred = torch.log(y_pred + eps)
# --> 126         return super().get_loss(y_pred, y_true, *args, **kwargs)
#     127
#     128     # pylint: disable=signature-differs
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in get_loss(self, y_pred, y_true, X, training)
#    1501         """
#    1502         y_true = to_tensor(y_true, device=self.device)
# -> 1503         return self.criterion_(y_pred, y_true)
#    1504
#    1505     def get_dataset(self, X, y=None):
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#    1148
#    1149     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1150         return F.cross_entropy(input, target, weight=self.weight,
#    1151                                ignore_index=self.ignore_index, reduction=self.reduction,
#    1152                                label_smoothing=self.label_smoothing)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    2844     if size_average is not None or reduce is not None:
#    2845         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2846     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    2847
#    2848
#
# RuntimeError: Expected target size [20, 10], got [20]
