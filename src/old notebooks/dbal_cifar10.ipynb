# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
# from torchvision.datasets import CIFAR10
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
from keras.datasets import cifar10

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
MAX_EPOCHS = 50
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
results_path = 'results\\cifar10_dbal'

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
#     "batch_bald": batch_bald
}

# %% [markdown]
# ### architecture of the network we will be using
#
# We will use the architecture described in the paper.

# %%
class MLP_REG(nn.Module):
    def __init__(self):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(3072, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.reshape(50000, 32, 32, 3).astype('float32') / 255.
X_test = X_test.reshape(10000, 32, 32, 3).astype('float32') / 255.

X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
y_train = y_train.reshape((y_train.shape[0], ))
y_test = y_test.reshape((y_test.shape[0], ))

# %% [markdown]
# ### Active Learning Procedure

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))
    
    for func_name, acquisition_func in ACQ_FUNCS.items():  
        X_initial = X_train[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP_REG().to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test,
                                                          y_test,
                                                          X_pool,
                                                          y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, func_name + "_exp_" + str(exp_iter) + ".npy")
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# Accuracy after query 1: 0.1782
# Accuracy after query 2: 0.1839
# Accuracy after query 3: 0.1881
# Accuracy after query 4: 0.2103
# Accuracy after query 5: 0.2098
# Accuracy after query 6: 0.2196
# Accuracy after query 7: 0.2126
# Accuracy after query 8: 0.2274
# Accuracy after query 9: 0.2361
# Accuracy after query 10: 0.2341
# Accuracy after query 11: 0.2313
# Accuracy after query 12: 0.2303
# Accuracy after query 13: 0.2285
# Accuracy after query 14: 0.2388
# Accuracy after query 15: 0.2519
# Accuracy after query 16: 0.2471
# Accuracy after query 17: 0.2590
# Accuracy after query 18: 0.2592
# Accuracy after query 19: 0.2639
# Accuracy after query 20: 0.2565
# Accuracy after query 21: 0.2525
# Accuracy after query 22: 0.2608
# Accuracy after query 23: 0.2595
# Accuracy after query 24: 0.2608
# Accuracy after query 25: 0.2620
# Accuracy after query 26: 0.2512
# Accuracy after query 27: 0.2689
# Accuracy after query 28: 0.2740
# Accuracy after query 29: 0.2662
# Accuracy after query 30: 0.2692
# Accuracy after query 31: 0.2673
# Accuracy after query 32: 0.2684
# Accuracy after query 33: 0.2784
# Accuracy after query 34: 0.2726
# Accuracy after query 35: 0.2677
# Accuracy after query 36: 0.2720
# Accuracy after query 37: 0.2603
# Accuracy after query 38: 0.2453
# Accuracy after query 39: 0.2695
# Accuracy after query 40: 0.2716
# Accuracy after query 41: 0.2708
# Accuracy after query 42: 0.2775
# Accuracy after query 43: 0.2662
# Accuracy after query 44: 0.2688
# Accuracy after query 45: 0.2645
# Accuracy after query 46: 0.2640
# Accuracy after query 47: 0.2580
# Accuracy after query 48: 0.2753
# Accuracy after query 49: 0.2647
# Accuracy after query 50: 0.2712
# Accuracy after query 51: 0.2620
# Accuracy after query 52: 0.2550
# Accuracy after query 53: 0.2658
# Accuracy after query 54: 0.2647
# Accuracy after query 55: 0.2706
# Accuracy after query 56: 0.2667
# Accuracy after query 57: 0.2746
# Accuracy after query 58: 0.2655
# Accuracy after query 59: 0.2639
# Accuracy after query 60: 0.2680
# Accuracy after query 61: 0.2619
# Accuracy after query 62: 0.2682
# Accuracy after query 63: 0.2604
# Accuracy after query 64: 0.2625
# Accuracy after query 65: 0.2563
# Accuracy after query 66: 0.2606
# Accuracy after query 67: 0.2697
# Accuracy after query 68: 0.2593
# Accuracy after query 69: 0.2586
# Accuracy after query 70: 0.2702
# Accuracy after query 71: 0.2592
# Accuracy after query 72: 0.2587
# Accuracy after query 73: 0.2632
# Accuracy after query 74: 0.2652
# Accuracy after query 75: 0.2524
# Accuracy after query 76: 0.2657
# Accuracy after query 77: 0.2531
# Accuracy after query 78: 0.2585
# Accuracy after query 79: 0.2597
# Accuracy after query 80: 0.2631
# Accuracy after query 81: 0.2528
# Accuracy after query 82: 0.2566
# Accuracy after query 83: 0.2597
# Accuracy after query 84: 0.2593
# Accuracy after query 85: 0.2578
# Accuracy after query 86: 0.2463
# Accuracy after query 87: 0.2493
# Accuracy after query 88: 0.2474
# Accuracy after query 89: 0.2471
# Accuracy after query 90: 0.2346
# Accuracy after query 91: 0.2427
# Accuracy after query 92: 0.2504
# Accuracy after query 93: 0.2276
# Accuracy after query 94: 0.2445
# Accuracy after query 95: 0.2422
# Accuracy after query 96: 0.2402
# Accuracy after query 97: 0.2356
# Accuracy after query 98: 0.2429
# Accuracy after query 1: 0.1739
# Accuracy after query 2: 0.1833
# Accuracy after query 3: 0.1977
# Accuracy after query 4: 0.2047
# Accuracy after query 5: 0.2239
# Accuracy after query 6: 0.2280
# Accuracy after query 7: 0.2318
# Accuracy after query 8: 0.2299
# Accuracy after query 9: 0.2422
# Accuracy after query 10: 0.2372
# Accuracy after query 11: 0.2367
# Accuracy after query 12: 0.2458
# Accuracy after query 13: 0.2505
# Accuracy after query 14: 0.2621
# Accuracy after query 15: 0.2708
# Accuracy after query 16: 0.2685
# Accuracy after query 17: 0.2814
# Accuracy after query 18: 0.2746
# Accuracy after query 19: 0.2685
# Accuracy after query 20: 0.2786
# Accuracy after query 21: 0.2741
# Accuracy after query 22: 0.2763
# Accuracy after query 23: 0.2688
# Accuracy after query 24: 0.2674
# Accuracy after query 25: 0.2687
# Accuracy after query 26: 0.2610
# Accuracy after query 27: 0.2409
# Accuracy after query 28: 0.2616
# Accuracy after query 29: 0.2616
# Accuracy after query 30: 0.2469
# Accuracy after query 31: 0.2568
# Accuracy after query 32: 0.2541
# Accuracy after query 33: 0.2647
# Accuracy after query 34: 0.2608
# Accuracy after query 35: 0.2690
# Accuracy after query 36: 0.2618
# Accuracy after query 37: 0.2563
# Accuracy after query 38: 0.2678
# Accuracy after query 39: 0.2696
# Accuracy after query 40: 0.2686
# Accuracy after query 41: 0.2641
# Accuracy after query 42: 0.2574
# Accuracy after query 43: 0.2618
# Accuracy after query 44: 0.2701
# Accuracy after query 45: 0.2571
# Accuracy after query 46: 0.2696
# Accuracy after query 47: 0.2584
# Accuracy after query 48: 0.2721
# Accuracy after query 49: 0.2714
# Accuracy after query 50: 0.2596
# Accuracy after query 51: 0.2759
# Accuracy after query 52: 0.2526
# Accuracy after query 53: 0.2718
# Accuracy after query 54: 0.2606
# Accuracy after query 55: 0.2786
# Accuracy after query 56: 0.2802
# Accuracy after query 57: 0.2731
# Accuracy after query 58: 0.2688
# Accuracy after query 59: 0.2767
# Accuracy after query 60: 0.2742
# Accuracy after query 61: 0.2717
# Accuracy after query 62: 0.2838
# Accuracy after query 63: 0.2852
# Accuracy after query 64: 0.2760
# Accuracy after query 65: 0.2811
# Accuracy after query 66: 0.2813
# Accuracy after query 67: 0.2868
# Accuracy after query 68: 0.2756
# Accuracy after query 69: 0.2738
# Accuracy after query 70: 0.2780
# Accuracy after query 71: 0.2740
# Accuracy after query 72: 0.2877
# Accuracy after query 73: 0.2750
# Accuracy after query 74: 0.2811
# Accuracy after query 75: 0.2761
# Accuracy after query 76: 0.2771
# Accuracy after query 77: 0.2754
# Accuracy after query 78: 0.2843
# Accuracy after query 79: 0.2834
# Accuracy after query 80: 0.2820
# Accuracy after query 81: 0.2928
# Accuracy after query 82: 0.2861
# Accuracy after query 83: 0.2813
# Accuracy after query 84: 0.2785
# Accuracy after query 85: 0.2809
# Accuracy after query 86: 0.2852
# Accuracy after query 87: 0.2906
# Accuracy after query 88: 0.2756
# Accuracy after query 89: 0.2755
# Accuracy after query 90: 0.2777
# Accuracy after query 91: 0.2844
# Accuracy after query 92: 0.2869
# Accuracy after query 93: 0.2853
# Accuracy after query 94: 0.2793
# Accuracy after query 95: 0.2701
# Accuracy after query 96: 0.2725
# Accuracy after query 97: 0.2834
# Accuracy after query 98: 0.2861
# Accuracy after query 1: 0.1530
# Accuracy after query 2: 0.1644
# Accuracy after query 3: 0.1814
# Accuracy after query 4: 0.1844
# Accuracy after query 5: 0.1878
# Accuracy after query 6: 0.1987
# Accuracy after query 7: 0.2045
# Accuracy after query 8: 0.2126
# Accuracy after query 9: 0.2219
# Accuracy after query 10: 0.2194
# Accuracy after query 11: 0.2130
# Accuracy after query 12: 0.2235
# Accuracy after query 13: 0.2195
# Accuracy after query 14: 0.2194
# Accuracy after query 15: 0.2313
# Accuracy after query 16: 0.2301
# Accuracy after query 17: 0.2336
# Accuracy after query 18: 0.2450
# Accuracy after query 19: 0.2365
# Accuracy after query 20: 0.2400
# Accuracy after query 21: 0.2372
# Accuracy after query 22: 0.2439
# Accuracy after query 23: 0.2466
# Accuracy after query 24: 0.2429
# Accuracy after query 25: 0.2379
# Accuracy after query 26: 0.2281
# Accuracy after query 27: 0.2394
# Accuracy after query 28: 0.2427
# Accuracy after query 29: 0.2499
# Accuracy after query 30: 0.2452
# Accuracy after query 31: 0.2431
# Accuracy after query 32: 0.2568
# Accuracy after query 33: 0.2529
# Accuracy after query 34: 0.2601
# Accuracy after query 35: 0.2430
# Accuracy after query 36: 0.2554
# Accuracy after query 37: 0.2328
# Accuracy after query 38: 0.2293
# Accuracy after query 39: 0.2404
# Accuracy after query 40: 0.2446
# Accuracy after query 41: 0.2383
# Accuracy after query 42: 0.2415
# Accuracy after query 43: 0.2538
# Accuracy after query 44: 0.2533
# Accuracy after query 45: 0.2480
# Accuracy after query 46: 0.2497
# Accuracy after query 47: 0.2443
# Accuracy after query 48: 0.2437
# Accuracy after query 49: 0.2451
# Accuracy after query 50: 0.2365
# Accuracy after query 51: 0.2421
# Accuracy after query 52: 0.2426
# Accuracy after query 53: 0.2515
# Accuracy after query 54: 0.2490
# Accuracy after query 55: 0.2448
# Accuracy after query 56: 0.2390
# Accuracy after query 57: 0.2398
# Accuracy after query 58: 0.2543
# Accuracy after query 59: 0.2436
# Accuracy after query 60: 0.2572
# Accuracy after query 61: 0.2474
# Accuracy after query 62: 0.2427
# Accuracy after query 63: 0.2313
# Accuracy after query 64: 0.2075
# Accuracy after query 65: 0.2392
# Accuracy after query 66: 0.1883
# Accuracy after query 67: 0.2235
# Accuracy after query 68: 0.2475
# Accuracy after query 69: 0.2440
# Accuracy after query 70: 0.2278
# Accuracy after query 71: 0.2473
# Accuracy after query 72: 0.2525
# Accuracy after query 73: 0.2490
# Accuracy after query 74: 0.2487
# Accuracy after query 75: 0.2206
# Accuracy after query 76: 0.2306
# Accuracy after query 77: 0.2301
# Accuracy after query 78: 0.2267
# Accuracy after query 79: 0.2312
# Accuracy after query 80: 0.2262
# Accuracy after query 81: 0.2183
# Accuracy after query 82: 0.1908
# Accuracy after query 83: 0.2281
# Accuracy after query 84: 0.2042
# Accuracy after query 85: 0.2129
# Accuracy after query 86: 0.2301
# Accuracy after query 87: 0.1975
# Accuracy after query 88: 0.1634
# Accuracy after query 89: 0.1812
# Accuracy after query 90: 0.1841
# Accuracy after query 91: 0.1925
# Accuracy after query 92: 0.1734
# Accuracy after query 93: 0.1819
# Accuracy after query 94: 0.1726
# Accuracy after query 95: 0.1954
# Accuracy after query 96: 0.1658
# Accuracy after query 97: 0.1927
# Accuracy after query 98: 0.1922
# Accuracy after query 1: 0.1824
# Accuracy after query 2: 0.2039
# Accuracy after query 3: 0.2081
# Accuracy after query 4: 0.2034
# Accuracy after query 5: 0.2144
# Accuracy after query 6: 0.2055
# Accuracy after query 7: 0.2048
# Accuracy after query 8: 0.2164
# Accuracy after query 9: 0.2233
# Accuracy after query 10: 0.2328
# Accuracy after query 11: 0.2114
# Accuracy after query 12: 0.2209
# Accuracy after query 13: 0.2274
# Accuracy after query 14: 0.2217
# Accuracy after query 15: 0.2353
# Accuracy after query 16: 0.2253
# Accuracy after query 17: 0.2174
# Accuracy after query 18: 0.2142
# Accuracy after query 19: 0.2453
# Accuracy after query 20: 0.2394
# Accuracy after query 21: 0.2391
# Accuracy after query 22: 0.2246
# Accuracy after query 23: 0.2450
# Accuracy after query 24: 0.2475
# Accuracy after query 25: 0.2345
# Accuracy after query 26: 0.2435
# Accuracy after query 27: 0.2470
# Accuracy after query 28: 0.2342
# Accuracy after query 29: 0.2507
# Accuracy after query 30: 0.2430
# Accuracy after query 31: 0.2555
# Accuracy after query 32: 0.2418
# Accuracy after query 33: 0.2618
# Accuracy after query 34: 0.2570
# Accuracy after query 35: 0.2539
# Accuracy after query 36: 0.2509
# Accuracy after query 37: 0.2425
# Accuracy after query 38: 0.2495
# Accuracy after query 39: 0.2463
# Accuracy after query 40: 0.2554
# Accuracy after query 41: 0.2562
# Accuracy after query 42: 0.2542
# Accuracy after query 43: 0.2580
# Accuracy after query 44: 0.2537
# Accuracy after query 45: 0.2535
# Accuracy after query 46: 0.2495
# Accuracy after query 47: 0.2560
# Accuracy after query 48: 0.2542
# Accuracy after query 49: 0.2628
# Accuracy after query 50: 0.2651
# Accuracy after query 51: 0.2600
# Accuracy after query 52: 0.2624
# Accuracy after query 53: 0.2533
# Accuracy after query 54: 0.2484
# Accuracy after query 55: 0.2589
# Accuracy after query 56: 0.2689
# Accuracy after query 57: 0.2588
# Accuracy after query 58: 0.2644
# Accuracy after query 59: 0.2598
# Accuracy after query 60: 0.2624
# Accuracy after query 61: 0.2689
# Accuracy after query 62: 0.2560
# Accuracy after query 63: 0.2593
# Accuracy after query 64: 0.2571
# Accuracy after query 65: 0.2574
# Accuracy after query 66: 0.2687
# Accuracy after query 67: 0.2696
# Accuracy after query 68: 0.2755
# Accuracy after query 69: 0.2683
# Accuracy after query 70: 0.2643
# Accuracy after query 71: 0.2706
# Accuracy after query 72: 0.2699
# Accuracy after query 73: 0.2651
# Accuracy after query 74: 0.2547
# Accuracy after query 75: 0.2680
# Accuracy after query 76: 0.2688
# Accuracy after query 77: 0.2569
# Accuracy after query 78: 0.2723
# Accuracy after query 79: 0.2627
# Accuracy after query 80: 0.2646
# Accuracy after query 81: 0.2580
# Accuracy after query 82: 0.2672
# Accuracy after query 83: 0.2625
# Accuracy after query 84: 0.2596
# Accuracy after query 85: 0.2598
# Accuracy after query 86: 0.2697
# Accuracy after query 87: 0.2805
# Accuracy after query 88: 0.2585
# Accuracy after query 89: 0.2517
# Accuracy after query 90: 0.2607
# Accuracy after query 91: 0.2667
# Accuracy after query 92: 0.2591
# Accuracy after query 93: 0.2597
# Accuracy after query 94: 0.2576
# Accuracy after query 95: 0.2610
# Accuracy after query 96: 0.2626
# Accuracy after query 97: 0.2671
# Accuracy after query 98: 0.2525
# Accuracy after query 1: 0.1578
# Accuracy after query 2: 0.2058
# Accuracy after query 3: 0.2212
# Accuracy after query 4: 0.2111
# Accuracy after query 5: 0.2030
# Accuracy after query 6: 0.2018
# Accuracy after query 7: 0.2046
# Accuracy after query 8: 0.2079
# Accuracy after query 9: 0.2122
# Accuracy after query 10: 0.2240
# Accuracy after query 11: 0.2326
# Accuracy after query 12: 0.2353
# Accuracy after query 13: 0.2497
# Accuracy after query 14: 0.2452
# Accuracy after query 15: 0.2557
# Accuracy after query 16: 0.2610
# Accuracy after query 17: 0.2628
# Accuracy after query 18: 0.2524
# Accuracy after query 19: 0.2547
# Accuracy after query 20: 0.2604
# Accuracy after query 21: 0.2628
# Accuracy after query 22: 0.2661
# Accuracy after query 23: 0.2745
# Accuracy after query 24: 0.2652
# Accuracy after query 25: 0.2613
# Accuracy after query 26: 0.2578
# Accuracy after query 27: 0.2735
# Accuracy after query 28: 0.2606
# Accuracy after query 29: 0.2685
# Accuracy after query 30: 0.2651
# Accuracy after query 31: 0.2748
# Accuracy after query 32: 0.2742
# Accuracy after query 33: 0.2644
# Accuracy after query 34: 0.2561
# Accuracy after query 35: 0.2689
# Accuracy after query 36: 0.2537
# Accuracy after query 37: 0.2583
# Accuracy after query 38: 0.2751
# Accuracy after query 39: 0.2638
# Accuracy after query 40: 0.2777
# Accuracy after query 41: 0.2797
# Accuracy after query 42: 0.2681
# Accuracy after query 43: 0.2654
# Accuracy after query 44: 0.2734
# Accuracy after query 45: 0.2772
# Accuracy after query 46: 0.2787
# Accuracy after query 47: 0.2806
# Accuracy after query 48: 0.2790
# Accuracy after query 49: 0.2764
# Accuracy after query 50: 0.2805
# Accuracy after query 51: 0.2751
# Accuracy after query 52: 0.2755
# Accuracy after query 53: 0.2805
# Accuracy after query 54: 0.2846
# Accuracy after query 55: 0.2771
# Accuracy after query 56: 0.2793
# Accuracy after query 57: 0.2844
# Accuracy after query 58: 0.2714
# Accuracy after query 59: 0.2881
# Accuracy after query 60: 0.2773
# Accuracy after query 61: 0.2782
# Accuracy after query 62: 0.2788
# Accuracy after query 63: 0.2835
# Accuracy after query 64: 0.2819
# Accuracy after query 65: 0.2817
# Accuracy after query 66: 0.2875
# Accuracy after query 67: 0.2915
# Accuracy after query 68: 0.2838
# Accuracy after query 69: 0.2851
# Accuracy after query 70: 0.2867
# Accuracy after query 71: 0.2866
# Accuracy after query 72: 0.2895
# Accuracy after query 73: 0.2848
# Accuracy after query 74: 0.2876
# Accuracy after query 75: 0.2751
# Accuracy after query 76: 0.2757
# Accuracy after query 77: 0.2820
# Accuracy after query 78: 0.2633
# Accuracy after query 79: 0.2824
# Accuracy after query 80: 0.2771
# Accuracy after query 81: 0.2679
# Accuracy after query 82: 0.2576
# Accuracy after query 83: 0.2788
# Accuracy after query 84: 0.2702
# Accuracy after query 85: 0.2718
# Accuracy after query 86: 0.2681
# Accuracy after query 87: 0.2733
# Accuracy after query 88: 0.2631
# Accuracy after query 89: 0.2493
# Accuracy after query 90: 0.2480
# Accuracy after query 91: 0.2551
# Accuracy after query 92: 0.2567
# Accuracy after query 93: 0.2539
# Accuracy after query 94: 0.2671
# Accuracy after query 95: 0.2629
# Accuracy after query 96: 0.2591
# Accuracy after query 97: 0.2581
# Accuracy after query 98: 0.2555
# Accuracy after query 1: 0.2093
# Accuracy after query 2: 0.2419
# Accuracy after query 3: 0.2357
# Accuracy after query 4: 0.2307
# Accuracy after query 5: 0.2358
# Accuracy after query 6: 0.2360
# Accuracy after query 7: 0.2428
# Accuracy after query 8: 0.2511
# Accuracy after query 9: 0.2470
# Accuracy after query 10: 0.2570
# Accuracy after query 11: 0.2551
# Accuracy after query 12: 0.2264
# Accuracy after query 13: 0.2373
# Accuracy after query 14: 0.2524
# Accuracy after query 15: 0.2514
# Accuracy after query 16: 0.2585
# Accuracy after query 17: 0.2525
# Accuracy after query 18: 0.2626
# Accuracy after query 19: 0.2717
# Accuracy after query 20: 0.2585
# Accuracy after query 21: 0.2646
# Accuracy after query 22: 0.2690
# Accuracy after query 23: 0.2743
# Accuracy after query 24: 0.2779
# Accuracy after query 25: 0.2702
# Accuracy after query 26: 0.2727
# Accuracy after query 27: 0.2614
# Accuracy after query 28: 0.2680
# Accuracy after query 29: 0.2732
# Accuracy after query 30: 0.2715
# Accuracy after query 31: 0.2800
# Accuracy after query 32: 0.2738
# Accuracy after query 33: 0.2756
# Accuracy after query 34: 0.2792
# Accuracy after query 35: 0.2784
# Accuracy after query 36: 0.2743
# Accuracy after query 37: 0.2713
# Accuracy after query 38: 0.2633
# Accuracy after query 39: 0.2724
# Accuracy after query 40: 0.2598
# Accuracy after query 41: 0.2683
# Accuracy after query 42: 0.2626
# Accuracy after query 43: 0.2559
# Accuracy after query 44: 0.2641
# Accuracy after query 45: 0.2605
# Accuracy after query 46: 0.2662
# Accuracy after query 47: 0.2657
# Accuracy after query 48: 0.2670
# Accuracy after query 49: 0.2657
# Accuracy after query 50: 0.2685
# Accuracy after query 51: 0.2613
# Accuracy after query 52: 0.2552
# Accuracy after query 53: 0.2557
# Accuracy after query 54: 0.2527
# Accuracy after query 55: 0.2448
# Accuracy after query 56: 0.2550
# Accuracy after query 57: 0.2534
# Accuracy after query 58: 0.2501
# Accuracy after query 59: 0.2543
# Accuracy after query 60: 0.2531
# Accuracy after query 61: 0.2511
# Accuracy after query 62: 0.2479
# Accuracy after query 63: 0.2494
# Accuracy after query 64: 0.2557
# Accuracy after query 65: 0.2494
# Accuracy after query 66: 0.2408
# Accuracy after query 67: 0.2453
# Accuracy after query 68: 0.2489
# Accuracy after query 69: 0.2467
# Accuracy after query 70: 0.2429
# Accuracy after query 71: 0.2490
# Accuracy after query 72: 0.2467
# Accuracy after query 73: 0.2431
# Accuracy after query 74: 0.2556
# Accuracy after query 75: 0.2437
# Accuracy after query 76: 0.2214
# Accuracy after query 77: 0.1944
# Accuracy after query 78: 0.2376
# Accuracy after query 79: 0.2414
# Accuracy after query 80: 0.2511
# Accuracy after query 81: 0.2439
# Accuracy after query 82: 0.2423
# Accuracy after query 83: 0.2425
# Accuracy after query 84: 0.2431
# Accuracy after query 85: 0.2378
# Accuracy after query 86: 0.2469
# Accuracy after query 87: 0.2449
# Accuracy after query 88: 0.2234
# Accuracy after query 89: 0.2247
# Accuracy after query 90: 0.2205
# Accuracy after query 91: 0.2194
# Accuracy after query 92: 0.2269
# Accuracy after query 93: 0.2276
# Accuracy after query 94: 0.2217
# Accuracy after query 95: 0.2248
# Accuracy after query 96: 0.2070
# Accuracy after query 97: 0.2292
# Accuracy after query 98: 0.2211
# Accuracy after query 1: 0.2100
# Accuracy after query 2: 0.2324
# Accuracy after query 3: 0.2409
# Accuracy after query 4: 0.2441
# Accuracy after query 5: 0.2232
# Accuracy after query 6: 0.2333
# Accuracy after query 7: 0.2375
# Accuracy after query 8: 0.2398
# Accuracy after query 9: 0.2443
# Accuracy after query 10: 0.2424
# Accuracy after query 11: 0.2492
# Accuracy after query 12: 0.2500
# Accuracy after query 13: 0.2580
# Accuracy after query 14: 0.2605
# Accuracy after query 15: 0.2649
# Accuracy after query 16: 0.2863
# Accuracy after query 17: 0.2710
# Accuracy after query 18: 0.2801
# Accuracy after query 19: 0.2632
# Accuracy after query 20: 0.2841
# Accuracy after query 21: 0.2832
# Accuracy after query 22: 0.2800
# Accuracy after query 23: 0.2850
# Accuracy after query 24: 0.2872
# Accuracy after query 25: 0.2661
# Accuracy after query 26: 0.2813
# Accuracy after query 27: 0.2718
# Accuracy after query 28: 0.2824
# Accuracy after query 29: 0.2799
# Accuracy after query 30: 0.2797
# Accuracy after query 31: 0.2976
# Accuracy after query 32: 0.2933
# Accuracy after query 33: 0.2853
# Accuracy after query 34: 0.2736
# Accuracy after query 35: 0.2914
# Accuracy after query 36: 0.2877
# Accuracy after query 37: 0.2954
# Accuracy after query 38: 0.2891
# Accuracy after query 39: 0.2808
# Accuracy after query 40: 0.2665
# Accuracy after query 41: 0.2846
# Accuracy after query 42: 0.2680
# Accuracy after query 43: 0.2906
# Accuracy after query 44: 0.2900
# Accuracy after query 45: 0.2761
# Accuracy after query 46: 0.2903
# Accuracy after query 47: 0.3000
# Accuracy after query 48: 0.2991
# Accuracy after query 49: 0.2940
# Accuracy after query 50: 0.2802
# Accuracy after query 51: 0.2834
# Accuracy after query 52: 0.2896
# Accuracy after query 53: 0.2831
# Accuracy after query 54: 0.2872
# Accuracy after query 55: 0.2912
# Accuracy after query 56: 0.2898
# Accuracy after query 57: 0.2978
# Accuracy after query 58: 0.2878
# Accuracy after query 59: 0.2972
# Accuracy after query 60: 0.2915
# Accuracy after query 61: 0.3001
# Accuracy after query 62: 0.2991
# Accuracy after query 63: 0.2850
# Accuracy after query 64: 0.2939
# Accuracy after query 65: 0.2975
# Accuracy after query 66: 0.2925
# Accuracy after query 67: 0.2858
# Accuracy after query 68: 0.2941
# Accuracy after query 69: 0.3028
# Accuracy after query 70: 0.3042
# Accuracy after query 71: 0.3058
# Accuracy after query 72: 0.3020
# Accuracy after query 73: 0.3057
# Accuracy after query 74: 0.3042
# Accuracy after query 75: 0.2761
# Accuracy after query 76: 0.3035
# Accuracy after query 77: 0.3003
# Accuracy after query 78: 0.3093
# Accuracy after query 79: 0.2941
# Accuracy after query 80: 0.2892
# Accuracy after query 81: 0.2913
# Accuracy after query 82: 0.2992
# Accuracy after query 83: 0.2971
# Accuracy after query 84: 0.2969
# Accuracy after query 85: 0.2988
# Accuracy after query 86: 0.2978
# Accuracy after query 87: 0.2885
# Accuracy after query 88: 0.2987
# Accuracy after query 89: 0.2950
# Accuracy after query 90: 0.2787
# Accuracy after query 91: 0.2990
# Accuracy after query 92: 0.2952
# Accuracy after query 93: 0.2971
# Accuracy after query 94: 0.2905
# Accuracy after query 95: 0.2888
# Accuracy after query 96: 0.2979
# Accuracy after query 97: 0.2991
# Accuracy after query 98: 0.2996
# Accuracy after query 1: 0.2038
# Accuracy after query 2: 0.2232
# Accuracy after query 3: 0.2211
# Accuracy after query 4: 0.2381
# Accuracy after query 5: 0.2404
# Accuracy after query 6: 0.2476
# Accuracy after query 7: 0.2355
# Accuracy after query 8: 0.2440
# Accuracy after query 9: 0.2359
# Accuracy after query 10: 0.2434
# Accuracy after query 11: 0.2415
# Accuracy after query 12: 0.2474
# Accuracy after query 13: 0.2316
# Accuracy after query 14: 0.2495
# Accuracy after query 15: 0.2482
# Accuracy after query 16: 0.2522
# Accuracy after query 17: 0.2530
# Accuracy after query 18: 0.2577
# Accuracy after query 19: 0.2475
# Accuracy after query 20: 0.2579
# Accuracy after query 21: 0.2595
# Accuracy after query 22: 0.2631
# Accuracy after query 23: 0.2545
# Accuracy after query 24: 0.2576
# Accuracy after query 25: 0.2476
# Accuracy after query 26: 0.2661
# Accuracy after query 27: 0.2522
# Accuracy after query 28: 0.2501
# Accuracy after query 29: 0.2602
# Accuracy after query 30: 0.2729
# Accuracy after query 31: 0.2537
# Accuracy after query 32: 0.2767
# Accuracy after query 33: 0.2551
# Accuracy after query 34: 0.2624
# Accuracy after query 35: 0.2624
# Accuracy after query 36: 0.2735
# Accuracy after query 37: 0.2431
# Accuracy after query 38: 0.2325
# Accuracy after query 39: 0.2630
# Accuracy after query 40: 0.2481
# Accuracy after query 41: 0.2516
# Accuracy after query 42: 0.2430
# Accuracy after query 43: 0.2503
# Accuracy after query 44: 0.2389
# Accuracy after query 45: 0.2449
# Accuracy after query 46: 0.2438
# Accuracy after query 47: 0.2404
# Accuracy after query 48: 0.2477
# Accuracy after query 49: 0.2586
# Accuracy after query 50: 0.2373
# Accuracy after query 51: 0.2432
# Accuracy after query 52: 0.2422
# Accuracy after query 53: 0.2471
# Accuracy after query 54: 0.2350
# Accuracy after query 55: 0.2399
# Accuracy after query 56: 0.2447
# Accuracy after query 57: 0.2215
# Accuracy after query 58: 0.2464
# Accuracy after query 59: 0.2385
# Accuracy after query 60: 0.2254
# Accuracy after query 61: 0.2371
# Accuracy after query 62: 0.2388
# Accuracy after query 63: 0.2313
# Accuracy after query 64: 0.2186
# Accuracy after query 65: 0.2410
# Accuracy after query 66: 0.2395
# Accuracy after query 67: 0.2262
# Accuracy after query 68: 0.2245
# Accuracy after query 69: 0.2368
# Accuracy after query 70: 0.2159
# Accuracy after query 71: 0.2254
# Accuracy after query 72: 0.2042
# Accuracy after query 73: 0.2122
# Accuracy after query 74: 0.2136
# Accuracy after query 75: 0.1833
# Accuracy after query 76: 0.1781
# Accuracy after query 77: 0.1699
# Accuracy after query 78: 0.1938
# Accuracy after query 79: 0.1938
# Accuracy after query 80: 0.2052
# Accuracy after query 81: 0.1869
# Accuracy after query 82: 0.2052
# Accuracy after query 83: 0.1915
# Accuracy after query 84: 0.1819
# Accuracy after query 85: 0.1887
# Accuracy after query 86: 0.1682
# Accuracy after query 87: 0.2082
# Accuracy after query 88: 0.1639
# Accuracy after query 89: 0.1675
# Accuracy after query 90: 0.1771
# Accuracy after query 91: 0.1581
# Accuracy after query 92: 0.1772
# Accuracy after query 93: 0.1811
# Accuracy after query 94: 0.1874
# Accuracy after query 95: 0.1825
# Accuracy after query 96: 0.1801
# Accuracy after query 97: 0.1878
# Accuracy after query 98: 0.1809
# Accuracy after query 1: 0.1764
# Accuracy after query 2: 0.2261
# Accuracy after query 3: 0.2395
# Accuracy after query 4: 0.2382
# Accuracy after query 5: 0.2423
# Accuracy after query 6: 0.2578
# Accuracy after query 7: 0.2434
# Accuracy after query 8: 0.2486
# Accuracy after query 9: 0.2481
# Accuracy after query 10: 0.2532
# Accuracy after query 11: 0.2640
# Accuracy after query 12: 0.2653
# Accuracy after query 13: 0.2511
# Accuracy after query 14: 0.2652
# Accuracy after query 15: 0.2675
# Accuracy after query 16: 0.2585
# Accuracy after query 17: 0.2698
# Accuracy after query 18: 0.2718
# Accuracy after query 19: 0.2564
# Accuracy after query 20: 0.2692
# Accuracy after query 21: 0.2706
# Accuracy after query 22: 0.2587
# Accuracy after query 23: 0.2817
# Accuracy after query 24: 0.2679
# Accuracy after query 25: 0.2689
# Accuracy after query 26: 0.2759
# Accuracy after query 27: 0.2839
# Accuracy after query 28: 0.2693
# Accuracy after query 29: 0.2703
# Accuracy after query 30: 0.2777
# Accuracy after query 31: 0.2579
# Accuracy after query 32: 0.2613
# Accuracy after query 33: 0.2569
# Accuracy after query 34: 0.2699
# Accuracy after query 35: 0.2804
# Accuracy after query 36: 0.2743
# Accuracy after query 37: 0.2823
# Accuracy after query 38: 0.2703
# Accuracy after query 39: 0.2858
# Accuracy after query 40: 0.2733
# Accuracy after query 41: 0.2770
# Accuracy after query 42: 0.2683
# Accuracy after query 43: 0.2740
# Accuracy after query 44: 0.2836
# Accuracy after query 45: 0.2895
# Accuracy after query 46: 0.2839
# Accuracy after query 47: 0.2813
# Accuracy after query 48: 0.2749
# Accuracy after query 49: 0.2935
# Accuracy after query 50: 0.2658
# Accuracy after query 51: 0.2759
# Accuracy after query 52: 0.2975
# Accuracy after query 53: 0.2746
# Accuracy after query 54: 0.2873
# Accuracy after query 55: 0.2810
# Accuracy after query 56: 0.2797
# Accuracy after query 57: 0.2784
# Accuracy after query 58: 0.2721
# Accuracy after query 59: 0.2833
# Accuracy after query 60: 0.2755
# Accuracy after query 61: 0.2727
# Accuracy after query 62: 0.2727
# Accuracy after query 63: 0.2835
# Accuracy after query 64: 0.2855
# Accuracy after query 65: 0.2881
# Accuracy after query 66: 0.2902
# Accuracy after query 67: 0.2916
# Accuracy after query 68: 0.2866
# Accuracy after query 69: 0.2951
# Accuracy after query 70: 0.2870
# Accuracy after query 71: 0.2942
# Accuracy after query 72: 0.2875
# Accuracy after query 73: 0.2929
# Accuracy after query 74: 0.3056
# Accuracy after query 75: 0.2614
# Accuracy after query 76: 0.2910
# Accuracy after query 77: 0.2788
# Accuracy after query 78: 0.2755
# Accuracy after query 79: 0.2879
# Accuracy after query 80: 0.2895
# Accuracy after query 81: 0.2898
# Accuracy after query 82: 0.2879
# Accuracy after query 83: 0.2849
# Accuracy after query 84: 0.2785
# Accuracy after query 85: 0.2874
# Accuracy after query 86: 0.2738
# Accuracy after query 87: 0.3000
# Accuracy after query 88: 0.2843
# Accuracy after query 89: 0.2829
# Accuracy after query 90: 0.2908
# Accuracy after query 91: 0.2867
# Accuracy after query 92: 0.2929
# Accuracy after query 93: 0.2818
# Accuracy after query 94: 0.2845
# Accuracy after query 95: 0.2839
# Accuracy after query 96: 0.2947
# Accuracy after query 97: 0.2844
# Accuracy after query 98: 0.2941
# Accuracy after query 1: 0.2096
# Accuracy after query 2: 0.2292
# Accuracy after query 3: 0.2304
# Accuracy after query 4: 0.2288
# Accuracy after query 5: 0.2462
# Accuracy after query 6: 0.2260
# Accuracy after query 7: 0.2389
# Accuracy after query 8: 0.2444
# Accuracy after query 9: 0.2423
# Accuracy after query 10: 0.2437
# Accuracy after query 11: 0.2556
# Accuracy after query 12: 0.2565
# Accuracy after query 13: 0.2618
# Accuracy after query 14: 0.2567
# Accuracy after query 15: 0.2628
# Accuracy after query 16: 0.2642
# Accuracy after query 17: 0.2642
# Accuracy after query 18: 0.2446
# Accuracy after query 19: 0.2568
# Accuracy after query 20: 0.2528
# Accuracy after query 21: 0.2470
# Accuracy after query 22: 0.2517
# Accuracy after query 23: 0.2526
# Accuracy after query 24: 0.2700
# Accuracy after query 25: 0.2586
# Accuracy after query 26: 0.2707
# Accuracy after query 27: 0.2693
# Accuracy after query 28: 0.2629
# Accuracy after query 29: 0.2730
# Accuracy after query 30: 0.2732
# Accuracy after query 31: 0.2642
# Accuracy after query 32: 0.2708
# Accuracy after query 33: 0.2746
# Accuracy after query 34: 0.2804
# Accuracy after query 35: 0.2812
# Accuracy after query 36: 0.2837
# Accuracy after query 37: 0.2838
# Accuracy after query 38: 0.2795
# Accuracy after query 39: 0.2871
# Accuracy after query 40: 0.2800
# Accuracy after query 41: 0.2933
# Accuracy after query 42: 0.2880
# Accuracy after query 43: 0.2949
# Accuracy after query 44: 0.2904
# Accuracy after query 45: 0.2923
# Accuracy after query 46: 0.2840
# Accuracy after query 47: 0.2983
# Accuracy after query 48: 0.2943
# Accuracy after query 49: 0.2888
# Accuracy after query 50: 0.2891
# Accuracy after query 51: 0.2850
# Accuracy after query 52: 0.2948
# Accuracy after query 53: 0.2986
# Accuracy after query 54: 0.2922
# Accuracy after query 55: 0.2884
# Accuracy after query 56: 0.2897
# Accuracy after query 57: 0.2843
# Accuracy after query 58: 0.2904
# Accuracy after query 59: 0.2883
# Accuracy after query 60: 0.2917
# Accuracy after query 61: 0.2942
# Accuracy after query 62: 0.2804
# Accuracy after query 63: 0.2906
# Accuracy after query 64: 0.2803
# Accuracy after query 65: 0.2897
# Accuracy after query 66: 0.2895
# Accuracy after query 67: 0.2809
# Accuracy after query 68: 0.2847
# Accuracy after query 69: 0.2814
# Accuracy after query 70: 0.2795
# Accuracy after query 71: 0.2736
# Accuracy after query 72: 0.2764
# Accuracy after query 73: 0.2800
# Accuracy after query 74: 0.2777
# Accuracy after query 75: 0.2706
# Accuracy after query 76: 0.2799
# Accuracy after query 77: 0.2579
# Accuracy after query 78: 0.2649
# Accuracy after query 79: 0.2701
# Accuracy after query 80: 0.2684
# Accuracy after query 81: 0.2687
# Accuracy after query 82: 0.2646
# Accuracy after query 83: 0.2774
# Accuracy after query 84: 0.2657
# Accuracy after query 85: 0.2701
# Accuracy after query 86: 0.2686
# Accuracy after query 87: 0.2758
# Accuracy after query 88: 0.2753
# Accuracy after query 89: 0.2669
# Accuracy after query 90: 0.2751
# Accuracy after query 91: 0.2738
# Accuracy after query 92: 0.2663
# Accuracy after query 93: 0.2626
# Accuracy after query 94: 0.2756
# Accuracy after query 95: 0.2729
# Accuracy after query 96: 0.2722
# Accuracy after query 97: 0.2726
# Accuracy after query 98: 0.2702
# Accuracy after query 1: 0.1631
# Accuracy after query 2: 0.1858
# Accuracy after query 3: 0.2177
# Accuracy after query 4: 0.2369
# Accuracy after query 5: 0.2445
# Accuracy after query 6: 0.2407
# Accuracy after query 7: 0.2441
# Accuracy after query 8: 0.2435
# Accuracy after query 9: 0.2412
# Accuracy after query 10: 0.2500
# Accuracy after query 11: 0.2620
# Accuracy after query 12: 0.2661
# Accuracy after query 13: 0.2677
# Accuracy after query 14: 0.2621
# Accuracy after query 15: 0.2539
# Accuracy after query 16: 0.2591
# Accuracy after query 17: 0.2604
# Accuracy after query 18: 0.2652
# Accuracy after query 19: 0.2685
# Accuracy after query 20: 0.2702
# Accuracy after query 21: 0.2650
# Accuracy after query 22: 0.2638
# Accuracy after query 23: 0.2732
# Accuracy after query 24: 0.2654
# Accuracy after query 25: 0.2629
# Accuracy after query 26: 0.2721
# Accuracy after query 27: 0.2562
# Accuracy after query 28: 0.2644
# Accuracy after query 29: 0.2713
# Accuracy after query 30: 0.2577
# Accuracy after query 31: 0.2657
# Accuracy after query 32: 0.2775
# Accuracy after query 33: 0.2691
# Accuracy after query 34: 0.2813
# Accuracy after query 35: 0.2834
# Accuracy after query 36: 0.2783
# Accuracy after query 37: 0.2828
# Accuracy after query 38: 0.2837
# Accuracy after query 39: 0.2749
# Accuracy after query 40: 0.2690
# Accuracy after query 41: 0.2816
# Accuracy after query 42: 0.2797
# Accuracy after query 43: 0.2695
# Accuracy after query 44: 0.2774
# Accuracy after query 45: 0.2765
# Accuracy after query 46: 0.2823
# Accuracy after query 47: 0.2905
# Accuracy after query 48: 0.2864
# Accuracy after query 49: 0.2881
# Accuracy after query 50: 0.2770
# Accuracy after query 51: 0.2796
# Accuracy after query 52: 0.2729
# Accuracy after query 53: 0.2643
# Accuracy after query 54: 0.2704
# Accuracy after query 55: 0.2832
# Accuracy after query 56: 0.2828
# Accuracy after query 57: 0.2901
# Accuracy after query 58: 0.2823
# Accuracy after query 59: 0.2862
# Accuracy after query 60: 0.2800
# Accuracy after query 61: 0.2833
# Accuracy after query 62: 0.2864
# Accuracy after query 63: 0.2770
# Accuracy after query 64: 0.2834
# Accuracy after query 65: 0.2871
# Accuracy after query 66: 0.2829
# Accuracy after query 67: 0.2823
# Accuracy after query 68: 0.2849
# Accuracy after query 69: 0.2842
# Accuracy after query 70: 0.2778
# Accuracy after query 71: 0.2771
# Accuracy after query 72: 0.2805
# Accuracy after query 73: 0.2697
# Accuracy after query 74: 0.2712
# Accuracy after query 75: 0.2693
# Accuracy after query 76: 0.2512
# Accuracy after query 77: 0.2647
# Accuracy after query 78: 0.2639
# Accuracy after query 79: 0.2542
# Accuracy after query 80: 0.2630
# Accuracy after query 81: 0.2677
# Accuracy after query 82: 0.2636
# Accuracy after query 83: 0.2611
# Accuracy after query 84: 0.2564
# Accuracy after query 85: 0.2655
# Accuracy after query 86: 0.2610
# Accuracy after query 87: 0.2658
# Accuracy after query 88: 0.2692
# Accuracy after query 89: 0.2532
# Accuracy after query 90: 0.2635
# Accuracy after query 91: 0.2604
# Accuracy after query 92: 0.2647
# Accuracy after query 93: 0.2649
# Accuracy after query 94: 0.2611
# Accuracy after query 95: 0.2607
# Accuracy after query 96: 0.2627
# Accuracy after query 97: 0.2650
# Accuracy after query 98: 0.2611
# Accuracy after query 1: 0.1698
# Accuracy after query 2: 0.1940
# Accuracy after query 3: 0.2149
# Accuracy after query 4: 0.2203
# Accuracy after query 5: 0.2249
# Accuracy after query 6: 0.2298
# Accuracy after query 7: 0.2333
# Accuracy after query 8: 0.2379
# Accuracy after query 9: 0.2465
# Accuracy after query 10: 0.2466
# Accuracy after query 11: 0.2473
# Accuracy after query 12: 0.2488
# Accuracy after query 13: 0.2415
# Accuracy after query 14: 0.2579
# Accuracy after query 15: 0.2574
# Accuracy after query 16: 0.2529
# Accuracy after query 17: 0.2469
# Accuracy after query 18: 0.2582
# Accuracy after query 19: 0.2630
# Accuracy after query 20: 0.2578
# Accuracy after query 21: 0.2586
# Accuracy after query 22: 0.2648
# Accuracy after query 23: 0.2550
# Accuracy after query 24: 0.2572
# Accuracy after query 25: 0.2539
# Accuracy after query 26: 0.2743
# Accuracy after query 27: 0.2634
# Accuracy after query 28: 0.2551
# Accuracy after query 29: 0.2551
# Accuracy after query 30: 0.2650
# Accuracy after query 31: 0.2609
# Accuracy after query 32: 0.2727
# Accuracy after query 33: 0.2738
# Accuracy after query 34: 0.2672
# Accuracy after query 35: 0.2748
# Accuracy after query 36: 0.2521
# Accuracy after query 37: 0.2725
# Accuracy after query 38: 0.2593
# Accuracy after query 39: 0.2707
# Accuracy after query 40: 0.2665
# Accuracy after query 41: 0.2668
# Accuracy after query 42: 0.2725
# Accuracy after query 43: 0.2682
# Accuracy after query 44: 0.2648
# Accuracy after query 45: 0.2771
# Accuracy after query 46: 0.2814
# Accuracy after query 47: 0.2765
# Accuracy after query 48: 0.2739
# Accuracy after query 49: 0.2859
# Accuracy after query 50: 0.2812
# Accuracy after query 51: 0.2739
# Accuracy after query 52: 0.2953
# Accuracy after query 53: 0.2835
# Accuracy after query 54: 0.2921
# Accuracy after query 55: 0.2875
# Accuracy after query 56: 0.2845
# Accuracy after query 57: 0.2907
# Accuracy after query 58: 0.2864
# Accuracy after query 59: 0.2837
# Accuracy after query 60: 0.2902
# Accuracy after query 61: 0.2834
# Accuracy after query 62: 0.2927
# Accuracy after query 63: 0.2810
# Accuracy after query 64: 0.2852
# Accuracy after query 65: 0.2796
# Accuracy after query 66: 0.2798
# Accuracy after query 67: 0.2807
# Accuracy after query 68: 0.2839
# Accuracy after query 69: 0.2901
# Accuracy after query 70: 0.2852
# Accuracy after query 71: 0.2779
# Accuracy after query 72: 0.2704
# Accuracy after query 73: 0.2846
# Accuracy after query 74: 0.2800
# Accuracy after query 75: 0.2880
# Accuracy after query 76: 0.2701
# Accuracy after query 77: 0.2697
# Accuracy after query 78: 0.2853
# Accuracy after query 79: 0.2843
# Accuracy after query 80: 0.2919
# Accuracy after query 81: 0.2963
# Accuracy after query 82: 0.2954
# Accuracy after query 83: 0.2985
# Accuracy after query 84: 0.2843
# Accuracy after query 85: 0.2904
# Accuracy after query 86: 0.2846
# Accuracy after query 87: 0.2931
# Accuracy after query 88: 0.2972
# Accuracy after query 89: 0.3003
# Accuracy after query 90: 0.2981
# Accuracy after query 91: 0.2999
# Accuracy after query 92: 0.3038
# Accuracy after query 93: 0.3040
# Accuracy after query 94: 0.3004
# Accuracy after query 95: 0.2952
# Accuracy after query 96: 0.2914
# Accuracy after query 97: 0.3026
# Accuracy after query 98: 0.2884
# Accuracy after query 1: 0.1615
# Accuracy after query 2: 0.1760
# Accuracy after query 3: 0.1796
# Accuracy after query 4: 0.1909
# Accuracy after query 5: 0.2035
# Accuracy after query 6: 0.2121
# Accuracy after query 7: 0.2167
# Accuracy after query 8: 0.2180
# Accuracy after query 9: 0.2293
# Accuracy after query 10: 0.2200
# Accuracy after query 11: 0.2119
# Accuracy after query 12: 0.2207
# Accuracy after query 13: 0.2263
# Accuracy after query 14: 0.2293
# Accuracy after query 15: 0.2337
# Accuracy after query 16: 0.2283
# Accuracy after query 17: 0.2425
# Accuracy after query 18: 0.2317
# Accuracy after query 19: 0.2469
# Accuracy after query 20: 0.2427
# Accuracy after query 21: 0.2523
# Accuracy after query 22: 0.2547
# Accuracy after query 23: 0.2539
# Accuracy after query 24: 0.2491
# Accuracy after query 25: 0.2489
# Accuracy after query 26: 0.2630
# Accuracy after query 27: 0.2484
# Accuracy after query 28: 0.2525
# Accuracy after query 29: 0.2596
# Accuracy after query 30: 0.2557
# Accuracy after query 31: 0.2582
# Accuracy after query 32: 0.2655
# Accuracy after query 33: 0.2663
# Accuracy after query 34: 0.2699
# Accuracy after query 35: 0.2635
# Accuracy after query 36: 0.2669
# Accuracy after query 37: 0.2643
# Accuracy after query 38: 0.2658
# Accuracy after query 39: 0.2624
# Accuracy after query 40: 0.2612
# Accuracy after query 41: 0.2622
# Accuracy after query 42: 0.2561
# Accuracy after query 43: 0.2592
# Accuracy after query 44: 0.2665
# Accuracy after query 45: 0.2688
# Accuracy after query 46: 0.2701
# Accuracy after query 47: 0.2632
# Accuracy after query 48: 0.2625
# Accuracy after query 49: 0.2578
# Accuracy after query 50: 0.2403
# Accuracy after query 51: 0.2520
# Accuracy after query 52: 0.2570
# Accuracy after query 53: 0.2472
# Accuracy after query 54: 0.2491
# Accuracy after query 55: 0.2625
# Accuracy after query 56: 0.2528
# Accuracy after query 57: 0.2529
# Accuracy after query 58: 0.2515
# Accuracy after query 59: 0.2528
# Accuracy after query 60: 0.2607
# Accuracy after query 61: 0.2694
# Accuracy after query 62: 0.2629
# Accuracy after query 63: 0.2458
# Accuracy after query 64: 0.2432
# Accuracy after query 65: 0.2364
# Accuracy after query 66: 0.2494
# Accuracy after query 67: 0.2573
# Accuracy after query 68: 0.2464
# Accuracy after query 69: 0.2469
# Accuracy after query 70: 0.2531
# Accuracy after query 71: 0.2540
# Accuracy after query 72: 0.2475
# Accuracy after query 73: 0.2343
# Accuracy after query 74: 0.2471
# Accuracy after query 75: 0.2258
# Accuracy after query 76: 0.2358
# Accuracy after query 77: 0.2355
# Accuracy after query 78: 0.2514
# Accuracy after query 79: 0.2318
# Accuracy after query 80: 0.2255
# Accuracy after query 81: 0.2393
# Accuracy after query 82: 0.2208
# Accuracy after query 83: 0.2487
# Accuracy after query 84: 0.2464
# Accuracy after query 85: 0.2426
# Accuracy after query 86: 0.2445
# Accuracy after query 87: 0.2461
# Accuracy after query 88: 0.2438
# Accuracy after query 89: 0.2284
# Accuracy after query 90: 0.2364
# Accuracy after query 91: 0.2310
# Accuracy after query 92: 0.2197
# Accuracy after query 93: 0.2325
# Accuracy after query 94: 0.2392
# Accuracy after query 95: 0.2424
# Accuracy after query 96: 0.2266
# Accuracy after query 97: 0.2207
# Accuracy after query 98: 0.2310
# Accuracy after query 1: 0.1551
# Accuracy after query 2: 0.1659
# Accuracy after query 3: 0.1893
# Accuracy after query 4: 0.1973
# Accuracy after query 5: 0.2048
# Accuracy after query 6: 0.2215
# Accuracy after query 7: 0.2098
# Accuracy after query 8: 0.2277
# Accuracy after query 9: 0.2097
# Accuracy after query 10: 0.2265
# Accuracy after query 11: 0.2291
# Accuracy after query 12: 0.2266
# Accuracy after query 13: 0.2424
# Accuracy after query 14: 0.2239
# Accuracy after query 15: 0.2289
# Accuracy after query 16: 0.2505
# Accuracy after query 17: 0.2518
# Accuracy after query 18: 0.2465
# Accuracy after query 19: 0.2545
# Accuracy after query 20: 0.2622
# Accuracy after query 21: 0.2458
# Accuracy after query 22: 0.2635
# Accuracy after query 23: 0.2617
# Accuracy after query 24: 0.2471
# Accuracy after query 25: 0.2444
# Accuracy after query 26: 0.2549
# Accuracy after query 27: 0.2580
# Accuracy after query 28: 0.2655
# Accuracy after query 29: 0.2610
# Accuracy after query 30: 0.2634
# Accuracy after query 31: 0.2628
# Accuracy after query 32: 0.2776
# Accuracy after query 33: 0.2806
# Accuracy after query 34: 0.2788
# Accuracy after query 35: 0.2700
# Accuracy after query 36: 0.2855
# Accuracy after query 37: 0.2777
# Accuracy after query 38: 0.2792
# Accuracy after query 39: 0.2718
# Accuracy after query 40: 0.2806
# Accuracy after query 41: 0.2728
# Accuracy after query 42: 0.2747
# Accuracy after query 43: 0.2851
# Accuracy after query 44: 0.2800
# Accuracy after query 45: 0.2848
# Accuracy after query 46: 0.2765
# Accuracy after query 47: 0.2794
# Accuracy after query 48: 0.2801
# Accuracy after query 49: 0.2761
# Accuracy after query 50: 0.2901
# Accuracy after query 51: 0.2786
# Accuracy after query 52: 0.2795
# Accuracy after query 53: 0.2826
# Accuracy after query 54: 0.2781
# Accuracy after query 55: 0.2662
# Accuracy after query 56: 0.2766
# Accuracy after query 57: 0.2823
# Accuracy after query 58: 0.2651
# Accuracy after query 59: 0.2693
# Accuracy after query 60: 0.2752
# Accuracy after query 61: 0.2796
# Accuracy after query 62: 0.2787
# Accuracy after query 63: 0.2456
# Accuracy after query 64: 0.2567
# Accuracy after query 65: 0.2814
# Accuracy after query 66: 0.2796
# Accuracy after query 67: 0.2791
# Accuracy after query 68: 0.2811
# Accuracy after query 69: 0.2825
# Accuracy after query 70: 0.2637
# Accuracy after query 71: 0.2849
# Accuracy after query 72: 0.2851
# Accuracy after query 73: 0.2814
# Accuracy after query 74: 0.2875
# Accuracy after query 75: 0.2774
# Accuracy after query 76: 0.2929
# Accuracy after query 77: 0.2884
# Accuracy after query 78: 0.2889
# Accuracy after query 79: 0.2860
# Accuracy after query 80: 0.2907
# Accuracy after query 81: 0.2781
# Accuracy after query 82: 0.2827
# Accuracy after query 83: 0.2840
# Accuracy after query 84: 0.2801
# Accuracy after query 85: 0.2909
# Accuracy after query 86: 0.2785
# Accuracy after query 87: 0.2875
# Accuracy after query 88: 0.2853
# Accuracy after query 89: 0.2953
# Accuracy after query 90: 0.2981
# Accuracy after query 91: 0.2906
# Accuracy after query 92: 0.2920
# Accuracy after query 93: 0.2878
# Accuracy after query 94: 0.2931
# Accuracy after query 95: 0.2824
# Accuracy after query 96: 0.2815
# Accuracy after query 97: 0.2929
# Accuracy after query 98: 0.3021
# Accuracy after query 1: 0.1803
# Accuracy after query 2: 0.1889
# Accuracy after query 3: 0.2092
# Accuracy after query 4: 0.2214
# Accuracy after query 5: 0.2149
# Accuracy after query 6: 0.2217
# Accuracy after query 7: 0.2312
# Accuracy after query 8: 0.2146
# Accuracy after query 9: 0.2138
# Accuracy after query 10: 0.2355
# Accuracy after query 11: 0.2489
# Accuracy after query 12: 0.2430
# Accuracy after query 13: 0.2541
# Accuracy after query 14: 0.2565
# Accuracy after query 15: 0.2565
# Accuracy after query 16: 0.2462
# Accuracy after query 17: 0.2521
# Accuracy after query 18: 0.2431
# Accuracy after query 19: 0.2545
# Accuracy after query 20: 0.2584
# Accuracy after query 21: 0.2537
# Accuracy after query 22: 0.2588
# Accuracy after query 23: 0.2699
# Accuracy after query 24: 0.2597
# Accuracy after query 25: 0.2612
# Accuracy after query 26: 0.2430
# Accuracy after query 27: 0.2681
# Accuracy after query 28: 0.2617
# Accuracy after query 29: 0.2665
# Accuracy after query 30: 0.2703
# Accuracy after query 31: 0.2721
# Accuracy after query 32: 0.2741
# Accuracy after query 33: 0.2787
# Accuracy after query 34: 0.2766
# Accuracy after query 35: 0.2895
# Accuracy after query 36: 0.2783
# Accuracy after query 37: 0.2813
# Accuracy after query 38: 0.2742
# Accuracy after query 39: 0.2902
# Accuracy after query 40: 0.2873
# Accuracy after query 41: 0.2833
# Accuracy after query 42: 0.2890
# Accuracy after query 43: 0.2947
# Accuracy after query 44: 0.2918
# Accuracy after query 45: 0.2873
# Accuracy after query 46: 0.2987
# Accuracy after query 47: 0.2995
# Accuracy after query 48: 0.2824
# Accuracy after query 49: 0.2978
# Accuracy after query 50: 0.3018
# Accuracy after query 51: 0.2920
# Accuracy after query 52: 0.2840
# Accuracy after query 53: 0.2969
# Accuracy after query 54: 0.3032
# Accuracy after query 55: 0.2915
# Accuracy after query 56: 0.3005
# Accuracy after query 57: 0.2855
# Accuracy after query 58: 0.2881
# Accuracy after query 59: 0.2877
# Accuracy after query 60: 0.2877
# Accuracy after query 61: 0.2947
# Accuracy after query 62: 0.2810
# Accuracy after query 63: 0.2828
# Accuracy after query 64: 0.2938
# Accuracy after query 65: 0.2983
# Accuracy after query 66: 0.2915
# Accuracy after query 67: 0.2879
# Accuracy after query 68: 0.2897
# Accuracy after query 69: 0.2897
# Accuracy after query 70: 0.3033
# Accuracy after query 71: 0.2828
# Accuracy after query 72: 0.2759
# Accuracy after query 73: 0.3001
# Accuracy after query 74: 0.2944
# Accuracy after query 75: 0.2960
# Accuracy after query 76: 0.3063
# Accuracy after query 77: 0.2944
# Accuracy after query 78: 0.2947
# Accuracy after query 79: 0.2891
# Accuracy after query 80: 0.2914
# Accuracy after query 81: 0.2911
# Accuracy after query 82: 0.2803
# Accuracy after query 83: 0.2945
# Accuracy after query 84: 0.2878
# Accuracy after query 85: 0.2850
# Accuracy after query 86: 0.2914
# Accuracy after query 87: 0.2882
# Accuracy after query 88: 0.2800
# Accuracy after query 89: 0.2851
# Accuracy after query 90: 0.2792
# Accuracy after query 91: 0.2868
# Accuracy after query 92: 0.2838
# Accuracy after query 93: 0.2867
# Accuracy after query 94: 0.2744
# Accuracy after query 95: 0.2834
# Accuracy after query 96: 0.2886
# Accuracy after query 97: 0.2892
# Accuracy after query 98: 0.2765
