# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import cifar10

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
LATENT_DIMS = [256]
latent_dim = 256
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\cifar10_infovae_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
#     "batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self, latent_dim):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = (X_train.astype(np.float32)) / 255.
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = (X_test.astype(np.float32)) / 255.
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
y_train = y_train.reshape((y_train.shape[0], ))
y_test = y_test.reshape((y_test.shape[0], ))

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_train_enhanced_infovae.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_test_enhanced_infovae.npy")

for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))

    for func_name, acquisition_func in ACQ_FUNCS.items():  

        X_initial = X_train_enhanced[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP_REG(latent_dim).to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test_enhanced,
                                                          y_test,
                                                          X_pool,
                                                          y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# Accuracy after query 1: 0.1811
# Accuracy after query 2: 0.2000
# Accuracy after query 3: 0.1977
# Accuracy after query 4: 0.1981
# Accuracy after query 5: 0.2060
# Accuracy after query 6: 0.2120
# Accuracy after query 7: 0.2167
# Accuracy after query 8: 0.2178
# Accuracy after query 9: 0.2307
# Accuracy after query 10: 0.2328
# Accuracy after query 11: 0.2372
# Accuracy after query 12: 0.2423
# Accuracy after query 13: 0.2492
# Accuracy after query 14: 0.2446
# Accuracy after query 15: 0.2437
# Accuracy after query 16: 0.2489
# Accuracy after query 17: 0.2459
# Accuracy after query 18: 0.2528
# Accuracy after query 19: 0.2540
# Accuracy after query 20: 0.2624
# Accuracy after query 21: 0.2569
# Accuracy after query 22: 0.2642
# Accuracy after query 23: 0.2573
# Accuracy after query 24: 0.2641
# Accuracy after query 25: 0.2669
# Accuracy after query 26: 0.2647
# Accuracy after query 27: 0.2618
# Accuracy after query 28: 0.2700
# Accuracy after query 29: 0.2735
# Accuracy after query 30: 0.2759
# Accuracy after query 31: 0.2731
# Accuracy after query 32: 0.2787
# Accuracy after query 33: 0.2736
# Accuracy after query 34: 0.2813
# Accuracy after query 35: 0.2797
# Accuracy after query 36: 0.2804
# Accuracy after query 37: 0.2855
# Accuracy after query 38: 0.2811
# Accuracy after query 39: 0.2920
# Accuracy after query 40: 0.2829
# Accuracy after query 41: 0.2858
# Accuracy after query 42: 0.2896
# Accuracy after query 43: 0.2929
# Accuracy after query 44: 0.2863
# Accuracy after query 45: 0.2921
# Accuracy after query 46: 0.3018
# Accuracy after query 47: 0.2834
# Accuracy after query 48: 0.3085
# Accuracy after query 49: 0.2986
# Accuracy after query 50: 0.3025
# Accuracy after query 51: 0.3058
# Accuracy after query 52: 0.3036
# Accuracy after query 53: 0.3075
# Accuracy after query 54: 0.2995
# Accuracy after query 55: 0.3176
# Accuracy after query 56: 0.3056
# Accuracy after query 57: 0.3160
# Accuracy after query 58: 0.3114
# Accuracy after query 59: 0.3126
# Accuracy after query 60: 0.3104
# Accuracy after query 61: 0.3165
# Accuracy after query 62: 0.3168
# Accuracy after query 63: 0.3140
# Accuracy after query 64: 0.3238
# Accuracy after query 65: 0.3200
# Accuracy after query 66: 0.3214
# Accuracy after query 67: 0.3212
# Accuracy after query 68: 0.3283
# Accuracy after query 69: 0.3243
# Accuracy after query 70: 0.3212
# Accuracy after query 71: 0.3295
# Accuracy after query 72: 0.3344
# Accuracy after query 73: 0.3311
# Accuracy after query 74: 0.3324
# Accuracy after query 75: 0.3358
# Accuracy after query 76: 0.3364
# Accuracy after query 77: 0.3363
# Accuracy after query 78: 0.3305
# Accuracy after query 79: 0.3301
# Accuracy after query 80: 0.3306
# Accuracy after query 81: 0.3351
# Accuracy after query 82: 0.3308
# Accuracy after query 83: 0.3336
# Accuracy after query 84: 0.3280
# Accuracy after query 85: 0.3332
# Accuracy after query 86: 0.3317
# Accuracy after query 87: 0.3294
# Accuracy after query 88: 0.3307
# Accuracy after query 89: 0.3385
# Accuracy after query 90: 0.3381
# Accuracy after query 91: 0.3295
# Accuracy after query 92: 0.3312
# Accuracy after query 93: 0.3415
# Accuracy after query 94: 0.3389
# Accuracy after query 95: 0.3376
# Accuracy after query 96: 0.3351
# Accuracy after query 97: 0.3381
# Accuracy after query 98: 0.3343
# Accuracy after query 1: 0.1534
# Accuracy after query 2: 0.1713
# Accuracy after query 3: 0.1755
# Accuracy after query 4: 0.1802
# Accuracy after query 5: 0.1849
# Accuracy after query 6: 0.1803
# Accuracy after query 7: 0.1848
# Accuracy after query 8: 0.1956
# Accuracy after query 9: 0.1928
# Accuracy after query 10: 0.2063
# Accuracy after query 11: 0.2140
# Accuracy after query 12: 0.2205
# Accuracy after query 13: 0.2229
# Accuracy after query 14: 0.2276
# Accuracy after query 15: 0.2188
# Accuracy after query 16: 0.2212
# Accuracy after query 17: 0.2381
# Accuracy after query 18: 0.2424
# Accuracy after query 19: 0.2449
# Accuracy after query 20: 0.2434
# Accuracy after query 21: 0.2434
# Accuracy after query 22: 0.2450
# Accuracy after query 23: 0.2493
# Accuracy after query 24: 0.2452
# Accuracy after query 25: 0.2502
# Accuracy after query 26: 0.2517
# Accuracy after query 27: 0.2451
# Accuracy after query 28: 0.2572
# Accuracy after query 29: 0.2613
# Accuracy after query 30: 0.2637
# Accuracy after query 31: 0.2593
# Accuracy after query 32: 0.2710
# Accuracy after query 33: 0.2759
# Accuracy after query 34: 0.2827
# Accuracy after query 35: 0.2804
# Accuracy after query 36: 0.2810
# Accuracy after query 37: 0.2945
# Accuracy after query 38: 0.2866
# Accuracy after query 39: 0.2898
# Accuracy after query 40: 0.2869
# Accuracy after query 41: 0.2951
# Accuracy after query 42: 0.3007
# Accuracy after query 43: 0.3001
# Accuracy after query 44: 0.3111
# Accuracy after query 45: 0.3095
# Accuracy after query 46: 0.3069
# Accuracy after query 47: 0.3022
# Accuracy after query 48: 0.3112
# Accuracy after query 49: 0.3054
# Accuracy after query 50: 0.3020
# Accuracy after query 51: 0.3050
# Accuracy after query 52: 0.3015
# Accuracy after query 53: 0.3088
# Accuracy after query 54: 0.3082
# Accuracy after query 55: 0.3136
# Accuracy after query 56: 0.3192
# Accuracy after query 57: 0.3087
# Accuracy after query 58: 0.3146
# Accuracy after query 59: 0.3060
# Accuracy after query 60: 0.3069
# Accuracy after query 61: 0.3166
# Accuracy after query 62: 0.3094
# Accuracy after query 63: 0.3170
# Accuracy after query 64: 0.3259
# Accuracy after query 65: 0.3151
# Accuracy after query 66: 0.3228
# Accuracy after query 67: 0.3158
# Accuracy after query 68: 0.3231
# Accuracy after query 69: 0.3258
# Accuracy after query 70: 0.3162
# Accuracy after query 71: 0.3283
# Accuracy after query 72: 0.3147
# Accuracy after query 73: 0.3055
# Accuracy after query 74: 0.3151
# Accuracy after query 75: 0.3212
# Accuracy after query 76: 0.3200
# Accuracy after query 77: 0.3135
# Accuracy after query 78: 0.3233
# Accuracy after query 79: 0.3217
# Accuracy after query 80: 0.3226
# Accuracy after query 81: 0.3256
# Accuracy after query 82: 0.3194
# Accuracy after query 83: 0.3209
# Accuracy after query 84: 0.3190
# Accuracy after query 85: 0.3207
# Accuracy after query 86: 0.3222
# Accuracy after query 87: 0.3254
# Accuracy after query 88: 0.3227
# Accuracy after query 89: 0.3256
# Accuracy after query 90: 0.3197
# Accuracy after query 91: 0.3149
# Accuracy after query 92: 0.3156
# Accuracy after query 93: 0.3230
# Accuracy after query 94: 0.3116
# Accuracy after query 95: 0.3167
# Accuracy after query 96: 0.3285
# Accuracy after query 97: 0.3310
# Accuracy after query 98: 0.3338
# Accuracy after query 1: 0.1790
# Accuracy after query 2: 0.1831
# Accuracy after query 3: 0.1876
# Accuracy after query 4: 0.1965
# Accuracy after query 5: 0.2035
# Accuracy after query 6: 0.2020
# Accuracy after query 7: 0.2118
# Accuracy after query 8: 0.2110
# Accuracy after query 9: 0.2210
# Accuracy after query 10: 0.2235
# Accuracy after query 11: 0.2317
# Accuracy after query 12: 0.2349
# Accuracy after query 13: 0.2340
# Accuracy after query 14: 0.2367
# Accuracy after query 15: 0.2390
# Accuracy after query 16: 0.2421
# Accuracy after query 17: 0.2478
# Accuracy after query 18: 0.2434
# Accuracy after query 19: 0.2384
# Accuracy after query 20: 0.2539
# Accuracy after query 21: 0.2462
# Accuracy after query 22: 0.2468
# Accuracy after query 23: 0.2492
# Accuracy after query 24: 0.2554
# Accuracy after query 25: 0.2544
# Accuracy after query 26: 0.2547
# Accuracy after query 27: 0.2568
# Accuracy after query 28: 0.2625
# Accuracy after query 29: 0.2720
# Accuracy after query 30: 0.2645
# Accuracy after query 31: 0.2620
# Accuracy after query 32: 0.2707
# Accuracy after query 33: 0.2785
# Accuracy after query 34: 0.2759
# Accuracy after query 35: 0.2792
# Accuracy after query 36: 0.2731
# Accuracy after query 37: 0.2777
# Accuracy after query 38: 0.2718
# Accuracy after query 39: 0.2806
# Accuracy after query 40: 0.2762
# Accuracy after query 41: 0.2869
# Accuracy after query 42: 0.2871
# Accuracy after query 43: 0.2985
# Accuracy after query 44: 0.2776
# Accuracy after query 45: 0.2915
# Accuracy after query 46: 0.2947
# Accuracy after query 47: 0.2967
# Accuracy after query 48: 0.3024
# Accuracy after query 49: 0.2939
# Accuracy after query 50: 0.2961
# Accuracy after query 51: 0.2983
# Accuracy after query 52: 0.3065
# Accuracy after query 53: 0.2997
# Accuracy after query 54: 0.3076
# Accuracy after query 55: 0.3084
# Accuracy after query 56: 0.3060
# Accuracy after query 57: 0.2944
# Accuracy after query 58: 0.3135
# Accuracy after query 59: 0.3104
# Accuracy after query 60: 0.3171
# Accuracy after query 61: 0.3202
# Accuracy after query 62: 0.3080
# Accuracy after query 63: 0.3122
# Accuracy after query 64: 0.3133
# Accuracy after query 65: 0.3106
# Accuracy after query 66: 0.3118
# Accuracy after query 67: 0.3156
# Accuracy after query 68: 0.3244
# Accuracy after query 69: 0.3231
# Accuracy after query 70: 0.3218
# Accuracy after query 71: 0.3211
# Accuracy after query 72: 0.3188
# Accuracy after query 73: 0.3183
# Accuracy after query 74: 0.3101
# Accuracy after query 75: 0.3168
# Accuracy after query 76: 0.3146
# Accuracy after query 77: 0.3188
# Accuracy after query 78: 0.3265
# Accuracy after query 79: 0.3189
# Accuracy after query 80: 0.3140
# Accuracy after query 81: 0.3229
# Accuracy after query 82: 0.3259
# Accuracy after query 83: 0.3192
# Accuracy after query 84: 0.3169
# Accuracy after query 85: 0.3271
# Accuracy after query 86: 0.3249
# Accuracy after query 87: 0.3270
# Accuracy after query 88: 0.3280
# Accuracy after query 89: 0.3337
# Accuracy after query 90: 0.3329
# Accuracy after query 91: 0.3300
# Accuracy after query 92: 0.3296
# Accuracy after query 93: 0.3298
# Accuracy after query 94: 0.3376
# Accuracy after query 95: 0.3299
# Accuracy after query 96: 0.3326
# Accuracy after query 97: 0.3387
# Accuracy after query 98: 0.3337
# Accuracy after query 1: 0.1468
# Accuracy after query 2: 0.1646
# Accuracy after query 3: 0.1839
# Accuracy after query 4: 0.1867
# Accuracy after query 5: 0.1854
# Accuracy after query 6: 0.1891
# Accuracy after query 7: 0.2025
# Accuracy after query 8: 0.1907
# Accuracy after query 9: 0.1996
# Accuracy after query 10: 0.1970
# Accuracy after query 11: 0.2058
# Accuracy after query 12: 0.2124
# Accuracy after query 13: 0.2045
# Accuracy after query 14: 0.2223
# Accuracy after query 15: 0.2185
# Accuracy after query 16: 0.2113
# Accuracy after query 17: 0.2242
# Accuracy after query 18: 0.2187
# Accuracy after query 19: 0.2167
# Accuracy after query 20: 0.2178
# Accuracy after query 21: 0.2286
# Accuracy after query 22: 0.2388
# Accuracy after query 23: 0.2452
# Accuracy after query 24: 0.2440
# Accuracy after query 25: 0.2480
# Accuracy after query 26: 0.2474
# Accuracy after query 27: 0.2370
# Accuracy after query 28: 0.2503
# Accuracy after query 29: 0.2498
# Accuracy after query 30: 0.2594
# Accuracy after query 31: 0.2633
# Accuracy after query 32: 0.2580
# Accuracy after query 33: 0.2589
# Accuracy after query 34: 0.2591
# Accuracy after query 35: 0.2676
# Accuracy after query 36: 0.2645
# Accuracy after query 37: 0.2704
# Accuracy after query 38: 0.2800
# Accuracy after query 39: 0.2798
# Accuracy after query 40: 0.2780
# Accuracy after query 41: 0.2878
# Accuracy after query 42: 0.2841
# Accuracy after query 43: 0.2824
# Accuracy after query 44: 0.2808
# Accuracy after query 45: 0.2867
# Accuracy after query 46: 0.2821
# Accuracy after query 47: 0.2857
# Accuracy after query 48: 0.2760
# Accuracy after query 49: 0.2862
# Accuracy after query 50: 0.2899
# Accuracy after query 51: 0.2854
# Accuracy after query 52: 0.2931
# Accuracy after query 53: 0.2856
# Accuracy after query 54: 0.2906
# Accuracy after query 55: 0.3079
# Accuracy after query 56: 0.3096
# Accuracy after query 57: 0.2949
# Accuracy after query 58: 0.2880
# Accuracy after query 59: 0.2925
# Accuracy after query 60: 0.2968
# Accuracy after query 61: 0.2969
# Accuracy after query 62: 0.2957
# Accuracy after query 63: 0.2972
# Accuracy after query 64: 0.3030
# Accuracy after query 65: 0.3144
# Accuracy after query 66: 0.3138
# Accuracy after query 67: 0.3063
# Accuracy after query 68: 0.3079
# Accuracy after query 69: 0.3185
# Accuracy after query 70: 0.3125
# Accuracy after query 71: 0.3104
# Accuracy after query 72: 0.3144
# Accuracy after query 73: 0.3150
# Accuracy after query 74: 0.3174
# Accuracy after query 75: 0.3240
# Accuracy after query 76: 0.3224
# Accuracy after query 77: 0.3155
# Accuracy after query 78: 0.3119
# Accuracy after query 79: 0.3195
# Accuracy after query 80: 0.3107
# Accuracy after query 81: 0.3018
# Accuracy after query 82: 0.3147
# Accuracy after query 83: 0.2982
# Accuracy after query 84: 0.2955
# Accuracy after query 85: 0.2994
# Accuracy after query 86: 0.3012
# Accuracy after query 87: 0.2850
# Accuracy after query 88: 0.2982
# Accuracy after query 89: 0.2970
# Accuracy after query 90: 0.3034
# Accuracy after query 91: 0.2969
# Accuracy after query 92: 0.2890
# Accuracy after query 93: 0.3010
# Accuracy after query 94: 0.2871
# Accuracy after query 95: 0.2867
# Accuracy after query 96: 0.2995
# Accuracy after query 97: 0.2904
# Accuracy after query 98: 0.2930
# Accuracy after query 1: 0.1740
# Accuracy after query 2: 0.1887
# Accuracy after query 3: 0.2059
# Accuracy after query 4: 0.1936
# Accuracy after query 5: 0.1941
# Accuracy after query 6: 0.1846
# Accuracy after query 7: 0.1975
# Accuracy after query 8: 0.2079
# Accuracy after query 9: 0.2049
# Accuracy after query 10: 0.2121
# Accuracy after query 11: 0.2238
# Accuracy after query 12: 0.2383
# Accuracy after query 13: 0.2375
# Accuracy after query 14: 0.2399
# Accuracy after query 15: 0.2349
# Accuracy after query 16: 0.2476
# Accuracy after query 17: 0.2442
# Accuracy after query 18: 0.2516
# Accuracy after query 19: 0.2472
# Accuracy after query 20: 0.2514
# Accuracy after query 21: 0.2582
# Accuracy after query 22: 0.2590
# Accuracy after query 23: 0.2498
# Accuracy after query 24: 0.2519
# Accuracy after query 25: 0.2578
# Accuracy after query 26: 0.2546
# Accuracy after query 27: 0.2589
# Accuracy after query 28: 0.2675
# Accuracy after query 29: 0.2758
# Accuracy after query 30: 0.2753
# Accuracy after query 31: 0.2691
# Accuracy after query 32: 0.2644
# Accuracy after query 33: 0.2624
# Accuracy after query 34: 0.2706
# Accuracy after query 35: 0.2754
# Accuracy after query 36: 0.2756
# Accuracy after query 37: 0.2823
# Accuracy after query 38: 0.2919
# Accuracy after query 39: 0.2922
# Accuracy after query 40: 0.2938
# Accuracy after query 41: 0.2913
# Accuracy after query 42: 0.2895
# Accuracy after query 43: 0.2930
# Accuracy after query 44: 0.2892
# Accuracy after query 45: 0.2970
# Accuracy after query 46: 0.2959
# Accuracy after query 47: 0.3035
# Accuracy after query 48: 0.2962
# Accuracy after query 49: 0.3032
# Accuracy after query 50: 0.2981
# Accuracy after query 51: 0.3031
# Accuracy after query 52: 0.3098
# Accuracy after query 53: 0.2958
# Accuracy after query 54: 0.3154
# Accuracy after query 55: 0.3154
# Accuracy after query 56: 0.3056
# Accuracy after query 57: 0.3084
# Accuracy after query 58: 0.3068
# Accuracy after query 59: 0.3125
# Accuracy after query 60: 0.3188
# Accuracy after query 61: 0.3049
# Accuracy after query 62: 0.3084
# Accuracy after query 63: 0.3091
# Accuracy after query 64: 0.3105
# Accuracy after query 65: 0.3162
# Accuracy after query 66: 0.3176
# Accuracy after query 67: 0.3105
# Accuracy after query 68: 0.3135
# Accuracy after query 69: 0.3189
# Accuracy after query 70: 0.3219
# Accuracy after query 71: 0.3138
# Accuracy after query 72: 0.3218
# Accuracy after query 73: 0.3286
# Accuracy after query 74: 0.3220
# Accuracy after query 75: 0.3195
# Accuracy after query 76: 0.3287
# Accuracy after query 77: 0.3248
# Accuracy after query 78: 0.3204
# Accuracy after query 79: 0.3192
# Accuracy after query 80: 0.3247
# Accuracy after query 81: 0.3162
# Accuracy after query 82: 0.3138
# Accuracy after query 83: 0.3214
# Accuracy after query 84: 0.3229
# Accuracy after query 85: 0.3170
# Accuracy after query 86: 0.3237
# Accuracy after query 87: 0.3311
# Accuracy after query 88: 0.3232
# Accuracy after query 89: 0.3212
# Accuracy after query 90: 0.3225
# Accuracy after query 91: 0.3213
# Accuracy after query 92: 0.3244
# Accuracy after query 93: 0.3234
# Accuracy after query 94: 0.3251
# Accuracy after query 95: 0.3266
# Accuracy after query 96: 0.3233
# Accuracy after query 97: 0.3299
# Accuracy after query 98: 0.3227
# Accuracy after query 1: 0.2065
# Accuracy after query 2: 0.1992
# Accuracy after query 3: 0.2133
# Accuracy after query 4: 0.2211
# Accuracy after query 5: 0.2328
# Accuracy after query 6: 0.2386
# Accuracy after query 7: 0.2416
# Accuracy after query 8: 0.2463
# Accuracy after query 9: 0.2500
# Accuracy after query 10: 0.2546
# Accuracy after query 11: 0.2510
# Accuracy after query 12: 0.2509
# Accuracy after query 13: 0.2635
# Accuracy after query 14: 0.2602
# Accuracy after query 15: 0.2649
# Accuracy after query 16: 0.2629
# Accuracy after query 17: 0.2654
# Accuracy after query 18: 0.2648
# Accuracy after query 19: 0.2678
# Accuracy after query 20: 0.2580
# Accuracy after query 21: 0.2631
# Accuracy after query 22: 0.2640
# Accuracy after query 23: 0.2632
# Accuracy after query 24: 0.2707
# Accuracy after query 25: 0.2783
# Accuracy after query 26: 0.2655
# Accuracy after query 27: 0.2682
# Accuracy after query 28: 0.2661
# Accuracy after query 29: 0.2781
# Accuracy after query 30: 0.2688
# Accuracy after query 31: 0.2722
# Accuracy after query 32: 0.2793
# Accuracy after query 33: 0.2781
# Accuracy after query 34: 0.2816
# Accuracy after query 35: 0.2820
# Accuracy after query 36: 0.2829
# Accuracy after query 37: 0.2828
# Accuracy after query 38: 0.2837
# Accuracy after query 39: 0.2842
# Accuracy after query 40: 0.2893
# Accuracy after query 41: 0.2834
# Accuracy after query 42: 0.2930
# Accuracy after query 43: 0.2894
# Accuracy after query 44: 0.2915
# Accuracy after query 45: 0.2939
# Accuracy after query 46: 0.3023
# Accuracy after query 47: 0.3067
# Accuracy after query 48: 0.2928
# Accuracy after query 49: 0.3041
# Accuracy after query 50: 0.3034
# Accuracy after query 51: 0.2957
# Accuracy after query 52: 0.3035
# Accuracy after query 53: 0.3051
# Accuracy after query 54: 0.3041
# Accuracy after query 55: 0.3188
# Accuracy after query 56: 0.3047
# Accuracy after query 57: 0.3136
# Accuracy after query 58: 0.3107
# Accuracy after query 59: 0.3116
# Accuracy after query 60: 0.3086
# Accuracy after query 61: 0.3084
# Accuracy after query 62: 0.3107
# Accuracy after query 63: 0.3150
# Accuracy after query 64: 0.3173
# Accuracy after query 65: 0.3205
# Accuracy after query 66: 0.3112
# Accuracy after query 67: 0.3205
# Accuracy after query 68: 0.3173
# Accuracy after query 69: 0.3183
# Accuracy after query 70: 0.3145
# Accuracy after query 71: 0.3092
# Accuracy after query 72: 0.3218
# Accuracy after query 73: 0.3233
# Accuracy after query 74: 0.3189
# Accuracy after query 75: 0.3184
# Accuracy after query 76: 0.3184
# Accuracy after query 77: 0.3158
# Accuracy after query 78: 0.3189
# Accuracy after query 79: 0.3252
# Accuracy after query 80: 0.3241
# Accuracy after query 81: 0.3240
# Accuracy after query 82: 0.3314
# Accuracy after query 83: 0.3311
# Accuracy after query 84: 0.3284
# Accuracy after query 85: 0.3293
# Accuracy after query 86: 0.3275
# Accuracy after query 87: 0.3327
# Accuracy after query 88: 0.3321
# Accuracy after query 89: 0.3250
# Accuracy after query 90: 0.3271
# Accuracy after query 91: 0.3343
# Accuracy after query 92: 0.3292
# Accuracy after query 93: 0.3323
# Accuracy after query 94: 0.3309
# Accuracy after query 95: 0.3331
# Accuracy after query 96: 0.3319
# Accuracy after query 97: 0.3332
# Accuracy after query 98: 0.3302
# Accuracy after query 1: 0.1935
# Accuracy after query 2: 0.1946
# Accuracy after query 3: 0.2020
# Accuracy after query 4: 0.2257
# Accuracy after query 5: 0.2198
# Accuracy after query 6: 0.2098
# Accuracy after query 7: 0.2216
# Accuracy after query 8: 0.2306
# Accuracy after query 9: 0.2264
# Accuracy after query 10: 0.2404
# Accuracy after query 11: 0.2240
# Accuracy after query 12: 0.2238
# Accuracy after query 13: 0.2362
# Accuracy after query 14: 0.2397
# Accuracy after query 15: 0.2409
# Accuracy after query 16: 0.2368
# Accuracy after query 17: 0.2391
# Accuracy after query 18: 0.2318
# Accuracy after query 19: 0.2441
# Accuracy after query 20: 0.2299
# Accuracy after query 21: 0.2499
# Accuracy after query 22: 0.2486
# Accuracy after query 23: 0.2520
# Accuracy after query 24: 0.2582
# Accuracy after query 25: 0.2619
# Accuracy after query 26: 0.2646
# Accuracy after query 27: 0.2671
# Accuracy after query 28: 0.2731
# Accuracy after query 29: 0.2702
# Accuracy after query 30: 0.2722
# Accuracy after query 31: 0.2817
# Accuracy after query 32: 0.2748
# Accuracy after query 33: 0.2761
# Accuracy after query 34: 0.2718
# Accuracy after query 35: 0.2828
# Accuracy after query 36: 0.2774
# Accuracy after query 37: 0.2810
# Accuracy after query 38: 0.2874
# Accuracy after query 39: 0.2868
# Accuracy after query 40: 0.2913
# Accuracy after query 41: 0.2856
# Accuracy after query 42: 0.2875
# Accuracy after query 43: 0.2872
# Accuracy after query 44: 0.2933
# Accuracy after query 45: 0.2878
# Accuracy after query 46: 0.2904
# Accuracy after query 47: 0.2927
# Accuracy after query 48: 0.2930
# Accuracy after query 49: 0.2937
# Accuracy after query 50: 0.3031
# Accuracy after query 51: 0.3003
# Accuracy after query 52: 0.3106
# Accuracy after query 53: 0.3125
# Accuracy after query 54: 0.3091
# Accuracy after query 55: 0.3156
# Accuracy after query 56: 0.3158
# Accuracy after query 57: 0.3165
# Accuracy after query 58: 0.3168
# Accuracy after query 59: 0.3127
# Accuracy after query 60: 0.3039
# Accuracy after query 61: 0.3070
# Accuracy after query 62: 0.3110
# Accuracy after query 63: 0.3199
# Accuracy after query 64: 0.3209
# Accuracy after query 65: 0.3105
# Accuracy after query 66: 0.3114
# Accuracy after query 67: 0.3029
# Accuracy after query 68: 0.3019
# Accuracy after query 69: 0.3075
# Accuracy after query 70: 0.3096
# Accuracy after query 71: 0.3037
# Accuracy after query 72: 0.3004
# Accuracy after query 73: 0.3027
# Accuracy after query 74: 0.3026
# Accuracy after query 75: 0.3109
# Accuracy after query 76: 0.3087
# Accuracy after query 77: 0.3097
# Accuracy after query 78: 0.3096
# Accuracy after query 79: 0.3117
# Accuracy after query 80: 0.2902
# Accuracy after query 81: 0.2953
# Accuracy after query 82: 0.3059
# Accuracy after query 83: 0.2975
# Accuracy after query 84: 0.3049
# Accuracy after query 85: 0.2992
# Accuracy after query 86: 0.3059
# Accuracy after query 87: 0.2965
# Accuracy after query 88: 0.3137
# Accuracy after query 89: 0.3129
# Accuracy after query 90: 0.2919
# Accuracy after query 91: 0.3112
# Accuracy after query 92: 0.3196
# Accuracy after query 93: 0.3202
# Accuracy after query 94: 0.3165
# Accuracy after query 95: 0.3187
# Accuracy after query 96: 0.3194
# Accuracy after query 97: 0.3221
# Accuracy after query 98: 0.3299
# Accuracy after query 1: 0.2018
# Accuracy after query 2: 0.1978
# Accuracy after query 3: 0.2252
# Accuracy after query 4: 0.2217
# Accuracy after query 5: 0.2145
# Accuracy after query 6: 0.2277
# Accuracy after query 7: 0.2250
# Accuracy after query 8: 0.2291
# Accuracy after query 9: 0.2309
# Accuracy after query 10: 0.2313
# Accuracy after query 11: 0.2366
# Accuracy after query 12: 0.2414
# Accuracy after query 13: 0.2424
# Accuracy after query 14: 0.2421
# Accuracy after query 15: 0.2399
# Accuracy after query 16: 0.2373
# Accuracy after query 17: 0.2458
# Accuracy after query 18: 0.2434
# Accuracy after query 19: 0.2436
# Accuracy after query 20: 0.2419
# Accuracy after query 21: 0.2484
# Accuracy after query 22: 0.2405
# Accuracy after query 23: 0.2508
# Accuracy after query 24: 0.2503
# Accuracy after query 25: 0.2546
# Accuracy after query 26: 0.2566
# Accuracy after query 27: 0.2572
# Accuracy after query 28: 0.2601
# Accuracy after query 29: 0.2562
# Accuracy after query 30: 0.2648
# Accuracy after query 31: 0.2657
# Accuracy after query 32: 0.2585
# Accuracy after query 33: 0.2675
# Accuracy after query 34: 0.2671
# Accuracy after query 35: 0.2652
# Accuracy after query 36: 0.2712
# Accuracy after query 37: 0.2738
# Accuracy after query 38: 0.2683
# Accuracy after query 39: 0.2768
# Accuracy after query 40: 0.2707
# Accuracy after query 41: 0.2812
# Accuracy after query 42: 0.2808
# Accuracy after query 43: 0.2779
# Accuracy after query 44: 0.2864
# Accuracy after query 45: 0.2806
# Accuracy after query 46: 0.2871
# Accuracy after query 47: 0.2760
# Accuracy after query 48: 0.2819
# Accuracy after query 49: 0.2982
# Accuracy after query 50: 0.2948
# Accuracy after query 51: 0.2912
# Accuracy after query 52: 0.3041
# Accuracy after query 53: 0.2954
# Accuracy after query 54: 0.2981
# Accuracy after query 55: 0.2986
# Accuracy after query 56: 0.2933
# Accuracy after query 57: 0.2978
# Accuracy after query 58: 0.3015
# Accuracy after query 59: 0.2904
# Accuracy after query 60: 0.2929
# Accuracy after query 61: 0.3037
# Accuracy after query 62: 0.2980
# Accuracy after query 63: 0.2880
# Accuracy after query 64: 0.3024
# Accuracy after query 65: 0.3021
# Accuracy after query 66: 0.2973
# Accuracy after query 67: 0.2945
# Accuracy after query 68: 0.2999
# Accuracy after query 69: 0.3051
# Accuracy after query 70: 0.3057
# Accuracy after query 71: 0.3084
# Accuracy after query 72: 0.3120
# Accuracy after query 73: 0.3003
# Accuracy after query 74: 0.3058
# Accuracy after query 75: 0.3093
# Accuracy after query 76: 0.3034
# Accuracy after query 77: 0.3065
# Accuracy after query 78: 0.3024
# Accuracy after query 79: 0.3040
# Accuracy after query 80: 0.3123
# Accuracy after query 81: 0.3081
# Accuracy after query 82: 0.3075
# Accuracy after query 83: 0.3144
# Accuracy after query 84: 0.3078
# Accuracy after query 85: 0.3133
# Accuracy after query 86: 0.3091
# Accuracy after query 87: 0.3110
# Accuracy after query 88: 0.3076
# Accuracy after query 89: 0.3048
# Accuracy after query 90: 0.3111
# Accuracy after query 91: 0.3116
# Accuracy after query 92: 0.3093
# Accuracy after query 93: 0.3042
# Accuracy after query 94: 0.3190
# Accuracy after query 95: 0.3207
# Accuracy after query 96: 0.3177
# Accuracy after query 97: 0.3156
# Accuracy after query 98: 0.3193
# Accuracy after query 1: 0.2114
# Accuracy after query 2: 0.2027
# Accuracy after query 3: 0.1994
# Accuracy after query 4: 0.2042
# Accuracy after query 5: 0.2117
# Accuracy after query 6: 0.2211
# Accuracy after query 7: 0.2171
# Accuracy after query 8: 0.2257
# Accuracy after query 9: 0.2365
# Accuracy after query 10: 0.2513
# Accuracy after query 11: 0.2487
# Accuracy after query 12: 0.2521
# Accuracy after query 13: 0.2475
# Accuracy after query 14: 0.2549
# Accuracy after query 15: 0.2420
# Accuracy after query 16: 0.2529
# Accuracy after query 17: 0.2383
# Accuracy after query 18: 0.2409
# Accuracy after query 19: 0.2514
# Accuracy after query 20: 0.2474
# Accuracy after query 21: 0.2535
# Accuracy after query 22: 0.2544
# Accuracy after query 23: 0.2518
# Accuracy after query 24: 0.2541
# Accuracy after query 25: 0.2508
# Accuracy after query 26: 0.2585
# Accuracy after query 27: 0.2483
# Accuracy after query 28: 0.2618
# Accuracy after query 29: 0.2469
# Accuracy after query 30: 0.2542
# Accuracy after query 31: 0.2609
# Accuracy after query 32: 0.2557
# Accuracy after query 33: 0.2701
# Accuracy after query 34: 0.2609
# Accuracy after query 35: 0.2727
# Accuracy after query 36: 0.2634
# Accuracy after query 37: 0.2725
# Accuracy after query 38: 0.2737
# Accuracy after query 39: 0.2812
# Accuracy after query 40: 0.2827
# Accuracy after query 41: 0.2944
# Accuracy after query 42: 0.2776
# Accuracy after query 43: 0.2860
# Accuracy after query 44: 0.2966
# Accuracy after query 45: 0.2931
# Accuracy after query 46: 0.2948
# Accuracy after query 47: 0.2942
# Accuracy after query 48: 0.2978
# Accuracy after query 49: 0.3000
# Accuracy after query 50: 0.3057
# Accuracy after query 51: 0.2940
# Accuracy after query 52: 0.2988
# Accuracy after query 53: 0.2946
# Accuracy after query 54: 0.3106
# Accuracy after query 55: 0.3008
# Accuracy after query 56: 0.3024
# Accuracy after query 57: 0.3106
# Accuracy after query 58: 0.3125
# Accuracy after query 59: 0.3064
# Accuracy after query 60: 0.3087
# Accuracy after query 61: 0.3103
# Accuracy after query 62: 0.3035
# Accuracy after query 63: 0.3104
# Accuracy after query 64: 0.3062
# Accuracy after query 65: 0.3087
# Accuracy after query 66: 0.3141
# Accuracy after query 67: 0.3115
# Accuracy after query 68: 0.3098
# Accuracy after query 69: 0.3110
# Accuracy after query 70: 0.3130
# Accuracy after query 71: 0.3098
# Accuracy after query 72: 0.3138
# Accuracy after query 73: 0.3176
# Accuracy after query 74: 0.3081
# Accuracy after query 75: 0.3135
# Accuracy after query 76: 0.3161
# Accuracy after query 77: 0.3187
# Accuracy after query 78: 0.3161
# Accuracy after query 79: 0.3152
# Accuracy after query 80: 0.3164
# Accuracy after query 81: 0.3243
# Accuracy after query 82: 0.3154
# Accuracy after query 83: 0.3127
# Accuracy after query 84: 0.3174
# Accuracy after query 85: 0.3097
# Accuracy after query 86: 0.3066
# Accuracy after query 87: 0.3178
# Accuracy after query 88: 0.3203
# Accuracy after query 89: 0.3176
# Accuracy after query 90: 0.3179
# Accuracy after query 91: 0.3120
# Accuracy after query 92: 0.3189
# Accuracy after query 93: 0.3109
# Accuracy after query 94: 0.3158
# Accuracy after query 95: 0.3225
# Accuracy after query 96: 0.2981
# Accuracy after query 97: 0.3046
# Accuracy after query 98: 0.3052
# Accuracy after query 1: 0.2155
# Accuracy after query 2: 0.2111
# Accuracy after query 3: 0.2217
# Accuracy after query 4: 0.2163
# Accuracy after query 5: 0.2222
# Accuracy after query 6: 0.2246
# Accuracy after query 7: 0.2262
# Accuracy after query 8: 0.2303
# Accuracy after query 9: 0.2205
# Accuracy after query 10: 0.2297
# Accuracy after query 11: 0.2308
# Accuracy after query 12: 0.2410
# Accuracy after query 13: 0.2421
# Accuracy after query 14: 0.2481
# Accuracy after query 15: 0.2596
# Accuracy after query 16: 0.2560
# Accuracy after query 17: 0.2551
# Accuracy after query 18: 0.2606
# Accuracy after query 19: 0.2553
# Accuracy after query 20: 0.2595
# Accuracy after query 21: 0.2453
# Accuracy after query 22: 0.2533
# Accuracy after query 23: 0.2503
# Accuracy after query 24: 0.2501
# Accuracy after query 25: 0.2503
# Accuracy after query 26: 0.2640
# Accuracy after query 27: 0.2608
# Accuracy after query 28: 0.2631
# Accuracy after query 29: 0.2652
# Accuracy after query 30: 0.2669
# Accuracy after query 31: 0.2720
# Accuracy after query 32: 0.2763
# Accuracy after query 33: 0.2708
# Accuracy after query 34: 0.2758
# Accuracy after query 35: 0.2700
# Accuracy after query 36: 0.2819
# Accuracy after query 37: 0.2913
# Accuracy after query 38: 0.2949
# Accuracy after query 39: 0.2955
# Accuracy after query 40: 0.2812
# Accuracy after query 41: 0.2865
# Accuracy after query 42: 0.2922
# Accuracy after query 43: 0.2999
# Accuracy after query 44: 0.2942
# Accuracy after query 45: 0.2914
# Accuracy after query 46: 0.2855
# Accuracy after query 47: 0.2942
# Accuracy after query 48: 0.3000
# Accuracy after query 49: 0.3009
# Accuracy after query 50: 0.3036
# Accuracy after query 51: 0.3056
# Accuracy after query 52: 0.3041
# Accuracy after query 53: 0.3016
# Accuracy after query 54: 0.3074
# Accuracy after query 55: 0.3095
# Accuracy after query 56: 0.3112
# Accuracy after query 57: 0.3067
# Accuracy after query 58: 0.3092
# Accuracy after query 59: 0.3069
# Accuracy after query 60: 0.3104
# Accuracy after query 61: 0.3032
# Accuracy after query 62: 0.3111
# Accuracy after query 63: 0.3206
# Accuracy after query 64: 0.3159
# Accuracy after query 65: 0.3080
# Accuracy after query 66: 0.3156
# Accuracy after query 67: 0.3247
# Accuracy after query 68: 0.3197
# Accuracy after query 69: 0.3170
# Accuracy after query 70: 0.3107
# Accuracy after query 71: 0.3130
# Accuracy after query 72: 0.3178
# Accuracy after query 73: 0.3152
# Accuracy after query 74: 0.3149
# Accuracy after query 75: 0.3176
# Accuracy after query 76: 0.3174
# Accuracy after query 77: 0.3217
# Accuracy after query 78: 0.3148
# Accuracy after query 79: 0.2964
# Accuracy after query 80: 0.3099
# Accuracy after query 81: 0.3077
# Accuracy after query 82: 0.3134
# Accuracy after query 83: 0.3148
# Accuracy after query 84: 0.3214
# Accuracy after query 85: 0.3081
# Accuracy after query 86: 0.3100
# Accuracy after query 87: 0.3227
# Accuracy after query 88: 0.3209
# Accuracy after query 89: 0.3223
# Accuracy after query 90: 0.3233
# Accuracy after query 91: 0.3283
# Accuracy after query 92: 0.3277
# Accuracy after query 93: 0.3151
# Accuracy after query 94: 0.3177
# Accuracy after query 95: 0.3199
# Accuracy after query 96: 0.3159
# Accuracy after query 97: 0.3061
# Accuracy after query 98: 0.3140
# Accuracy after query 1: 0.1769
# Accuracy after query 2: 0.1716
# Accuracy after query 3: 0.1951
# Accuracy after query 4: 0.1964
# Accuracy after query 5: 0.2010
# Accuracy after query 6: 0.2156
# Accuracy after query 7: 0.2156
# Accuracy after query 8: 0.2129
# Accuracy after query 9: 0.2207
# Accuracy after query 10: 0.2288
# Accuracy after query 11: 0.2283
# Accuracy after query 12: 0.2318
# Accuracy after query 13: 0.2361
# Accuracy after query 14: 0.2357
# Accuracy after query 15: 0.2405
# Accuracy after query 16: 0.2347
# Accuracy after query 17: 0.2362
# Accuracy after query 18: 0.2313
# Accuracy after query 19: 0.2463
# Accuracy after query 20: 0.2451
# Accuracy after query 21: 0.2491
# Accuracy after query 22: 0.2526
# Accuracy after query 23: 0.2519
# Accuracy after query 24: 0.2543
# Accuracy after query 25: 0.2614
# Accuracy after query 26: 0.2588
# Accuracy after query 27: 0.2645
# Accuracy after query 28: 0.2667
# Accuracy after query 29: 0.2704
# Accuracy after query 30: 0.2763
# Accuracy after query 31: 0.2735
# Accuracy after query 32: 0.2706
# Accuracy after query 33: 0.2679
# Accuracy after query 34: 0.2687
# Accuracy after query 35: 0.2776
# Accuracy after query 36: 0.2705
# Accuracy after query 37: 0.2748
# Accuracy after query 38: 0.2864
# Accuracy after query 39: 0.2891
# Accuracy after query 40: 0.2788
# Accuracy after query 41: 0.2787
# Accuracy after query 42: 0.2837
# Accuracy after query 43: 0.2802
# Accuracy after query 44: 0.2857
# Accuracy after query 45: 0.2940
# Accuracy after query 46: 0.2961
# Accuracy after query 47: 0.2856
# Accuracy after query 48: 0.2855
# Accuracy after query 49: 0.2947
# Accuracy after query 50: 0.2897
# Accuracy after query 51: 0.2936
# Accuracy after query 52: 0.2967
# Accuracy after query 53: 0.3101
# Accuracy after query 54: 0.3070
# Accuracy after query 55: 0.2962
# Accuracy after query 56: 0.3014
# Accuracy after query 57: 0.3017
# Accuracy after query 58: 0.3130
# Accuracy after query 59: 0.3114
# Accuracy after query 60: 0.3110
# Accuracy after query 61: 0.3117
# Accuracy after query 62: 0.3131
# Accuracy after query 63: 0.3098
# Accuracy after query 64: 0.3148
# Accuracy after query 65: 0.3121
# Accuracy after query 66: 0.3155
# Accuracy after query 67: 0.3175
# Accuracy after query 68: 0.3134
# Accuracy after query 69: 0.3211
# Accuracy after query 70: 0.3242
# Accuracy after query 71: 0.3222
# Accuracy after query 72: 0.3199
# Accuracy after query 73: 0.3231
# Accuracy after query 74: 0.3245
# Accuracy after query 75: 0.3347
# Accuracy after query 76: 0.3295
# Accuracy after query 77: 0.3273
# Accuracy after query 78: 0.3350
# Accuracy after query 79: 0.3291
# Accuracy after query 80: 0.3409
# Accuracy after query 81: 0.3385
# Accuracy after query 82: 0.3374
# Accuracy after query 83: 0.3288
# Accuracy after query 84: 0.3346
# Accuracy after query 85: 0.3393
# Accuracy after query 86: 0.3356
# Accuracy after query 87: 0.3301
# Accuracy after query 88: 0.3327
# Accuracy after query 89: 0.3358
# Accuracy after query 90: 0.3311
# Accuracy after query 91: 0.3301
# Accuracy after query 92: 0.3279
# Accuracy after query 93: 0.3328
# Accuracy after query 94: 0.3273
# Accuracy after query 95: 0.3350
# Accuracy after query 96: 0.3207
# Accuracy after query 97: 0.3241
# Accuracy after query 98: 0.3356
# Accuracy after query 1: 0.1864
# Accuracy after query 2: 0.1854
# Accuracy after query 3: 0.1868
# Accuracy after query 4: 0.2076
# Accuracy after query 5: 0.2196
# Accuracy after query 6: 0.2200
# Accuracy after query 7: 0.2271
# Accuracy after query 8: 0.2234
# Accuracy after query 9: 0.2244
# Accuracy after query 10: 0.2395
# Accuracy after query 11: 0.2466
# Accuracy after query 12: 0.2479
# Accuracy after query 13: 0.2478
# Accuracy after query 14: 0.2502
# Accuracy after query 15: 0.2525
# Accuracy after query 16: 0.2568
# Accuracy after query 17: 0.2525
# Accuracy after query 18: 0.2487
# Accuracy after query 19: 0.2509
# Accuracy after query 20: 0.2600
# Accuracy after query 21: 0.2661
# Accuracy after query 22: 0.2629
# Accuracy after query 23: 0.2689
# Accuracy after query 24: 0.2731
# Accuracy after query 25: 0.2677
# Accuracy after query 26: 0.2686
# Accuracy after query 27: 0.2674
# Accuracy after query 28: 0.2732
# Accuracy after query 29: 0.2680
# Accuracy after query 30: 0.2755
# Accuracy after query 31: 0.2770
# Accuracy after query 32: 0.2854
# Accuracy after query 33: 0.2877
# Accuracy after query 34: 0.2857
# Accuracy after query 35: 0.2826
# Accuracy after query 36: 0.2746
# Accuracy after query 37: 0.2811
# Accuracy after query 38: 0.2815
# Accuracy after query 39: 0.2860
# Accuracy after query 40: 0.2908
# Accuracy after query 41: 0.2958
# Accuracy after query 42: 0.3043
# Accuracy after query 43: 0.2884
# Accuracy after query 44: 0.3008
# Accuracy after query 45: 0.2969
# Accuracy after query 46: 0.3081
# Accuracy after query 47: 0.3066
# Accuracy after query 48: 0.3100
# Accuracy after query 49: 0.3004
# Accuracy after query 50: 0.3013
# Accuracy after query 51: 0.2977
# Accuracy after query 52: 0.3045
# Accuracy after query 53: 0.3066
# Accuracy after query 54: 0.3063
# Accuracy after query 55: 0.3123
# Accuracy after query 56: 0.3038
# Accuracy after query 57: 0.3144
# Accuracy after query 58: 0.3094
# Accuracy after query 59: 0.3108
# Accuracy after query 60: 0.3180
# Accuracy after query 61: 0.3121
# Accuracy after query 62: 0.3142
# Accuracy after query 63: 0.3105
# Accuracy after query 64: 0.3149
# Accuracy after query 65: 0.3053
# Accuracy after query 66: 0.3126
# Accuracy after query 67: 0.3145
# Accuracy after query 68: 0.3128
# Accuracy after query 69: 0.3185
# Accuracy after query 70: 0.3180
# Accuracy after query 71: 0.3160
# Accuracy after query 72: 0.3086
# Accuracy after query 73: 0.3180
# Accuracy after query 74: 0.3193
# Accuracy after query 75: 0.3231
# Accuracy after query 76: 0.3179
# Accuracy after query 77: 0.3113
# Accuracy after query 78: 0.3106
# Accuracy after query 79: 0.3159
# Accuracy after query 80: 0.3081
# Accuracy after query 81: 0.3064
# Accuracy after query 82: 0.3169
# Accuracy after query 83: 0.3188
# Accuracy after query 84: 0.3086
# Accuracy after query 85: 0.3001
# Accuracy after query 86: 0.3070
# Accuracy after query 87: 0.2997
# Accuracy after query 88: 0.3044
# Accuracy after query 89: 0.2939
# Accuracy after query 90: 0.3000
# Accuracy after query 91: 0.2947
# Accuracy after query 92: 0.3057
# Accuracy after query 93: 0.3052
# Accuracy after query 94: 0.3019
# Accuracy after query 95: 0.2971
# Accuracy after query 96: 0.2902
# Accuracy after query 97: 0.2921
# Accuracy after query 98: 0.3032
# Accuracy after query 1: 0.1608
# Accuracy after query 2: 0.1921
# Accuracy after query 3: 0.1837
# Accuracy after query 4: 0.1833
# Accuracy after query 5: 0.1917
# Accuracy after query 6: 0.1991
# Accuracy after query 7: 0.2165
# Accuracy after query 8: 0.2150
# Accuracy after query 9: 0.2146
# Accuracy after query 10: 0.2161
# Accuracy after query 11: 0.2182
# Accuracy after query 12: 0.2170
# Accuracy after query 13: 0.2217
# Accuracy after query 14: 0.2240
# Accuracy after query 15: 0.2309
# Accuracy after query 16: 0.2345
# Accuracy after query 17: 0.2350
# Accuracy after query 18: 0.2398
# Accuracy after query 19: 0.2290
# Accuracy after query 20: 0.2403
# Accuracy after query 21: 0.2403
# Accuracy after query 22: 0.2460
# Accuracy after query 23: 0.2412
# Accuracy after query 24: 0.2460
# Accuracy after query 25: 0.2496
# Accuracy after query 26: 0.2482
# Accuracy after query 27: 0.2437
# Accuracy after query 28: 0.2514
# Accuracy after query 29: 0.2487
# Accuracy after query 30: 0.2523
# Accuracy after query 31: 0.2583
# Accuracy after query 32: 0.2588
# Accuracy after query 33: 0.2733
# Accuracy after query 34: 0.2688
# Accuracy after query 35: 0.2703
# Accuracy after query 36: 0.2670
# Accuracy after query 37: 0.2722
# Accuracy after query 38: 0.2730
# Accuracy after query 39: 0.2686
# Accuracy after query 40: 0.2817
# Accuracy after query 41: 0.2785
# Accuracy after query 42: 0.2875
# Accuracy after query 43: 0.2851
# Accuracy after query 44: 0.2837
# Accuracy after query 45: 0.2903
# Accuracy after query 46: 0.2881
# Accuracy after query 47: 0.2812
# Accuracy after query 48: 0.2812
# Accuracy after query 49: 0.2892
# Accuracy after query 50: 0.2860
# Accuracy after query 51: 0.2917
# Accuracy after query 52: 0.2909
# Accuracy after query 53: 0.2869
# Accuracy after query 54: 0.3015
# Accuracy after query 55: 0.2945
# Accuracy after query 56: 0.2949
# Accuracy after query 57: 0.3022
# Accuracy after query 58: 0.2995
# Accuracy after query 59: 0.3015
# Accuracy after query 60: 0.3063
# Accuracy after query 61: 0.3058
# Accuracy after query 62: 0.3037
# Accuracy after query 63: 0.3020
# Accuracy after query 64: 0.3033
# Accuracy after query 65: 0.3017
# Accuracy after query 66: 0.3130
# Accuracy after query 67: 0.3104
# Accuracy after query 68: 0.3072
# Accuracy after query 69: 0.3091
# Accuracy after query 70: 0.3194
# Accuracy after query 71: 0.3089
# Accuracy after query 72: 0.3055
# Accuracy after query 73: 0.3136
# Accuracy after query 74: 0.3081
# Accuracy after query 75: 0.3048
# Accuracy after query 76: 0.3053
# Accuracy after query 77: 0.3136
# Accuracy after query 78: 0.3099
# Accuracy after query 79: 0.3150
# Accuracy after query 80: 0.3166
# Accuracy after query 81: 0.3183
# Accuracy after query 82: 0.3165
# Accuracy after query 83: 0.3076
# Accuracy after query 84: 0.3163
# Accuracy after query 85: 0.3200
# Accuracy after query 86: 0.3169
# Accuracy after query 87: 0.3191
# Accuracy after query 88: 0.3224
# Accuracy after query 89: 0.3192
# Accuracy after query 90: 0.3217
# Accuracy after query 91: 0.3269
# Accuracy after query 92: 0.3310
# Accuracy after query 93: 0.3307
# Accuracy after query 94: 0.3245
# Accuracy after query 95: 0.3275
# Accuracy after query 96: 0.3297
# Accuracy after query 97: 0.3287
# Accuracy after query 98: 0.3266
# Accuracy after query 1: 0.1853
# Accuracy after query 2: 0.1785
# Accuracy after query 3: 0.1972
# Accuracy after query 4: 0.1995
# Accuracy after query 5: 0.2035
# Accuracy after query 6: 0.2068
# Accuracy after query 7: 0.2128
# Accuracy after query 8: 0.2211
# Accuracy after query 9: 0.2363
# Accuracy after query 10: 0.2347
# Accuracy after query 11: 0.2252
# Accuracy after query 12: 0.2310
# Accuracy after query 13: 0.2335
# Accuracy after query 14: 0.2364
# Accuracy after query 15: 0.2324
# Accuracy after query 16: 0.2276
# Accuracy after query 17: 0.2397
# Accuracy after query 18: 0.2470
# Accuracy after query 19: 0.2456
# Accuracy after query 20: 0.2425
# Accuracy after query 21: 0.2489
# Accuracy after query 22: 0.2564
# Accuracy after query 23: 0.2676
# Accuracy after query 24: 0.2685
# Accuracy after query 25: 0.2683
# Accuracy after query 26: 0.2767
# Accuracy after query 27: 0.2685
# Accuracy after query 28: 0.2682
# Accuracy after query 29: 0.2509
# Accuracy after query 30: 0.2612
# Accuracy after query 31: 0.2600
# Accuracy after query 32: 0.2645
# Accuracy after query 33: 0.2736
# Accuracy after query 34: 0.2746
# Accuracy after query 35: 0.2757
# Accuracy after query 36: 0.2734
# Accuracy after query 37: 0.2725
# Accuracy after query 38: 0.2743
# Accuracy after query 39: 0.2720
# Accuracy after query 40: 0.2880
# Accuracy after query 41: 0.2831
# Accuracy after query 42: 0.2854
# Accuracy after query 43: 0.2821
# Accuracy after query 44: 0.2835
# Accuracy after query 45: 0.2821
# Accuracy after query 46: 0.2814
# Accuracy after query 47: 0.2859
# Accuracy after query 48: 0.2871
# Accuracy after query 49: 0.2782
# Accuracy after query 50: 0.2872
# Accuracy after query 51: 0.2820
# Accuracy after query 52: 0.2939
# Accuracy after query 53: 0.2979
# Accuracy after query 54: 0.2930
# Accuracy after query 55: 0.2875
# Accuracy after query 56: 0.2975
# Accuracy after query 57: 0.2930
# Accuracy after query 58: 0.2996
# Accuracy after query 59: 0.3027
# Accuracy after query 60: 0.2966
# Accuracy after query 61: 0.2886
# Accuracy after query 62: 0.2945
# Accuracy after query 63: 0.2963
# Accuracy after query 64: 0.2897
# Accuracy after query 65: 0.2989
# Accuracy after query 66: 0.2910
# Accuracy after query 67: 0.2928
# Accuracy after query 68: 0.2986
# Accuracy after query 69: 0.3016
# Accuracy after query 70: 0.2961
# Accuracy after query 71: 0.2916
# Accuracy after query 72: 0.2994
# Accuracy after query 73: 0.3041
# Accuracy after query 74: 0.2998
# Accuracy after query 75: 0.2995
# Accuracy after query 76: 0.2896
# Accuracy after query 77: 0.2979
# Accuracy after query 78: 0.3086
# Accuracy after query 79: 0.3056
# Accuracy after query 80: 0.3005
# Accuracy after query 81: 0.3016
# Accuracy after query 82: 0.3025
# Accuracy after query 83: 0.2998
# Accuracy after query 84: 0.2794
# Accuracy after query 85: 0.3038
# Accuracy after query 86: 0.3050
# Accuracy after query 87: 0.3118
# Accuracy after query 88: 0.2956
# Accuracy after query 89: 0.2964
# Accuracy after query 90: 0.2929
# Accuracy after query 91: 0.3153
# Accuracy after query 92: 0.3234
# Accuracy after query 93: 0.3190
# Accuracy after query 94: 0.3188
# Accuracy after query 95: 0.3078
# Accuracy after query 96: 0.2929
# Accuracy after query 97: 0.2944
# Accuracy after query 98: 0.2924
# Accuracy after query 1: 0.1711
# Accuracy after query 2: 0.1893
# Accuracy after query 3: 0.1858
# Accuracy after query 4: 0.2036
# Accuracy after query 5: 0.2089
# Accuracy after query 6: 0.2109
# Accuracy after query 7: 0.2226
# Accuracy after query 8: 0.2065
# Accuracy after query 9: 0.2154
# Accuracy after query 10: 0.2292
# Accuracy after query 11: 0.2362
# Accuracy after query 12: 0.2300
# Accuracy after query 13: 0.2329
# Accuracy after query 14: 0.2405
# Accuracy after query 15: 0.2487
# Accuracy after query 16: 0.2420
# Accuracy after query 17: 0.2514
# Accuracy after query 18: 0.2472
# Accuracy after query 19: 0.2437
# Accuracy after query 20: 0.2495
# Accuracy after query 21: 0.2545
# Accuracy after query 22: 0.2389
# Accuracy after query 23: 0.2363
# Accuracy after query 24: 0.2477
# Accuracy after query 25: 0.2485
# Accuracy after query 26: 0.2600
# Accuracy after query 27: 0.2596
# Accuracy after query 28: 0.2585
# Accuracy after query 29: 0.2554
# Accuracy after query 30: 0.2708
# Accuracy after query 31: 0.2801
# Accuracy after query 32: 0.2824
# Accuracy after query 33: 0.2759
# Accuracy after query 34: 0.2806
# Accuracy after query 35: 0.2816
# Accuracy after query 36: 0.2904
# Accuracy after query 37: 0.2911
# Accuracy after query 38: 0.2841
# Accuracy after query 39: 0.2894
# Accuracy after query 40: 0.2898
# Accuracy after query 41: 0.2818
# Accuracy after query 42: 0.2890
# Accuracy after query 43: 0.2872
# Accuracy after query 44: 0.2853
# Accuracy after query 45: 0.2999
# Accuracy after query 46: 0.2942
# Accuracy after query 47: 0.2992
# Accuracy after query 48: 0.2992
# Accuracy after query 49: 0.3043
# Accuracy after query 50: 0.3040
# Accuracy after query 51: 0.3055
# Accuracy after query 52: 0.3072
# Accuracy after query 53: 0.3136
# Accuracy after query 54: 0.3041
# Accuracy after query 55: 0.3118
# Accuracy after query 56: 0.3087
# Accuracy after query 57: 0.3120
# Accuracy after query 58: 0.3131
# Accuracy after query 59: 0.3070
# Accuracy after query 60: 0.3059
# Accuracy after query 61: 0.3106
# Accuracy after query 62: 0.3147
# Accuracy after query 63: 0.3113
# Accuracy after query 64: 0.3153
# Accuracy after query 65: 0.3190
# Accuracy after query 66: 0.3143
# Accuracy after query 67: 0.3188
# Accuracy after query 68: 0.3177
# Accuracy after query 69: 0.3247
# Accuracy after query 70: 0.3141
# Accuracy after query 71: 0.3249
# Accuracy after query 72: 0.3208
# Accuracy after query 73: 0.3215
# Accuracy after query 74: 0.3296
# Accuracy after query 75: 0.3185
# Accuracy after query 76: 0.3278
# Accuracy after query 77: 0.3282
# Accuracy after query 78: 0.3301
# Accuracy after query 79: 0.3298
# Accuracy after query 80: 0.3256
# Accuracy after query 81: 0.3252
# Accuracy after query 82: 0.3290
# Accuracy after query 83: 0.3287
# Accuracy after query 84: 0.3253
# Accuracy after query 85: 0.3351
# Accuracy after query 86: 0.3316
# Accuracy after query 87: 0.3284
# Accuracy after query 88: 0.3354
# Accuracy after query 89: 0.3310
# Accuracy after query 90: 0.3308
# Accuracy after query 91: 0.3310
# Accuracy after query 92: 0.3388
# Accuracy after query 93: 0.3298
# Accuracy after query 94: 0.3321
# Accuracy after query 95: 0.3344
# Accuracy after query 96: 0.3362
# Accuracy after query 97: 0.3407
# Accuracy after query 98: 0.3365
