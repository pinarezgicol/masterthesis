# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import cifar10

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
LATENT_DIMS = [256]
latent_dim = 256
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\cifar10_bigan_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
#     "batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self, latent_dim):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = (X_train.astype(np.float32)) / 255.
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = (X_test.astype(np.float32)) / 255.
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
y_train = y_train.reshape((y_train.shape[0], ))
y_test = y_test.reshape((y_test.shape[0], ))

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_train_enhanced_bigan.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_test_enhanced_bigan.npy")

for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))

    for func_name, acquisition_func in ACQ_FUNCS.items():  

        X_initial = X_train_enhanced[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP_REG(latent_dim).to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test_enhanced,
                                                          y_test,
                                                          X_pool,
                                                          y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# Accuracy after query 1: 0.1768
# Accuracy after query 2: 0.1758
# Accuracy after query 3: 0.1793
# Accuracy after query 4: 0.1869
# Accuracy after query 5: 0.1883
# Accuracy after query 6: 0.1939
# Accuracy after query 7: 0.2046
# Accuracy after query 8: 0.2087
# Accuracy after query 9: 0.2123
# Accuracy after query 10: 0.2165
# Accuracy after query 11: 0.2141
# Accuracy after query 12: 0.2163
# Accuracy after query 13: 0.2186
# Accuracy after query 14: 0.2207
# Accuracy after query 15: 0.2216
# Accuracy after query 16: 0.2240
# Accuracy after query 17: 0.2334
# Accuracy after query 18: 0.2410
# Accuracy after query 19: 0.2398
# Accuracy after query 20: 0.2487
# Accuracy after query 21: 0.2473
# Accuracy after query 22: 0.2528
# Accuracy after query 23: 0.2576
# Accuracy after query 24: 0.2521
# Accuracy after query 25: 0.2518
# Accuracy after query 26: 0.2569
# Accuracy after query 27: 0.2561
# Accuracy after query 28: 0.2601
# Accuracy after query 29: 0.2548
# Accuracy after query 30: 0.2616
# Accuracy after query 31: 0.2718
# Accuracy after query 32: 0.2704
# Accuracy after query 33: 0.2717
# Accuracy after query 34: 0.2744
# Accuracy after query 35: 0.2795
# Accuracy after query 36: 0.2792
# Accuracy after query 37: 0.2784
# Accuracy after query 38: 0.2964
# Accuracy after query 39: 0.2824
# Accuracy after query 40: 0.2881
# Accuracy after query 41: 0.2974
# Accuracy after query 42: 0.2897
# Accuracy after query 43: 0.2836
# Accuracy after query 44: 0.2934
# Accuracy after query 45: 0.2939
# Accuracy after query 46: 0.2930
# Accuracy after query 47: 0.2977
# Accuracy after query 48: 0.2890
# Accuracy after query 49: 0.2965
# Accuracy after query 50: 0.2921
# Accuracy after query 51: 0.2966
# Accuracy after query 52: 0.2876
# Accuracy after query 53: 0.2979
# Accuracy after query 54: 0.2917
# Accuracy after query 55: 0.3004
# Accuracy after query 56: 0.3008
# Accuracy after query 57: 0.2997
# Accuracy after query 58: 0.2993
# Accuracy after query 59: 0.2930
# Accuracy after query 60: 0.3059
# Accuracy after query 61: 0.3026
# Accuracy after query 62: 0.3056
# Accuracy after query 63: 0.3051
# Accuracy after query 64: 0.3024
# Accuracy after query 65: 0.3094
# Accuracy after query 66: 0.3053
# Accuracy after query 67: 0.3095
# Accuracy after query 68: 0.3072
# Accuracy after query 69: 0.3073
# Accuracy after query 70: 0.3132
# Accuracy after query 71: 0.3140
# Accuracy after query 72: 0.3128
# Accuracy after query 73: 0.3105
# Accuracy after query 74: 0.3124
# Accuracy after query 75: 0.3104
# Accuracy after query 76: 0.3084
# Accuracy after query 77: 0.3094
# Accuracy after query 78: 0.3108
# Accuracy after query 79: 0.3122
# Accuracy after query 80: 0.3024
# Accuracy after query 81: 0.3096
# Accuracy after query 82: 0.3099
# Accuracy after query 83: 0.3130
# Accuracy after query 84: 0.3150
# Accuracy after query 85: 0.3136
# Accuracy after query 86: 0.3185
# Accuracy after query 87: 0.3148
# Accuracy after query 88: 0.3145
# Accuracy after query 89: 0.3111
# Accuracy after query 90: 0.3246
# Accuracy after query 91: 0.3153
# Accuracy after query 92: 0.3194
# Accuracy after query 93: 0.3102
# Accuracy after query 94: 0.3098
# Accuracy after query 95: 0.3158
# Accuracy after query 96: 0.3219
# Accuracy after query 97: 0.3135
# Accuracy after query 98: 0.3204
# Accuracy after query 1: 0.1664
# Accuracy after query 2: 0.1563
# Accuracy after query 3: 0.1676
# Accuracy after query 4: 0.1808
# Accuracy after query 5: 0.1926
# Accuracy after query 6: 0.2001
# Accuracy after query 7: 0.2027
# Accuracy after query 8: 0.2092
# Accuracy after query 9: 0.2150
# Accuracy after query 10: 0.2225
# Accuracy after query 11: 0.2174
# Accuracy after query 12: 0.2225
# Accuracy after query 13: 0.2302
# Accuracy after query 14: 0.2292
# Accuracy after query 15: 0.2318
# Accuracy after query 16: 0.2445
# Accuracy after query 17: 0.2472
# Accuracy after query 18: 0.2496
# Accuracy after query 19: 0.2614
# Accuracy after query 20: 0.2462
# Accuracy after query 21: 0.2634
# Accuracy after query 22: 0.2534
# Accuracy after query 23: 0.2640
# Accuracy after query 24: 0.2662
# Accuracy after query 25: 0.2595
# Accuracy after query 26: 0.2580
# Accuracy after query 27: 0.2628
# Accuracy after query 28: 0.2707
# Accuracy after query 29: 0.2763
# Accuracy after query 30: 0.2754
# Accuracy after query 31: 0.2768
# Accuracy after query 32: 0.2809
# Accuracy after query 33: 0.2830
# Accuracy after query 34: 0.2743
# Accuracy after query 35: 0.2804
# Accuracy after query 36: 0.2833
# Accuracy after query 37: 0.2798
# Accuracy after query 38: 0.2818
# Accuracy after query 39: 0.2781
# Accuracy after query 40: 0.2829
# Accuracy after query 41: 0.2807
# Accuracy after query 42: 0.2711
# Accuracy after query 43: 0.2770
# Accuracy after query 44: 0.2750
# Accuracy after query 45: 0.2840
# Accuracy after query 46: 0.2859
# Accuracy after query 47: 0.2803
# Accuracy after query 48: 0.2870
# Accuracy after query 49: 0.2961
# Accuracy after query 50: 0.2950
# Accuracy after query 51: 0.2860
# Accuracy after query 52: 0.2844
# Accuracy after query 53: 0.2944
# Accuracy after query 54: 0.2870
# Accuracy after query 55: 0.2977
# Accuracy after query 56: 0.2868
# Accuracy after query 57: 0.2918
# Accuracy after query 58: 0.2933
# Accuracy after query 59: 0.2902
# Accuracy after query 60: 0.2984
# Accuracy after query 61: 0.3008
# Accuracy after query 62: 0.3025
# Accuracy after query 63: 0.2929
# Accuracy after query 64: 0.2927
# Accuracy after query 65: 0.2964
# Accuracy after query 66: 0.2920
# Accuracy after query 67: 0.2911
# Accuracy after query 68: 0.3022
# Accuracy after query 69: 0.3049
# Accuracy after query 70: 0.3088
# Accuracy after query 71: 0.3151
# Accuracy after query 72: 0.3085
# Accuracy after query 73: 0.3042
# Accuracy after query 74: 0.3085
# Accuracy after query 75: 0.3097
# Accuracy after query 76: 0.3142
# Accuracy after query 77: 0.3198
# Accuracy after query 78: 0.3136
# Accuracy after query 79: 0.3201
# Accuracy after query 80: 0.3252
# Accuracy after query 81: 0.3257
# Accuracy after query 82: 0.3166
# Accuracy after query 83: 0.3229
# Accuracy after query 84: 0.3137
# Accuracy after query 85: 0.3196
# Accuracy after query 86: 0.3231
# Accuracy after query 87: 0.3179
# Accuracy after query 88: 0.3195
# Accuracy after query 89: 0.3257
# Accuracy after query 90: 0.3278
# Accuracy after query 91: 0.3328
# Accuracy after query 92: 0.3284
# Accuracy after query 93: 0.3223
# Accuracy after query 94: 0.3278
# Accuracy after query 95: 0.3248
# Accuracy after query 96: 0.3334
# Accuracy after query 97: 0.3299
# Accuracy after query 98: 0.3341
# Accuracy after query 1: 0.1646
# Accuracy after query 2: 0.1549
# Accuracy after query 3: 0.1588
# Accuracy after query 4: 0.1658
# Accuracy after query 5: 0.1713
# Accuracy after query 6: 0.1772
# Accuracy after query 7: 0.1818
# Accuracy after query 8: 0.1830
# Accuracy after query 9: 0.1896
# Accuracy after query 10: 0.1961
# Accuracy after query 11: 0.2003
# Accuracy after query 12: 0.2024
# Accuracy after query 13: 0.1985
# Accuracy after query 14: 0.2073
# Accuracy after query 15: 0.2205
# Accuracy after query 16: 0.2204
# Accuracy after query 17: 0.2285
# Accuracy after query 18: 0.2347
# Accuracy after query 19: 0.2320
# Accuracy after query 20: 0.2356
# Accuracy after query 21: 0.2413
# Accuracy after query 22: 0.2456
# Accuracy after query 23: 0.2419
# Accuracy after query 24: 0.2487
# Accuracy after query 25: 0.2594
# Accuracy after query 26: 0.2556
# Accuracy after query 27: 0.2607
# Accuracy after query 28: 0.2726
# Accuracy after query 29: 0.2716
# Accuracy after query 30: 0.2738
# Accuracy after query 31: 0.2698
# Accuracy after query 32: 0.2722
# Accuracy after query 33: 0.2717
# Accuracy after query 34: 0.2756
# Accuracy after query 35: 0.2734
# Accuracy after query 36: 0.2792
# Accuracy after query 37: 0.2803
# Accuracy after query 38: 0.2778
# Accuracy after query 39: 0.2767
# Accuracy after query 40: 0.2824
# Accuracy after query 41: 0.2791
# Accuracy after query 42: 0.2772
# Accuracy after query 43: 0.2785
# Accuracy after query 44: 0.2860
# Accuracy after query 45: 0.2799
# Accuracy after query 46: 0.2853
# Accuracy after query 47: 0.2923
# Accuracy after query 48: 0.2924
# Accuracy after query 49: 0.2916
# Accuracy after query 50: 0.2975
# Accuracy after query 51: 0.2950
# Accuracy after query 52: 0.2912
# Accuracy after query 53: 0.2929
# Accuracy after query 54: 0.2918
# Accuracy after query 55: 0.2997
# Accuracy after query 56: 0.2913
# Accuracy after query 57: 0.2907
# Accuracy after query 58: 0.2947
# Accuracy after query 59: 0.2939
# Accuracy after query 60: 0.2986
# Accuracy after query 61: 0.2914
# Accuracy after query 62: 0.2923
# Accuracy after query 63: 0.2908
# Accuracy after query 64: 0.3070
# Accuracy after query 65: 0.3025
# Accuracy after query 66: 0.3024
# Accuracy after query 67: 0.2978
# Accuracy after query 68: 0.3040
# Accuracy after query 69: 0.3021
# Accuracy after query 70: 0.3041
# Accuracy after query 71: 0.3050
# Accuracy after query 72: 0.3098
# Accuracy after query 73: 0.3133
# Accuracy after query 74: 0.3129
# Accuracy after query 75: 0.3013
# Accuracy after query 76: 0.3082
# Accuracy after query 77: 0.3100
# Accuracy after query 78: 0.3154
# Accuracy after query 79: 0.3114
# Accuracy after query 80: 0.3079
# Accuracy after query 81: 0.3127
# Accuracy after query 82: 0.3100
# Accuracy after query 83: 0.3150
# Accuracy after query 84: 0.3085
# Accuracy after query 85: 0.3117
# Accuracy after query 86: 0.3166
# Accuracy after query 87: 0.3141
# Accuracy after query 88: 0.3087
# Accuracy after query 89: 0.3144
# Accuracy after query 90: 0.3129
# Accuracy after query 91: 0.3143
# Accuracy after query 92: 0.3147
# Accuracy after query 93: 0.3213
# Accuracy after query 94: 0.3159
# Accuracy after query 95: 0.3174
# Accuracy after query 96: 0.3164
# Accuracy after query 97: 0.3170
# Accuracy after query 98: 0.3154
# Accuracy after query 1: 0.1635
# Accuracy after query 2: 0.1654
# Accuracy after query 3: 0.1822
# Accuracy after query 4: 0.1926
# Accuracy after query 5: 0.1896
# Accuracy after query 6: 0.2038
# Accuracy after query 7: 0.2043
# Accuracy after query 8: 0.2105
# Accuracy after query 9: 0.2134
# Accuracy after query 10: 0.2135
# Accuracy after query 11: 0.2177
# Accuracy after query 12: 0.2289
# Accuracy after query 13: 0.2396
# Accuracy after query 14: 0.2379
# Accuracy after query 15: 0.2430
# Accuracy after query 16: 0.2472
# Accuracy after query 17: 0.2525
# Accuracy after query 18: 0.2445
# Accuracy after query 19: 0.2461
# Accuracy after query 20: 0.2577
# Accuracy after query 21: 0.2500
# Accuracy after query 22: 0.2560
# Accuracy after query 23: 0.2607
# Accuracy after query 24: 0.2585
# Accuracy after query 25: 0.2689
# Accuracy after query 26: 0.2579
# Accuracy after query 27: 0.2655
# Accuracy after query 28: 0.2636
# Accuracy after query 29: 0.2674
# Accuracy after query 30: 0.2742
# Accuracy after query 31: 0.2779
# Accuracy after query 32: 0.2706
# Accuracy after query 33: 0.2815
# Accuracy after query 34: 0.2804
# Accuracy after query 35: 0.2826
# Accuracy after query 36: 0.2837
# Accuracy after query 37: 0.2852
# Accuracy after query 38: 0.2858
# Accuracy after query 39: 0.2829
# Accuracy after query 40: 0.2805
# Accuracy after query 41: 0.2832
# Accuracy after query 42: 0.2881
# Accuracy after query 43: 0.2825
# Accuracy after query 44: 0.2929
# Accuracy after query 45: 0.2878
# Accuracy after query 46: 0.2898
# Accuracy after query 47: 0.2905
# Accuracy after query 48: 0.2934
# Accuracy after query 49: 0.2976
# Accuracy after query 50: 0.3023
# Accuracy after query 51: 0.2986
# Accuracy after query 52: 0.3011
# Accuracy after query 53: 0.2997
# Accuracy after query 54: 0.3004
# Accuracy after query 55: 0.3000
# Accuracy after query 56: 0.3057
# Accuracy after query 57: 0.3072
# Accuracy after query 58: 0.3179
# Accuracy after query 59: 0.3066
# Accuracy after query 60: 0.3120
# Accuracy after query 61: 0.3049
# Accuracy after query 62: 0.3088
# Accuracy after query 63: 0.3119
# Accuracy after query 64: 0.3129
# Accuracy after query 65: 0.3170
# Accuracy after query 66: 0.3136
# Accuracy after query 67: 0.3196
# Accuracy after query 68: 0.3104
# Accuracy after query 69: 0.3142
# Accuracy after query 70: 0.3118
# Accuracy after query 71: 0.3117
# Accuracy after query 72: 0.3129
# Accuracy after query 73: 0.3195
# Accuracy after query 74: 0.3190
# Accuracy after query 75: 0.3234
# Accuracy after query 76: 0.3207
# Accuracy after query 77: 0.3242
# Accuracy after query 78: 0.3221
# Accuracy after query 79: 0.3158
# Accuracy after query 80: 0.3169
# Accuracy after query 81: 0.3184
# Accuracy after query 82: 0.3287
# Accuracy after query 83: 0.3198
# Accuracy after query 84: 0.3264
# Accuracy after query 85: 0.3257
# Accuracy after query 86: 0.3274
# Accuracy after query 87: 0.3268
# Accuracy after query 88: 0.3160
# Accuracy after query 89: 0.3193
# Accuracy after query 90: 0.3221
# Accuracy after query 91: 0.3231
# Accuracy after query 92: 0.3197
# Accuracy after query 93: 0.3152
# Accuracy after query 94: 0.3308
# Accuracy after query 95: 0.3274
# Accuracy after query 96: 0.3292
# Accuracy after query 97: 0.3279
# Accuracy after query 98: 0.3276
# Accuracy after query 1: 0.1847
# Accuracy after query 2: 0.1966
# Accuracy after query 3: 0.1884
# Accuracy after query 4: 0.1774
# Accuracy after query 5: 0.1835
# Accuracy after query 6: 0.1770
# Accuracy after query 7: 0.1888
# Accuracy after query 8: 0.2059
# Accuracy after query 9: 0.2038
# Accuracy after query 10: 0.2146
# Accuracy after query 11: 0.2217
# Accuracy after query 12: 0.2287
# Accuracy after query 13: 0.2408
# Accuracy after query 14: 0.2315
# Accuracy after query 15: 0.2434
# Accuracy after query 16: 0.2350
# Accuracy after query 17: 0.2480
# Accuracy after query 18: 0.2524
# Accuracy after query 19: 0.2509
# Accuracy after query 20: 0.2509
# Accuracy after query 21: 0.2600
# Accuracy after query 22: 0.2581
# Accuracy after query 23: 0.2682
# Accuracy after query 24: 0.2695
# Accuracy after query 25: 0.2779
# Accuracy after query 26: 0.2873
# Accuracy after query 27: 0.2819
# Accuracy after query 28: 0.2733
# Accuracy after query 29: 0.2698
# Accuracy after query 30: 0.2797
# Accuracy after query 31: 0.2742
# Accuracy after query 32: 0.2788
# Accuracy after query 33: 0.2842
# Accuracy after query 34: 0.2813
# Accuracy after query 35: 0.2837
# Accuracy after query 36: 0.2842
# Accuracy after query 37: 0.2906
# Accuracy after query 38: 0.2893
# Accuracy after query 39: 0.2853
# Accuracy after query 40: 0.2864
# Accuracy after query 41: 0.2886
# Accuracy after query 42: 0.2947
# Accuracy after query 43: 0.2982
# Accuracy after query 44: 0.2980
# Accuracy after query 45: 0.2942
# Accuracy after query 46: 0.2968
# Accuracy after query 47: 0.2985
# Accuracy after query 48: 0.3025
# Accuracy after query 49: 0.3080
# Accuracy after query 50: 0.3075
# Accuracy after query 51: 0.3061
# Accuracy after query 52: 0.2993
# Accuracy after query 53: 0.3108
# Accuracy after query 54: 0.3036
# Accuracy after query 55: 0.3089
# Accuracy after query 56: 0.3079
# Accuracy after query 57: 0.3088
# Accuracy after query 58: 0.3127
# Accuracy after query 59: 0.3086
# Accuracy after query 60: 0.3119
# Accuracy after query 61: 0.3108
# Accuracy after query 62: 0.3160
# Accuracy after query 63: 0.3162
# Accuracy after query 64: 0.3025
# Accuracy after query 65: 0.3108
# Accuracy after query 66: 0.3099
# Accuracy after query 67: 0.3111
# Accuracy after query 68: 0.3201
# Accuracy after query 69: 0.3134
# Accuracy after query 70: 0.3159
# Accuracy after query 71: 0.3203
# Accuracy after query 72: 0.3161
# Accuracy after query 73: 0.3172
# Accuracy after query 74: 0.3265
# Accuracy after query 75: 0.3181
# Accuracy after query 76: 0.3151
# Accuracy after query 77: 0.3150
# Accuracy after query 78: 0.3179
# Accuracy after query 79: 0.3183
# Accuracy after query 80: 0.3167
# Accuracy after query 81: 0.3147
# Accuracy after query 82: 0.3189
# Accuracy after query 83: 0.3276
# Accuracy after query 84: 0.3207
# Accuracy after query 85: 0.3171
# Accuracy after query 86: 0.3221
# Accuracy after query 87: 0.3177
# Accuracy after query 88: 0.3244
# Accuracy after query 89: 0.3199
# Accuracy after query 90: 0.3211
# Accuracy after query 91: 0.3182
# Accuracy after query 92: 0.3150
# Accuracy after query 93: 0.3254
# Accuracy after query 94: 0.3242
# Accuracy after query 95: 0.3260
# Accuracy after query 96: 0.3227
# Accuracy after query 97: 0.3234
# Accuracy after query 98: 0.3228
# Accuracy after query 1: 0.1708
# Accuracy after query 2: 0.1737
# Accuracy after query 3: 0.1621
# Accuracy after query 4: 0.1858
# Accuracy after query 5: 0.1851
# Accuracy after query 6: 0.1971
# Accuracy after query 7: 0.2123
# Accuracy after query 8: 0.2212
# Accuracy after query 9: 0.2305
# Accuracy after query 10: 0.2414
# Accuracy after query 11: 0.2303
# Accuracy after query 12: 0.2317
# Accuracy after query 13: 0.2398
# Accuracy after query 14: 0.2399
# Accuracy after query 15: 0.2596
# Accuracy after query 16: 0.2638
# Accuracy after query 17: 0.2640
# Accuracy after query 18: 0.2551
# Accuracy after query 19: 0.2600
# Accuracy after query 20: 0.2655
# Accuracy after query 21: 0.2658
# Accuracy after query 22: 0.2753
# Accuracy after query 23: 0.2802
# Accuracy after query 24: 0.2904
# Accuracy after query 25: 0.2938
# Accuracy after query 26: 0.2791
# Accuracy after query 27: 0.2896
# Accuracy after query 28: 0.2849
# Accuracy after query 29: 0.2960
# Accuracy after query 30: 0.2906
# Accuracy after query 31: 0.3021
# Accuracy after query 32: 0.2970
# Accuracy after query 33: 0.2936
# Accuracy after query 34: 0.2999
# Accuracy after query 35: 0.3011
# Accuracy after query 36: 0.2985
# Accuracy after query 37: 0.2984
# Accuracy after query 38: 0.2902
