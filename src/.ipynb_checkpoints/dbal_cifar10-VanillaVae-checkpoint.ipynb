# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import cifar10

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
LATENT_DIMS = [256]
latent_dim = 256
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\cifar10_vanillavae_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
#     "batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self, latent_dim):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = (X_train.astype(np.float32)) / 255.
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = (X_test.astype(np.float32)) / 255.
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
y_train = y_train.reshape((y_train.shape[0], ))
y_test = y_test.reshape((y_test.shape[0], ))

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_train_enhanced_vanillavae.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\cifar10\x_test_enhanced_vanillavae.npy")

for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))

    for func_name, acquisition_func in ACQ_FUNCS.items():  

        X_initial = X_train_enhanced[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP_REG(latent_dim).to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test_enhanced,
                                                          y_test,
                                                          X_pool,
                                                          y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# Accuracy after query 1: 0.1969
# Accuracy after query 2: 0.2093
# Accuracy after query 3: 0.2048
# Accuracy after query 4: 0.2163
# Accuracy after query 5: 0.2220
# Accuracy after query 6: 0.2261
# Accuracy after query 7: 0.2299
# Accuracy after query 8: 0.2335
# Accuracy after query 9: 0.2385
# Accuracy after query 10: 0.2391
# Accuracy after query 11: 0.2416
# Accuracy after query 12: 0.2500
# Accuracy after query 13: 0.2491
# Accuracy after query 14: 0.2517
# Accuracy after query 15: 0.2510
# Accuracy after query 16: 0.2597
# Accuracy after query 17: 0.2608
# Accuracy after query 18: 0.2642
# Accuracy after query 19: 0.2598
# Accuracy after query 20: 0.2684
# Accuracy after query 21: 0.2730
# Accuracy after query 22: 0.2715
# Accuracy after query 23: 0.2791
# Accuracy after query 24: 0.2779
# Accuracy after query 25: 0.2842
# Accuracy after query 26: 0.2759
# Accuracy after query 27: 0.2847
# Accuracy after query 28: 0.2921
# Accuracy after query 29: 0.2883
# Accuracy after query 30: 0.2853
# Accuracy after query 31: 0.2851
# Accuracy after query 32: 0.2855
# Accuracy after query 33: 0.2876
# Accuracy after query 34: 0.2869
# Accuracy after query 35: 0.2899
# Accuracy after query 36: 0.2958
# Accuracy after query 37: 0.2991
# Accuracy after query 38: 0.3041
# Accuracy after query 39: 0.2949
# Accuracy after query 40: 0.3103
# Accuracy after query 41: 0.3026
# Accuracy after query 42: 0.3028
# Accuracy after query 43: 0.2965
# Accuracy after query 44: 0.2972
# Accuracy after query 45: 0.2947
# Accuracy after query 46: 0.3006
# Accuracy after query 47: 0.3044
# Accuracy after query 48: 0.3003
# Accuracy after query 49: 0.2978
# Accuracy after query 50: 0.3049
# Accuracy after query 51: 0.3017
# Accuracy after query 52: 0.3072
# Accuracy after query 53: 0.3009
# Accuracy after query 54: 0.3047
# Accuracy after query 55: 0.3008
# Accuracy after query 56: 0.3101
# Accuracy after query 57: 0.3006
# Accuracy after query 58: 0.3125
# Accuracy after query 59: 0.3072
# Accuracy after query 60: 0.3133
# Accuracy after query 61: 0.3079
# Accuracy after query 62: 0.3022
# Accuracy after query 63: 0.3048
# Accuracy after query 64: 0.3078
# Accuracy after query 65: 0.3113
# Accuracy after query 66: 0.3168
# Accuracy after query 67: 0.3168
# Accuracy after query 68: 0.3154
# Accuracy after query 69: 0.3156
# Accuracy after query 70: 0.3157
# Accuracy after query 71: 0.3142
# Accuracy after query 72: 0.3226
# Accuracy after query 73: 0.3172
# Accuracy after query 74: 0.3252
# Accuracy after query 75: 0.3220
# Accuracy after query 76: 0.3275
# Accuracy after query 77: 0.3158
# Accuracy after query 78: 0.3210
# Accuracy after query 79: 0.3256
# Accuracy after query 80: 0.3208
# Accuracy after query 81: 0.3199
# Accuracy after query 82: 0.3323
# Accuracy after query 83: 0.3360
# Accuracy after query 84: 0.3255
# Accuracy after query 85: 0.3293
# Accuracy after query 86: 0.3288
# Accuracy after query 87: 0.3329
# Accuracy after query 88: 0.3302
# Accuracy after query 89: 0.3297
# Accuracy after query 90: 0.3300
# Accuracy after query 91: 0.3344
# Accuracy after query 92: 0.3384
# Accuracy after query 93: 0.3361
# Accuracy after query 94: 0.3319
# Accuracy after query 95: 0.3380
# Accuracy after query 96: 0.3347
# Accuracy after query 97: 0.3419
# Accuracy after query 98: 0.3365
# Accuracy after query 1: 0.1644
# Accuracy after query 2: 0.1671
# Accuracy after query 3: 0.1901
# Accuracy after query 4: 0.1887
# Accuracy after query 5: 0.1916
# Accuracy after query 6: 0.1925
# Accuracy after query 7: 0.1966
# Accuracy after query 8: 0.2139
# Accuracy after query 9: 0.2205
# Accuracy after query 10: 0.2322
# Accuracy after query 11: 0.2409
# Accuracy after query 12: 0.2361
# Accuracy after query 13: 0.2442
# Accuracy after query 14: 0.2413
# Accuracy after query 15: 0.2476
# Accuracy after query 16: 0.2494
# Accuracy after query 17: 0.2419
# Accuracy after query 18: 0.2448
# Accuracy after query 19: 0.2525
# Accuracy after query 20: 0.2487
# Accuracy after query 21: 0.2589
# Accuracy after query 22: 0.2625
# Accuracy after query 23: 0.2613
# Accuracy after query 24: 0.2674
# Accuracy after query 25: 0.2696
# Accuracy after query 26: 0.2700
# Accuracy after query 27: 0.2773
# Accuracy after query 28: 0.2556
# Accuracy after query 29: 0.2655
# Accuracy after query 30: 0.2661
# Accuracy after query 31: 0.2693
# Accuracy after query 32: 0.2615
# Accuracy after query 33: 0.2770
# Accuracy after query 34: 0.2679
# Accuracy after query 35: 0.2710
# Accuracy after query 36: 0.2754
# Accuracy after query 37: 0.2745
# Accuracy after query 38: 0.2748
# Accuracy after query 39: 0.2692
# Accuracy after query 40: 0.2658
# Accuracy after query 41: 0.2834
# Accuracy after query 42: 0.2744
# Accuracy after query 43: 0.2800
# Accuracy after query 44: 0.2799
# Accuracy after query 45: 0.2798
# Accuracy after query 46: 0.2830
# Accuracy after query 47: 0.2837
# Accuracy after query 48: 0.2870
# Accuracy after query 49: 0.2852
# Accuracy after query 50: 0.2866
# Accuracy after query 51: 0.2836
# Accuracy after query 52: 0.2784
# Accuracy after query 53: 0.2804
# Accuracy after query 54: 0.2839
# Accuracy after query 55: 0.2852
# Accuracy after query 56: 0.2817
# Accuracy after query 57: 0.2758
# Accuracy after query 58: 0.2806
# Accuracy after query 59: 0.2823
# Accuracy after query 60: 0.2776
# Accuracy after query 61: 0.2761
# Accuracy after query 62: 0.2710
# Accuracy after query 63: 0.2789
# Accuracy after query 64: 0.2889
# Accuracy after query 65: 0.2887
# Accuracy after query 66: 0.2946
# Accuracy after query 67: 0.2911
# Accuracy after query 68: 0.2939
# Accuracy after query 69: 0.2958
# Accuracy after query 70: 0.3002
# Accuracy after query 71: 0.2962
# Accuracy after query 72: 0.2954
# Accuracy after query 73: 0.2953
# Accuracy after query 74: 0.2975
# Accuracy after query 75: 0.3002
# Accuracy after query 76: 0.3051
# Accuracy after query 77: 0.3003
# Accuracy after query 78: 0.3050
# Accuracy after query 79: 0.3087
# Accuracy after query 80: 0.3075
# Accuracy after query 81: 0.3046
# Accuracy after query 82: 0.3010
# Accuracy after query 83: 0.3035
# Accuracy after query 84: 0.3043
# Accuracy after query 85: 0.2953
# Accuracy after query 86: 0.3046
# Accuracy after query 87: 0.3053
# Accuracy after query 88: 0.3088
# Accuracy after query 89: 0.3048
# Accuracy after query 90: 0.3029
# Accuracy after query 91: 0.3065
# Accuracy after query 92: 0.3058
# Accuracy after query 93: 0.3004
# Accuracy after query 94: 0.2973
# Accuracy after query 95: 0.2987
# Accuracy after query 96: 0.2968
# Accuracy after query 97: 0.3027
# Accuracy after query 98: 0.3020
# Accuracy after query 1: 0.1938
# Accuracy after query 2: 0.2136
# Accuracy after query 3: 0.2203
# Accuracy after query 4: 0.2181
# Accuracy after query 5: 0.2113
# Accuracy after query 6: 0.2155
# Accuracy after query 7: 0.2227
# Accuracy after query 8: 0.2199
# Accuracy after query 9: 0.2143
# Accuracy after query 10: 0.2222
# Accuracy after query 11: 0.2221
# Accuracy after query 12: 0.2325
# Accuracy after query 13: 0.2349
# Accuracy after query 14: 0.2377
# Accuracy after query 15: 0.2388
# Accuracy after query 16: 0.2452
# Accuracy after query 17: 0.2437
# Accuracy after query 18: 0.2486
# Accuracy after query 19: 0.2490
# Accuracy after query 20: 0.2528
# Accuracy after query 21: 0.2553
# Accuracy after query 22: 0.2597
# Accuracy after query 23: 0.2533
# Accuracy after query 24: 0.2604
# Accuracy after query 25: 0.2625
# Accuracy after query 26: 0.2620
# Accuracy after query 27: 0.2615
# Accuracy after query 28: 0.2638
# Accuracy after query 29: 0.2670
# Accuracy after query 30: 0.2706
# Accuracy after query 31: 0.2623
# Accuracy after query 32: 0.2750
# Accuracy after query 33: 0.2762
# Accuracy after query 34: 0.2654
# Accuracy after query 35: 0.2687
# Accuracy after query 36: 0.2812
# Accuracy after query 37: 0.2798
# Accuracy after query 38: 0.2758
# Accuracy after query 39: 0.2801
# Accuracy after query 40: 0.2826
# Accuracy after query 41: 0.2893
# Accuracy after query 42: 0.2861
# Accuracy after query 43: 0.2838
# Accuracy after query 44: 0.2892
# Accuracy after query 45: 0.2880
# Accuracy after query 46: 0.2853
# Accuracy after query 47: 0.2842
# Accuracy after query 48: 0.2921
# Accuracy after query 49: 0.2947
# Accuracy after query 50: 0.2910
# Accuracy after query 51: 0.2934
# Accuracy after query 52: 0.2930
# Accuracy after query 53: 0.2805
# Accuracy after query 54: 0.2904
# Accuracy after query 55: 0.2952
# Accuracy after query 56: 0.3039
# Accuracy after query 57: 0.2913
# Accuracy after query 58: 0.2942
# Accuracy after query 59: 0.3018
# Accuracy after query 60: 0.2972
# Accuracy after query 61: 0.2928
# Accuracy after query 62: 0.2958
# Accuracy after query 63: 0.3012
# Accuracy after query 64: 0.2983
# Accuracy after query 65: 0.2926
# Accuracy after query 66: 0.3019
# Accuracy after query 67: 0.3020
# Accuracy after query 68: 0.3027
# Accuracy after query 69: 0.3040
# Accuracy after query 70: 0.3095
# Accuracy after query 71: 0.3074
# Accuracy after query 72: 0.3008
# Accuracy after query 73: 0.3066
# Accuracy after query 74: 0.3144
# Accuracy after query 75: 0.3083
# Accuracy after query 76: 0.3100
# Accuracy after query 77: 0.3089
# Accuracy after query 78: 0.3080
# Accuracy after query 79: 0.3073
# Accuracy after query 80: 0.3155
# Accuracy after query 81: 0.3115
# Accuracy after query 82: 0.3141
# Accuracy after query 83: 0.3040
# Accuracy after query 84: 0.3150
# Accuracy after query 85: 0.3089
# Accuracy after query 86: 0.3174
# Accuracy after query 87: 0.3176
# Accuracy after query 88: 0.3207
# Accuracy after query 89: 0.3163
# Accuracy after query 90: 0.3158
# Accuracy after query 91: 0.3170
# Accuracy after query 92: 0.3178
# Accuracy after query 93: 0.3143
# Accuracy after query 94: 0.3228
# Accuracy after query 95: 0.3186
# Accuracy after query 96: 0.3063
# Accuracy after query 97: 0.3096
# Accuracy after query 98: 0.3147
# Accuracy after query 1: 0.1534
# Accuracy after query 2: 0.1633
# Accuracy after query 3: 0.1754
# Accuracy after query 4: 0.1808
# Accuracy after query 5: 0.1880
# Accuracy after query 6: 0.1929
# Accuracy after query 7: 0.1894
# Accuracy after query 8: 0.2012
# Accuracy after query 9: 0.2106
# Accuracy after query 10: 0.2132
# Accuracy after query 11: 0.2158
# Accuracy after query 12: 0.2085
# Accuracy after query 13: 0.2157
# Accuracy after query 14: 0.2224
# Accuracy after query 15: 0.2191
# Accuracy after query 16: 0.2265
# Accuracy after query 17: 0.2326
# Accuracy after query 18: 0.2309
# Accuracy after query 19: 0.2223
# Accuracy after query 20: 0.2254
# Accuracy after query 21: 0.2363
# Accuracy after query 22: 0.2276
# Accuracy after query 23: 0.2346
# Accuracy after query 24: 0.2358
# Accuracy after query 25: 0.2345
# Accuracy after query 26: 0.2405
# Accuracy after query 27: 0.2420
# Accuracy after query 28: 0.2480
# Accuracy after query 29: 0.2462
# Accuracy after query 30: 0.2543
# Accuracy after query 31: 0.2532
# Accuracy after query 32: 0.2525
# Accuracy after query 33: 0.2587
# Accuracy after query 34: 0.2523
# Accuracy after query 35: 0.2608
# Accuracy after query 36: 0.2488
# Accuracy after query 37: 0.2495
# Accuracy after query 38: 0.2609
# Accuracy after query 39: 0.2657
# Accuracy after query 40: 0.2624
# Accuracy after query 41: 0.2624
# Accuracy after query 42: 0.2691
# Accuracy after query 43: 0.2608
# Accuracy after query 44: 0.2675
# Accuracy after query 45: 0.2659
# Accuracy after query 46: 0.2754
# Accuracy after query 47: 0.2759
# Accuracy after query 48: 0.2767
# Accuracy after query 49: 0.2797
# Accuracy after query 50: 0.2825
# Accuracy after query 51: 0.2852
# Accuracy after query 52: 0.2832
# Accuracy after query 53: 0.2814
# Accuracy after query 54: 0.2896
# Accuracy after query 55: 0.2846
# Accuracy after query 56: 0.2840
# Accuracy after query 57: 0.2820
# Accuracy after query 58: 0.2818
# Accuracy after query 59: 0.2799
# Accuracy after query 60: 0.2944
# Accuracy after query 61: 0.2887
# Accuracy after query 62: 0.2889
# Accuracy after query 63: 0.3011
# Accuracy after query 64: 0.2950
# Accuracy after query 65: 0.2856
# Accuracy after query 66: 0.2959
# Accuracy after query 67: 0.2972
# Accuracy after query 68: 0.2981
# Accuracy after query 69: 0.2983
# Accuracy after query 70: 0.2934
# Accuracy after query 71: 0.3004
# Accuracy after query 72: 0.3016
# Accuracy after query 73: 0.2954
# Accuracy after query 74: 0.2934
# Accuracy after query 75: 0.2883
# Accuracy after query 76: 0.2929
# Accuracy after query 77: 0.3030
# Accuracy after query 78: 0.2971
# Accuracy after query 79: 0.3010
# Accuracy after query 80: 0.3070
# Accuracy after query 81: 0.3101
# Accuracy after query 82: 0.2868
# Accuracy after query 83: 0.2998
# Accuracy after query 84: 0.3002
# Accuracy after query 85: 0.3116
# Accuracy after query 86: 0.3086
# Accuracy after query 87: 0.2994
# Accuracy after query 88: 0.3005
# Accuracy after query 89: 0.3057
# Accuracy after query 90: 0.3035
# Accuracy after query 91: 0.3026
# Accuracy after query 92: 0.2962
# Accuracy after query 93: 0.3042
# Accuracy after query 94: 0.2974
# Accuracy after query 95: 0.3090
# Accuracy after query 96: 0.3059
# Accuracy after query 97: 0.2975
# Accuracy after query 98: 0.3130
# Accuracy after query 1: 0.1784
# Accuracy after query 2: 0.1993
# Accuracy after query 3: 0.2185
# Accuracy after query 4: 0.2092
# Accuracy after query 5: 0.2107
# Accuracy after query 6: 0.1971
# Accuracy after query 7: 0.2066
# Accuracy after query 8: 0.2135
# Accuracy after query 9: 0.2230
# Accuracy after query 10: 0.2289
# Accuracy after query 11: 0.2401
# Accuracy after query 12: 0.2505
# Accuracy after query 13: 0.2529
# Accuracy after query 14: 0.2571
# Accuracy after query 15: 0.2462
# Accuracy after query 16: 0.2632
# Accuracy after query 17: 0.2546
# Accuracy after query 18: 0.2683
# Accuracy after query 19: 0.2639
# Accuracy after query 20: 0.2714
# Accuracy after query 21: 0.2751
# Accuracy after query 22: 0.2742
# Accuracy after query 23: 0.2654
# Accuracy after query 24: 0.2694
# Accuracy after query 25: 0.2809
# Accuracy after query 26: 0.2774
# Accuracy after query 27: 0.2782
# Accuracy after query 28: 0.2737
# Accuracy after query 29: 0.2726
# Accuracy after query 30: 0.2780
# Accuracy after query 31: 0.2808
# Accuracy after query 32: 0.2727
# Accuracy after query 33: 0.2817
# Accuracy after query 34: 0.2755
# Accuracy after query 35: 0.2819
# Accuracy after query 36: 0.2839
# Accuracy after query 37: 0.2844
# Accuracy after query 38: 0.2872
# Accuracy after query 39: 0.2912
# Accuracy after query 40: 0.2975
# Accuracy after query 41: 0.2892
# Accuracy after query 42: 0.2939
# Accuracy after query 43: 0.2956
# Accuracy after query 44: 0.2903
# Accuracy after query 45: 0.3046
# Accuracy after query 46: 0.2965
# Accuracy after query 47: 0.2994
# Accuracy after query 48: 0.3059
# Accuracy after query 49: 0.2970
# Accuracy after query 50: 0.3053
# Accuracy after query 51: 0.3087
# Accuracy after query 52: 0.3137
# Accuracy after query 53: 0.3087
# Accuracy after query 54: 0.3117
# Accuracy after query 55: 0.3132
# Accuracy after query 56: 0.3132
# Accuracy after query 57: 0.3075
# Accuracy after query 58: 0.3159
# Accuracy after query 59: 0.3121
# Accuracy after query 60: 0.3147
# Accuracy after query 61: 0.3162
# Accuracy after query 62: 0.3066
# Accuracy after query 63: 0.3189
# Accuracy after query 64: 0.3213
# Accuracy after query 65: 0.3151
# Accuracy after query 66: 0.3241
# Accuracy after query 67: 0.3162
# Accuracy after query 68: 0.3253
# Accuracy after query 69: 0.3223
# Accuracy after query 70: 0.3222
# Accuracy after query 71: 0.3264
# Accuracy after query 72: 0.3323
# Accuracy after query 73: 0.3279
# Accuracy after query 74: 0.3319
# Accuracy after query 75: 0.3238
# Accuracy after query 76: 0.3345
# Accuracy after query 77: 0.3359
# Accuracy after query 78: 0.3386
# Accuracy after query 79: 0.3350
# Accuracy after query 80: 0.3306
# Accuracy after query 81: 0.3373
# Accuracy after query 82: 0.3291
# Accuracy after query 83: 0.3401
# Accuracy after query 84: 0.3376
# Accuracy after query 85: 0.3374
# Accuracy after query 86: 0.3388
# Accuracy after query 87: 0.3362
# Accuracy after query 88: 0.3385
# Accuracy after query 89: 0.3360
# Accuracy after query 90: 0.3375
# Accuracy after query 91: 0.3433
# Accuracy after query 92: 0.3385
# Accuracy after query 93: 0.3398
# Accuracy after query 94: 0.3482
# Accuracy after query 95: 0.3432
# Accuracy after query 96: 0.3476
# Accuracy after query 97: 0.3488
# Accuracy after query 98: 0.3451
# Accuracy after query 1: 0.2023
# Accuracy after query 2: 0.2103
# Accuracy after query 3: 0.2275
# Accuracy after query 4: 0.2409
# Accuracy after query 5: 0.2521
# Accuracy after query 6: 0.2438
# Accuracy after query 7: 0.2409
# Accuracy after query 8: 0.2552
# Accuracy after query 9: 0.2649
# Accuracy after query 10: 0.2592
# Accuracy after query 11: 0.2729
# Accuracy after query 12: 0.2667
# Accuracy after query 13: 0.2718
# Accuracy after query 14: 0.2699
# Accuracy after query 15: 0.2678
# Accuracy after query 16: 0.2719
# Accuracy after query 17: 0.2818
# Accuracy after query 18: 0.2806
# Accuracy after query 19: 0.2785
# Accuracy after query 20: 0.2820
# Accuracy after query 21: 0.2722
# Accuracy after query 22: 0.2856
# Accuracy after query 23: 0.2835
# Accuracy after query 24: 0.2796
# Accuracy after query 25: 0.2862
# Accuracy after query 26: 0.2824
# Accuracy after query 27: 0.2892
# Accuracy after query 28: 0.2866
# Accuracy after query 29: 0.2945
# Accuracy after query 30: 0.3002
# Accuracy after query 31: 0.2930
# Accuracy after query 32: 0.2984
# Accuracy after query 33: 0.3007
# Accuracy after query 34: 0.3032
# Accuracy after query 35: 0.2984
# Accuracy after query 36: 0.3022
# Accuracy after query 37: 0.3033
# Accuracy after query 38: 0.2944
# Accuracy after query 39: 0.2982
# Accuracy after query 40: 0.3038
# Accuracy after query 41: 0.3030
# Accuracy after query 42: 0.3016
# Accuracy after query 43: 0.3096
# Accuracy after query 44: 0.3112
# Accuracy after query 45: 0.3008
# Accuracy after query 46: 0.2971
# Accuracy after query 47: 0.3056
# Accuracy after query 48: 0.3031
# Accuracy after query 49: 0.3044
# Accuracy after query 50: 0.3097
# Accuracy after query 51: 0.3129
# Accuracy after query 52: 0.3115
# Accuracy after query 53: 0.3146
# Accuracy after query 54: 0.3076
# Accuracy after query 55: 0.3147
# Accuracy after query 56: 0.3108
# Accuracy after query 57: 0.3178
# Accuracy after query 58: 0.3147
# Accuracy after query 59: 0.3118
# Accuracy after query 60: 0.3053
# Accuracy after query 61: 0.3107
# Accuracy after query 62: 0.3166
# Accuracy after query 63: 0.3225
# Accuracy after query 64: 0.3154
# Accuracy after query 65: 0.3119
# Accuracy after query 66: 0.3074
# Accuracy after query 67: 0.3177
# Accuracy after query 68: 0.3285
# Accuracy after query 69: 0.3242
# Accuracy after query 70: 0.3218
# Accuracy after query 71: 0.3255
# Accuracy after query 72: 0.3228
# Accuracy after query 73: 0.3274
# Accuracy after query 74: 0.3242
# Accuracy after query 75: 0.3165
# Accuracy after query 76: 0.3258
# Accuracy after query 77: 0.3245
# Accuracy after query 78: 0.3212
# Accuracy after query 79: 0.3257
# Accuracy after query 80: 0.3336
# Accuracy after query 81: 0.3336
# Accuracy after query 82: 0.3322
# Accuracy after query 83: 0.3245
# Accuracy after query 84: 0.3262
# Accuracy after query 85: 0.3329
# Accuracy after query 86: 0.3279
# Accuracy after query 87: 0.3316
# Accuracy after query 88: 0.3326
# Accuracy after query 89: 0.3302
# Accuracy after query 90: 0.3330
# Accuracy after query 91: 0.3316
# Accuracy after query 92: 0.3302
# Accuracy after query 93: 0.3339
# Accuracy after query 94: 0.3337
# Accuracy after query 95: 0.3374
# Accuracy after query 96: 0.3318
# Accuracy after query 97: 0.3295
# Accuracy after query 98: 0.3406
# Accuracy after query 1: 0.2038
# Accuracy after query 2: 0.2026
# Accuracy after query 3: 0.2005
# Accuracy after query 4: 0.2002
# Accuracy after query 5: 0.1993
# Accuracy after query 6: 0.2040
# Accuracy after query 7: 0.2015
# Accuracy after query 8: 0.2151
# Accuracy after query 9: 0.2153
# Accuracy after query 10: 0.2196
# Accuracy after query 11: 0.2274
# Accuracy after query 12: 0.2254
# Accuracy after query 13: 0.2236
# Accuracy after query 14: 0.2344
# Accuracy after query 15: 0.2418
# Accuracy after query 16: 0.2438
# Accuracy after query 17: 0.2462
# Accuracy after query 18: 0.2420
# Accuracy after query 19: 0.2471
# Accuracy after query 20: 0.2457
# Accuracy after query 21: 0.2521
# Accuracy after query 22: 0.2603
# Accuracy after query 23: 0.2550
# Accuracy after query 24: 0.2614
# Accuracy after query 25: 0.2700
# Accuracy after query 26: 0.2639
# Accuracy after query 27: 0.2659
# Accuracy after query 28: 0.2736
# Accuracy after query 29: 0.2728
# Accuracy after query 30: 0.2732
# Accuracy after query 31: 0.2791
# Accuracy after query 32: 0.2761
# Accuracy after query 33: 0.2842
# Accuracy after query 34: 0.2827
# Accuracy after query 35: 0.2718
# Accuracy after query 36: 0.2810
# Accuracy after query 37: 0.2899
# Accuracy after query 38: 0.2884
# Accuracy after query 39: 0.2865
# Accuracy after query 40: 0.2870
# Accuracy after query 41: 0.2861
# Accuracy after query 42: 0.2876
# Accuracy after query 43: 0.2906
# Accuracy after query 44: 0.2891
# Accuracy after query 45: 0.2786
# Accuracy after query 46: 0.2866
# Accuracy after query 47: 0.2912
# Accuracy after query 48: 0.2923
# Accuracy after query 49: 0.2960
# Accuracy after query 50: 0.3000
# Accuracy after query 51: 0.3072
# Accuracy after query 52: 0.2998
# Accuracy after query 53: 0.3006
# Accuracy after query 54: 0.2910
# Accuracy after query 55: 0.2913
# Accuracy after query 56: 0.3080
# Accuracy after query 57: 0.3152
# Accuracy after query 58: 0.3060
# Accuracy after query 59: 0.3075
# Accuracy after query 60: 0.3096
# Accuracy after query 61: 0.3040
# Accuracy after query 62: 0.3155
# Accuracy after query 63: 0.3112
# Accuracy after query 64: 0.3066
# Accuracy after query 65: 0.3072
# Accuracy after query 66: 0.3087
# Accuracy after query 67: 0.3087
# Accuracy after query 68: 0.3009
# Accuracy after query 69: 0.3070
# Accuracy after query 70: 0.3005
# Accuracy after query 71: 0.3011
# Accuracy after query 72: 0.3101
# Accuracy after query 73: 0.3110
# Accuracy after query 74: 0.3020
# Accuracy after query 75: 0.3028
# Accuracy after query 76: 0.3117
# Accuracy after query 77: 0.3056
# Accuracy after query 78: 0.3059
# Accuracy after query 79: 0.3169
# Accuracy after query 80: 0.3142
# Accuracy after query 81: 0.3126
# Accuracy after query 82: 0.3067
# Accuracy after query 83: 0.3203
# Accuracy after query 84: 0.3138
# Accuracy after query 85: 0.3127
# Accuracy after query 86: 0.3239
# Accuracy after query 87: 0.3148
# Accuracy after query 88: 0.3112
# Accuracy after query 89: 0.3065
# Accuracy after query 90: 0.3070
# Accuracy after query 91: 0.3091
# Accuracy after query 92: 0.3054
# Accuracy after query 93: 0.3093
# Accuracy after query 94: 0.3112
# Accuracy after query 95: 0.3089
# Accuracy after query 96: 0.3166
# Accuracy after query 97: 0.3117
# Accuracy after query 98: 0.3082
# Accuracy after query 1: 0.2024
# Accuracy after query 2: 0.2078
# Accuracy after query 3: 0.2085
# Accuracy after query 4: 0.2098
# Accuracy after query 5: 0.2201
# Accuracy after query 6: 0.2298
# Accuracy after query 7: 0.2359
# Accuracy after query 8: 0.2430
# Accuracy after query 9: 0.2438
# Accuracy after query 10: 0.2448
# Accuracy after query 11: 0.2428
# Accuracy after query 12: 0.2525
# Accuracy after query 13: 0.2550
# Accuracy after query 14: 0.2598
# Accuracy after query 15: 0.2600
# Accuracy after query 16: 0.2536
# Accuracy after query 17: 0.2553
# Accuracy after query 18: 0.2700
# Accuracy after query 19: 0.2724
# Accuracy after query 20: 0.2636
# Accuracy after query 21: 0.2687
# Accuracy after query 22: 0.2565
# Accuracy after query 23: 0.2655
# Accuracy after query 24: 0.2733
# Accuracy after query 25: 0.2730
# Accuracy after query 26: 0.2725
# Accuracy after query 27: 0.2728
# Accuracy after query 28: 0.2735
# Accuracy after query 29: 0.2743
# Accuracy after query 30: 0.2726
# Accuracy after query 31: 0.2846
# Accuracy after query 32: 0.2847
# Accuracy after query 33: 0.2816
# Accuracy after query 34: 0.2835
# Accuracy after query 35: 0.2915
# Accuracy after query 36: 0.2868
# Accuracy after query 37: 0.2932
# Accuracy after query 38: 0.2902
# Accuracy after query 39: 0.2921
# Accuracy after query 40: 0.2929
# Accuracy after query 41: 0.2982
# Accuracy after query 42: 0.3023
# Accuracy after query 43: 0.2988
# Accuracy after query 44: 0.3017
# Accuracy after query 45: 0.3091
# Accuracy after query 46: 0.3043
# Accuracy after query 47: 0.3077
# Accuracy after query 48: 0.3038
# Accuracy after query 49: 0.3029
# Accuracy after query 50: 0.3052
# Accuracy after query 51: 0.3077
# Accuracy after query 52: 0.3094
# Accuracy after query 53: 0.3176
# Accuracy after query 54: 0.3138
# Accuracy after query 55: 0.3155
# Accuracy after query 56: 0.3150
# Accuracy after query 57: 0.3080
# Accuracy after query 58: 0.3197
# Accuracy after query 59: 0.3178
# Accuracy after query 60: 0.3201
# Accuracy after query 61: 0.3237
# Accuracy after query 62: 0.3137
# Accuracy after query 63: 0.3216
# Accuracy after query 64: 0.3246
# Accuracy after query 65: 0.3235
# Accuracy after query 66: 0.3306
# Accuracy after query 67: 0.3283
# Accuracy after query 68: 0.3257
# Accuracy after query 69: 0.3241
# Accuracy after query 70: 0.3224
# Accuracy after query 71: 0.3204
# Accuracy after query 72: 0.3223
# Accuracy after query 73: 0.3204
# Accuracy after query 74: 0.3201
# Accuracy after query 75: 0.3249
# Accuracy after query 76: 0.3220
# Accuracy after query 77: 0.3295
# Accuracy after query 78: 0.3247
# Accuracy after query 79: 0.3276
# Accuracy after query 80: 0.3293
# Accuracy after query 81: 0.3276
# Accuracy after query 82: 0.3341
# Accuracy after query 83: 0.3360
# Accuracy after query 84: 0.3349
# Accuracy after query 85: 0.3363
# Accuracy after query 86: 0.3366
# Accuracy after query 87: 0.3321
# Accuracy after query 88: 0.3296
# Accuracy after query 89: 0.3297
# Accuracy after query 90: 0.3364
# Accuracy after query 91: 0.3357
# Accuracy after query 92: 0.3355
# Accuracy after query 93: 0.3378
# Accuracy after query 94: 0.3345
# Accuracy after query 95: 0.3406
# Accuracy after query 96: 0.3407
# Accuracy after query 97: 0.3339
# Accuracy after query 98: 0.3399
# Accuracy after query 1: 0.2209
# Accuracy after query 2: 0.2218
# Accuracy after query 3: 0.2239
# Accuracy after query 4: 0.2238
# Accuracy after query 5: 0.2279
# Accuracy after query 6: 0.2310
# Accuracy after query 7: 0.2239
# Accuracy after query 8: 0.2318
# Accuracy after query 9: 0.2248
# Accuracy after query 10: 0.2254
# Accuracy after query 11: 0.2295
# Accuracy after query 12: 0.2337
# Accuracy after query 13: 0.2341
# Accuracy after query 14: 0.2291
# Accuracy after query 15: 0.2395
# Accuracy after query 16: 0.2471
# Accuracy after query 17: 0.2484
# Accuracy after query 18: 0.2550
# Accuracy after query 19: 0.2617
# Accuracy after query 20: 0.2527
# Accuracy after query 21: 0.2510
# Accuracy after query 22: 0.2631
# Accuracy after query 23: 0.2669
# Accuracy after query 24: 0.2631
# Accuracy after query 25: 0.2633
# Accuracy after query 26: 0.2661
# Accuracy after query 27: 0.2634
# Accuracy after query 28: 0.2606
# Accuracy after query 29: 0.2652
# Accuracy after query 30: 0.2628
# Accuracy after query 31: 0.2738
# Accuracy after query 32: 0.2633
# Accuracy after query 33: 0.2696
# Accuracy after query 34: 0.2716
# Accuracy after query 35: 0.2754
# Accuracy after query 36: 0.2678
# Accuracy after query 37: 0.2787
# Accuracy after query 38: 0.2806
# Accuracy after query 39: 0.2766
# Accuracy after query 40: 0.2800
# Accuracy after query 41: 0.2917
# Accuracy after query 42: 0.2884
# Accuracy after query 43: 0.2926
# Accuracy after query 44: 0.2941
# Accuracy after query 45: 0.2952
# Accuracy after query 46: 0.2960
# Accuracy after query 47: 0.2918
# Accuracy after query 48: 0.2959
# Accuracy after query 49: 0.2911
# Accuracy after query 50: 0.2931
# Accuracy after query 51: 0.2890
# Accuracy after query 52: 0.2955
# Accuracy after query 53: 0.2933
# Accuracy after query 54: 0.2931
# Accuracy after query 55: 0.2897
# Accuracy after query 56: 0.2898
# Accuracy after query 57: 0.2865
# Accuracy after query 58: 0.2933
# Accuracy after query 59: 0.2913
# Accuracy after query 60: 0.2996
# Accuracy after query 61: 0.2965
# Accuracy after query 62: 0.2957
# Accuracy after query 63: 0.2971
# Accuracy after query 64: 0.2986
# Accuracy after query 65: 0.2986
# Accuracy after query 66: 0.2889
# Accuracy after query 67: 0.2971
# Accuracy after query 68: 0.3052
# Accuracy after query 69: 0.2983
# Accuracy after query 70: 0.2988
# Accuracy after query 71: 0.3017
# Accuracy after query 72: 0.3007
# Accuracy after query 73: 0.3023
# Accuracy after query 74: 0.3012
# Accuracy after query 75: 0.2942
# Accuracy after query 76: 0.2952
# Accuracy after query 77: 0.2913
# Accuracy after query 78: 0.2921
# Accuracy after query 79: 0.2926
# Accuracy after query 80: 0.2948
# Accuracy after query 81: 0.2826
# Accuracy after query 82: 0.2810
# Accuracy after query 83: 0.2820
# Accuracy after query 84: 0.2858
# Accuracy after query 85: 0.2927
# Accuracy after query 86: 0.2835
# Accuracy after query 87: 0.2917
# Accuracy after query 88: 0.2932
# Accuracy after query 89: 0.2923
# Accuracy after query 90: 0.3015
# Accuracy after query 91: 0.2925
# Accuracy after query 92: 0.2922
# Accuracy after query 93: 0.2802
# Accuracy after query 94: 0.2880
# Accuracy after query 95: 0.2949
# Accuracy after query 96: 0.2994
# Accuracy after query 97: 0.2913
# Accuracy after query 98: 0.2906
# Accuracy after query 1: 0.2241
# Accuracy after query 2: 0.2267
# Accuracy after query 3: 0.2322
# Accuracy after query 4: 0.2305
# Accuracy after query 5: 0.2397
# Accuracy after query 6: 0.2327
# Accuracy after query 7: 0.2407
# Accuracy after query 8: 0.2486
# Accuracy after query 9: 0.2433
# Accuracy after query 10: 0.2403
# Accuracy after query 11: 0.2499
# Accuracy after query 12: 0.2490
# Accuracy after query 13: 0.2497
# Accuracy after query 14: 0.2480
# Accuracy after query 15: 0.2641
# Accuracy after query 16: 0.2612
# Accuracy after query 17: 0.2653
# Accuracy after query 18: 0.2620
# Accuracy after query 19: 0.2620
# Accuracy after query 20: 0.2656
# Accuracy after query 21: 0.2537
# Accuracy after query 22: 0.2716
# Accuracy after query 23: 0.2606
# Accuracy after query 24: 0.2696
# Accuracy after query 25: 0.2721
# Accuracy after query 26: 0.2766
# Accuracy after query 27: 0.2666
# Accuracy after query 28: 0.2732
# Accuracy after query 29: 0.2624
# Accuracy after query 30: 0.2804
# Accuracy after query 31: 0.2797
# Accuracy after query 32: 0.2788
# Accuracy after query 33: 0.2791
# Accuracy after query 34: 0.2845
# Accuracy after query 35: 0.2879
# Accuracy after query 36: 0.2998
# Accuracy after query 37: 0.3010
# Accuracy after query 38: 0.2962
# Accuracy after query 39: 0.3044
# Accuracy after query 40: 0.3045
# Accuracy after query 41: 0.3011
# Accuracy after query 42: 0.2994
# Accuracy after query 43: 0.3067
# Accuracy after query 44: 0.2923
# Accuracy after query 45: 0.2927
# Accuracy after query 46: 0.3059
# Accuracy after query 47: 0.3151
# Accuracy after query 48: 0.3118
# Accuracy after query 49: 0.3119
# Accuracy after query 50: 0.3172
# Accuracy after query 51: 0.3178
# Accuracy after query 52: 0.3119
# Accuracy after query 53: 0.3196
# Accuracy after query 54: 0.3226
# Accuracy after query 55: 0.3127
# Accuracy after query 56: 0.3187
# Accuracy after query 57: 0.3203
# Accuracy after query 58: 0.3180
# Accuracy after query 59: 0.3267
# Accuracy after query 60: 0.3223
# Accuracy after query 61: 0.3151
# Accuracy after query 62: 0.3235
# Accuracy after query 63: 0.3246
# Accuracy after query 64: 0.3289
# Accuracy after query 65: 0.3273
# Accuracy after query 66: 0.3250
# Accuracy after query 67: 0.3285
# Accuracy after query 68: 0.3238
# Accuracy after query 69: 0.3225
# Accuracy after query 70: 0.3221
# Accuracy after query 71: 0.3261
# Accuracy after query 72: 0.3243
# Accuracy after query 73: 0.3290
# Accuracy after query 74: 0.3253
# Accuracy after query 75: 0.3272
# Accuracy after query 76: 0.3310
# Accuracy after query 77: 0.3305
# Accuracy after query 78: 0.3281
# Accuracy after query 79: 0.3283
# Accuracy after query 80: 0.3248
# Accuracy after query 81: 0.3334
# Accuracy after query 82: 0.3311
# Accuracy after query 83: 0.3351
# Accuracy after query 84: 0.3334
# Accuracy after query 85: 0.3384
# Accuracy after query 86: 0.3402
# Accuracy after query 87: 0.3423
# Accuracy after query 88: 0.3426
# Accuracy after query 89: 0.3488
# Accuracy after query 90: 0.3434
# Accuracy after query 91: 0.3425
# Accuracy after query 92: 0.3352
# Accuracy after query 93: 0.3411
# Accuracy after query 94: 0.3446
# Accuracy after query 95: 0.3359
# Accuracy after query 96: 0.3306
# Accuracy after query 97: 0.3354
# Accuracy after query 98: 0.3254
# Accuracy after query 1: 0.1987
# Accuracy after query 2: 0.2040
# Accuracy after query 3: 0.2079
# Accuracy after query 4: 0.2144
# Accuracy after query 5: 0.2187
# Accuracy after query 6: 0.2295
# Accuracy after query 7: 0.2304
# Accuracy after query 8: 0.2357
# Accuracy after query 9: 0.2366
# Accuracy after query 10: 0.2404
# Accuracy after query 11: 0.2415
# Accuracy after query 12: 0.2404
# Accuracy after query 13: 0.2437
# Accuracy after query 14: 0.2496
# Accuracy after query 15: 0.2478
# Accuracy after query 16: 0.2484
# Accuracy after query 17: 0.2512
# Accuracy after query 18: 0.2520
# Accuracy after query 19: 0.2628
# Accuracy after query 20: 0.2591
# Accuracy after query 21: 0.2572
# Accuracy after query 22: 0.2618
# Accuracy after query 23: 0.2561
# Accuracy after query 24: 0.2698
# Accuracy after query 25: 0.2669
# Accuracy after query 26: 0.2734
# Accuracy after query 27: 0.2732
# Accuracy after query 28: 0.2758
# Accuracy after query 29: 0.2744
# Accuracy after query 30: 0.2537
# Accuracy after query 31: 0.2576
# Accuracy after query 32: 0.2646
# Accuracy after query 33: 0.2724
# Accuracy after query 34: 0.2787
# Accuracy after query 35: 0.2873
# Accuracy after query 36: 0.2867
# Accuracy after query 37: 0.2890
# Accuracy after query 38: 0.2921
# Accuracy after query 39: 0.2956
# Accuracy after query 40: 0.2892
# Accuracy after query 41: 0.2978
# Accuracy after query 42: 0.2990
# Accuracy after query 43: 0.3016
# Accuracy after query 44: 0.2940
# Accuracy after query 45: 0.2938
# Accuracy after query 46: 0.3009
# Accuracy after query 47: 0.3003
# Accuracy after query 48: 0.3024
# Accuracy after query 49: 0.3087
# Accuracy after query 50: 0.3098
# Accuracy after query 51: 0.3093
# Accuracy after query 52: 0.3120
# Accuracy after query 53: 0.3144
# Accuracy after query 54: 0.3121
# Accuracy after query 55: 0.3089
# Accuracy after query 56: 0.3029
# Accuracy after query 57: 0.3074
# Accuracy after query 58: 0.3105
# Accuracy after query 59: 0.3127
# Accuracy after query 60: 0.3074
# Accuracy after query 61: 0.3057
# Accuracy after query 62: 0.3120
# Accuracy after query 63: 0.3157
# Accuracy after query 64: 0.3149
# Accuracy after query 65: 0.3160
# Accuracy after query 66: 0.3185
# Accuracy after query 67: 0.3083
# Accuracy after query 68: 0.3183
# Accuracy after query 69: 0.3172
# Accuracy after query 70: 0.3213
# Accuracy after query 71: 0.3164
# Accuracy after query 72: 0.3176
# Accuracy after query 73: 0.3175
# Accuracy after query 74: 0.3234
# Accuracy after query 75: 0.3173
# Accuracy after query 76: 0.3224
# Accuracy after query 77: 0.3233
# Accuracy after query 78: 0.3232
# Accuracy after query 79: 0.3152
# Accuracy after query 80: 0.3155
# Accuracy after query 81: 0.3228
# Accuracy after query 82: 0.3253
# Accuracy after query 83: 0.3296
# Accuracy after query 84: 0.3306
# Accuracy after query 85: 0.3330
# Accuracy after query 86: 0.3298
# Accuracy after query 87: 0.3250
# Accuracy after query 88: 0.3250
# Accuracy after query 89: 0.3289
# Accuracy after query 90: 0.3367
# Accuracy after query 91: 0.3361
# Accuracy after query 92: 0.3283
# Accuracy after query 93: 0.3351
# Accuracy after query 94: 0.3331
# Accuracy after query 95: 0.3315
# Accuracy after query 96: 0.3299
# Accuracy after query 97: 0.3315
# Accuracy after query 98: 0.3311
# Accuracy after query 1: 0.1706
# Accuracy after query 2: 0.1879
# Accuracy after query 3: 0.1891
# Accuracy after query 4: 0.1892
# Accuracy after query 5: 0.1980
# Accuracy after query 6: 0.2080
# Accuracy after query 7: 0.2131
# Accuracy after query 8: 0.2078
# Accuracy after query 9: 0.2178
# Accuracy after query 10: 0.2239
# Accuracy after query 11: 0.2314
# Accuracy after query 12: 0.2273
# Accuracy after query 13: 0.2336
# Accuracy after query 14: 0.2342
# Accuracy after query 15: 0.2357
# Accuracy after query 16: 0.2409
# Accuracy after query 17: 0.2490
# Accuracy after query 18: 0.2427
# Accuracy after query 19: 0.2347
# Accuracy after query 20: 0.2497
# Accuracy after query 21: 0.2431
# Accuracy after query 22: 0.2481
# Accuracy after query 23: 0.2563
# Accuracy after query 24: 0.2469
# Accuracy after query 25: 0.2480
# Accuracy after query 26: 0.2553
# Accuracy after query 27: 0.2605
# Accuracy after query 28: 0.2562
# Accuracy after query 29: 0.2479
# Accuracy after query 30: 0.2432
# Accuracy after query 31: 0.2510
# Accuracy after query 32: 0.2477
# Accuracy after query 33: 0.2503
# Accuracy after query 34: 0.2536
# Accuracy after query 35: 0.2489
# Accuracy after query 36: 0.2628
# Accuracy after query 37: 0.2630
# Accuracy after query 38: 0.2570
# Accuracy after query 39: 0.2642
# Accuracy after query 40: 0.2736
# Accuracy after query 41: 0.2794
# Accuracy after query 42: 0.2804
# Accuracy after query 43: 0.2796
# Accuracy after query 44: 0.2821
# Accuracy after query 45: 0.2812
# Accuracy after query 46: 0.2815
# Accuracy after query 47: 0.2760
# Accuracy after query 48: 0.2929
# Accuracy after query 49: 0.2900
# Accuracy after query 50: 0.2916
# Accuracy after query 51: 0.2944
# Accuracy after query 52: 0.3017
# Accuracy after query 53: 0.2957
# Accuracy after query 54: 0.2837
# Accuracy after query 55: 0.2833
# Accuracy after query 56: 0.2947
# Accuracy after query 57: 0.2966
# Accuracy after query 58: 0.2962
# Accuracy after query 59: 0.2975
# Accuracy after query 60: 0.2963
# Accuracy after query 61: 0.2999
# Accuracy after query 62: 0.2970
# Accuracy after query 63: 0.3013
# Accuracy after query 64: 0.3007
# Accuracy after query 65: 0.3024
# Accuracy after query 66: 0.3049
# Accuracy after query 67: 0.2976
# Accuracy after query 68: 0.2969
# Accuracy after query 69: 0.3046
# Accuracy after query 70: 0.3058
# Accuracy after query 71: 0.3037
# Accuracy after query 72: 0.2999
# Accuracy after query 73: 0.2995
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18100/368673557.py in <module>
#      31
#      32
# ---> 33         acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
#      34                                                           X_test_enhanced,
#      35                                                           y_test,
#
# ~\AppData\Local\Temp/ipykernel_18100/2474446029.py in active_learning_procedure(query_strategy, X_test, y_test, X_pool, y_pool, X_initial, y_initial, estimator, n_queries, n_instances)
#      18     pool_size = len(X_initial)
#      19     for index in range(n_queries):
# ---> 20         query_idx, query_instance = learner.query(X_pool, n_instances)
#      21         learner.teach(X_pool[query_idx], y_pool[query_idx])
#      22         X_pool = np.delete(X_pool, query_idx, axis=0)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py in query(self, X_pool, *query_args, **query_kwargs)
#     251             labelled upon query synthesis.
#     252         """
# --> 253         query_result = self.query_strategy(self, X_pool, *query_args, **query_kwargs)
#     254
#     255         if isinstance(query_result, tuple):
#
# ~\OneDrive\Masaüstü\masterthesis\src\acquisition_functions.py in mean_std(model, X_pool, n_query, T, training)
#     182         training: If False, run test without MC dropout. (default=True)
#     183     """
# --> 184     outputs, random_subset = predictions_from_pool(model, X_pool, T, training)
#     185     sigma_c = np.std(outputs, axis=0)
#     186     acquisition = np.mean(sigma_c, axis=-1)
#
# ~\OneDrive\Masaüstü\masterthesis\src\acquisition_functions.py in predictions_from_pool(model, X_pool, T, training)
#      18     with torch.no_grad():
#      19         outputs = np.stack(
# ---> 20             [
#      21                 torch.softmax(
#      22                     model.estimator.forward(X_pool[random_subset], training=training),
#
# ~\OneDrive\Masaüstü\masterthesis\src\acquisition_functions.py in <listcomp>(.0)
#      20             [
#      21                 torch.softmax(
# ---> 22                     model.estimator.forward(X_pool[random_subset], training=training),
#      23                     dim=-1,
#      24                 )
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in forward(self, X, training, device)
#    1322
#    1323         """
# -> 1324         y_infer = list(self.forward_iter(X, training=training, device=device))
#    1325
#    1326         is_multioutput = len(y_infer) > 0 and isinstance(y_infer[0], tuple)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in forward_iter(self, X, training, device)
#    1277         iterator = self.get_iterator(dataset, training=training)
#    1278         for batch in iterator:
# -> 1279             yp = self.evaluation_step(batch, training=training)
#    1280             yield to_device(yp, device=device)
#    1281
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in evaluation_step(self, batch, training)
#    1034         with torch.set_grad_enabled(training):
#    1035             self._set_training(training)
# -> 1036             return self.infer(Xi)
#    1037
#    1038     def fit_loop(self, X, y=None, epochs=None, **fit_params):
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in infer(self, x, **fit_params)
#    1357             x_dict = self._merge_x_and_fit_params(x, fit_params)
#    1358             return self.module_(**x_dict)
# -> 1359         return self.module_(x, **fit_params)
#    1360
#    1361     def _get_predict_nonlinearity(self):
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Temp/ipykernel_18100/622579740.py in forward(self, x)
#      17
#      18     def forward(self, x):
# ---> 19         return self.layers(x)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#      96
#      97     def forward(self, input: Tensor) -> Tensor:
# ---> 98         return F.relu(input, inplace=self.inplace)
#      99
#     100     def extra_repr(self) -> str:
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#    1297         result = torch.relu_(input)
#    1298     else:
# -> 1299         result = torch.relu(input)
#    1300     return result
#    1301
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:76] data. DefaultCPUAllocator: not enough memory: you tried to allocate 65536 bytes.
