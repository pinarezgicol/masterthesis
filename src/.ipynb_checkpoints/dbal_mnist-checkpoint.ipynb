# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
from keras.datasets import mnist

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 5
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
results_path = 'results'

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
    "batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self,):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 28, 28, 1).astype('float32') / 255.
X_test = X_test.reshape(10000, 28, 28, 1).astype('float32') / 255.

# %% [markdown]
# ### Active Learning Procedure

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=198,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for exp_iter in range(EXPERIMENT_COUNT):
    np.random.seed(exp_iter)
    initial_idx = np.array([],dtype=int)
    for i in range(10):
        idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
        initial_idx = np.concatenate((initial_idx, idx))
    print(initial_idx)
    for func_name, acquisition_func in ACQ_FUNCS.items():  
        X_initial = X_train[initial_idx]
        y_initial = y_train[initial_idx]

        X_pool = np.delete(X_train, initial_idx, axis=0)
        y_pool = np.delete(y_train, initial_idx, axis=0)

        model = MLP_REG().to(DEVICE)

        estimator = NeuralNetClassifier(model,
                                      max_epochs=MAX_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      lr=LEARNING_RATE,
                                      optimizer=torch.optim.Adam,
                                      criterion=torch.nn.CrossEntropyLoss,
                                      train_split=None,
                                      verbose=0,
                                      device=DEVICE)



        acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                          X_test,
                                                          y_test,
                                                          X_pool,
                                                              y_pool,
                                                          X_initial,
                                                          y_initial,
                                                          estimator,)
        file_name = os.path.join(results_path, func_name + "_exp_" + str(exp_iter) + ".npy")
        np.save(file_name, (acc_arr, dataset_size_arr))
# Out:
# [13830 52831 48335 40348 50295 38826  2029 16386 51261 39375 49784 13120
#  30968 45157 23526 48622 53817  9345 20389 31834]
# Accuracy after query 1: 0.5884
# Accuracy after query 2: 0.6332
# Accuracy after query 3: 0.6843
# Accuracy after query 4: 0.7275
# Accuracy after query 5: 0.7488
# Accuracy after query 6: 0.7843
# Accuracy after query 7: 0.7915
# Accuracy after query 8: 0.8059
# Accuracy after query 9: 0.8043
# Accuracy after query 10: 0.8088
# Accuracy after query 11: 0.8206
# Accuracy after query 12: 0.8454
# Accuracy after query 13: 0.8368
# Accuracy after query 14: 0.8489
# Accuracy after query 15: 0.8522
# Accuracy after query 16: 0.8573
# Accuracy after query 17: 0.8542
# Accuracy after query 18: 0.8536
# Accuracy after query 19: 0.8701
# Accuracy after query 20: 0.8655
# Accuracy after query 21: 0.8710
# Accuracy after query 22: 0.8732
# Accuracy after query 23: 0.8893
# Accuracy after query 24: 0.8801
# Accuracy after query 25: 0.8829
# Accuracy after query 26: 0.8874
# Accuracy after query 27: 0.8877
# Accuracy after query 28: 0.8878
# Accuracy after query 29: 0.8804
# Accuracy after query 30: 0.8833
# Accuracy after query 31: 0.8867
# Accuracy after query 32: 0.8927
# Accuracy after query 33: 0.9006
# Accuracy after query 34: 0.8970
# Accuracy after query 35: 0.9015
# Accuracy after query 36: 0.9005
# Accuracy after query 37: 0.9021
# Accuracy after query 38: 0.9095
# Accuracy after query 39: 0.9110
# Accuracy after query 40: 0.9183
# Accuracy after query 41: 0.9179
# Accuracy after query 42: 0.9146
# Accuracy after query 43: 0.9143
# Accuracy after query 44: 0.9172
# Accuracy after query 45: 0.9214
# Accuracy after query 46: 0.9235
# Accuracy after query 47: 0.9247
# Accuracy after query 48: 0.9201
# Accuracy after query 49: 0.9271
# Accuracy after query 50: 0.9188
# Accuracy after query 51: 0.9274
# Accuracy after query 52: 0.9169
# Accuracy after query 53: 0.9238
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pinar\AppData\Local\Temp/ipykernel_8316/2020748713.py", line 29, in <module>
#     acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
#   File "C:\Users\pinar\AppData\Local\Temp/ipykernel_8316/1328085363.py", line 24, in active_learning_procedure
#     model_accuracy = learner.score(X_test, y_test)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py", line 275, in score
#     return self.estimator.score(X, y, **score_kwargs)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\sklearn\base.py", line 646, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py", line 208, in predict
#     return self.predict_proba(X).argmax(axis=1)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py", line 176, in predict_proba
#     return super().predict_proba(X)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py", line 1433, in predict_proba
#     for yp in self.forward_iter(X, training=False):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py", line 1278, in forward_iter
#     for batch in iterator:
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\utils\data\dataloader.py", line 534, in __next__
#     return data
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\autograd\profiler.py", line 440, in __exit__
#     torch.ops.profiler._record_function_exit(self.handle)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pinar\AppData\Local\Temp/ipykernel_8316/2020748713.py", line 29, in <module>
#     acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
#   File "C:\Users\pinar\AppData\Local\Temp/ipykernel_8316/1328085363.py", line 24, in active_learning_procedure
#     model_accuracy = learner.score(X_test, y_test)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py", line 275, in score
#     return self.estimator.score(X, y, **score_kwargs)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\sklearn\base.py", line 646, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py", line 208, in predict
#     return self.predict_proba(X).argmax(axis=1)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py", line 176, in predict_proba
#     return super().predict_proba(X)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py", line 1433, in predict_proba
#     for yp in self.forward_iter(X, training=False):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py", line 1278, in forward_iter
#     for batch in iterator:
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\utils\data\dataloader.py", line 534, in __next__
#     return data
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\autograd\profiler.py", line 440, in __exit__
#     torch.ops.profiler._record_function_exit(self.handle)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "c:\users\pinar\appdata\local\programs\python\python38\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_8316/2020748713.py in <module>
#      28
# ---> 29         acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
#      30                                                           X_test,
#
# ~\AppData\Local\Temp/ipykernel_8316/1328085363.py in active_learning_procedure(query_strategy, X_test, y_test, X_pool, y_pool, X_initial, y_initial, estimator, n_queries, n_instances)
#      23         y_pool = np.delete(y_pool, query_idx, axis=0)
# ---> 24         model_accuracy = learner.score(X_test, y_test)
#      25         pool_size = pool_size + n_instances
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\modAL\models\base.py in score(self, X, y, **score_kwargs)
#     274         """
# --> 275         return self.estimator.score(X, y, **score_kwargs)
#     276
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     645
# --> 646         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     647
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py in predict(self, X)
#     207         """
# --> 208         return self.predict_proba(X).argmax(axis=1)
#     209
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\classifier.py in predict_proba(self, X)
#     175         # pylint: disable=useless-super-delegation
# --> 176         return super().predict_proba(X)
#     177
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in predict_proba(self, X)
#    1432         y_probas = []
# -> 1433         for yp in self.forward_iter(X, training=False):
#    1434             yp = yp[0] if isinstance(yp, tuple) else yp
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\skorch\net.py in forward_iter(self, X, training, device)
#    1277         iterator = self.get_iterator(dataset, training=training)
# -> 1278         for batch in iterator:
#    1279             yp = self.evaluation_step(batch, training=training)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     533                 warnings.warn(warn_msg)
# --> 534             return data
#     535
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\torch\autograd\profiler.py in __exit__(self, exc_type, exc_value, traceback)
#     439         if self.run_callbacks_on_exit:
# --> 440             torch.ops.profiler._record_function_exit(self.handle)
#     441
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3363                         asy = compare(code)
# -> 3364                     if (await self.run_code(code, result,  async_=asy)):
#    3365                         return True
#
#     [... skipping hidden 1 frame]
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3170                     interactivity = 'async'
#    3171
# -> 3172                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3173                        interactivity=interactivity, compiler=compiler, result=result)
#    3174
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3381             if result:
#    3382                 result.error_before_exec = sys.exc_info()[1]
# -> 3383             self.showtraceback()
#    3384             return True
#    3385
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\users\pinar\onedrive\masaüstü\masterthesis\msthesisenv\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
