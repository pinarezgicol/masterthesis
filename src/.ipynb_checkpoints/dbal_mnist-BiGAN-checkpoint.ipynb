# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import mnist

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
LATENT_DIMS = [64]
LATENT_DIM = 64
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\mnist_bigan_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
    #"batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self, latent_dim):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = (X_train.astype(np.float32)) / 255.
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = (X_test.astype(np.float32)) / 255.
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_train_enhanced_bigan.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_test_enhanced_bigan.npy")

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for latent_dim in LATENT_DIMS:
    for exp_iter in range(EXPERIMENT_COUNT):
        np.random.seed(exp_iter)
        initial_idx = np.array([],dtype=int)
        for i in range(10):
            idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
            initial_idx = np.concatenate((initial_idx, idx))

        for func_name, acquisition_func in ACQ_FUNCS.items():  

            X_initial = X_train_enhanced[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = MLP_REG(latent_dim).to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test_enhanced,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
        for func_name, acquisition_func in ACQ_FUNCS.items():  
            X_initial = X_train[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = MLP_REG(ORIGINAL_DIM).to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join("results\\mnist_dbal", "{func_name}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
# Out:
# Accuracy after query 1: 0.4341
# Accuracy after query 2: 0.5018
# Accuracy after query 3: 0.5257
# Accuracy after query 4: 0.5431
# Accuracy after query 5: 0.5748
# Accuracy after query 6: 0.6214
# Accuracy after query 7: 0.6421
# Accuracy after query 8: 0.6683
# Accuracy after query 9: 0.6618
# Accuracy after query 10: 0.6769
# Accuracy after query 11: 0.6936
# Accuracy after query 12: 0.7144
# Accuracy after query 13: 0.7145
# Accuracy after query 14: 0.7424
# Accuracy after query 15: 0.7566
# Accuracy after query 16: 0.7610
# Accuracy after query 17: 0.7710
# Accuracy after query 18: 0.7777
# Accuracy after query 19: 0.7720
# Accuracy after query 20: 0.7871
# Accuracy after query 21: 0.7865
# Accuracy after query 22: 0.7788
# Accuracy after query 23: 0.7926
# Accuracy after query 24: 0.7977
# Accuracy after query 25: 0.8095
# Accuracy after query 26: 0.8030
# Accuracy after query 27: 0.8098
# Accuracy after query 28: 0.8072
# Accuracy after query 29: 0.8230
# Accuracy after query 30: 0.8204
# Accuracy after query 31: 0.8305
# Accuracy after query 32: 0.8242
# Accuracy after query 33: 0.8237
# Accuracy after query 34: 0.8356
# Accuracy after query 35: 0.8385
# Accuracy after query 36: 0.8393
# Accuracy after query 37: 0.8421
# Accuracy after query 38: 0.8401
# Accuracy after query 39: 0.8408
# Accuracy after query 40: 0.8434
# Accuracy after query 41: 0.8429
# Accuracy after query 42: 0.8543
# Accuracy after query 43: 0.8476
# Accuracy after query 44: 0.8508
# Accuracy after query 45: 0.8513
# Accuracy after query 46: 0.8559
# Accuracy after query 47: 0.8581
# Accuracy after query 48: 0.8583
# Accuracy after query 49: 0.8623
# Accuracy after query 50: 0.8625
# Accuracy after query 51: 0.8631
# Accuracy after query 52: 0.8660
# Accuracy after query 53: 0.8639
# Accuracy after query 54: 0.8613
# Accuracy after query 55: 0.8596
# Accuracy after query 56: 0.8633
# Accuracy after query 57: 0.8677
# Accuracy after query 58: 0.8646
# Accuracy after query 59: 0.8723
# Accuracy after query 60: 0.8686
# Accuracy after query 61: 0.8743
# Accuracy after query 62: 0.8750
# Accuracy after query 63: 0.8713
# Accuracy after query 64: 0.8717
# Accuracy after query 65: 0.8697
# Accuracy after query 66: 0.8753
# Accuracy after query 67: 0.8664
# Accuracy after query 68: 0.8794
# Accuracy after query 69: 0.8801
# Accuracy after query 70: 0.8819
# Accuracy after query 71: 0.8710
# Accuracy after query 72: 0.8717
# Accuracy after query 73: 0.8813
# Accuracy after query 74: 0.8781
# Accuracy after query 75: 0.8762
# Accuracy after query 76: 0.8768
# Accuracy after query 77: 0.8782
# Accuracy after query 78: 0.8820
# Accuracy after query 79: 0.8744
# Accuracy after query 80: 0.8850
# Accuracy after query 81: 0.8838
# Accuracy after query 82: 0.8837
# Accuracy after query 83: 0.8842
# Accuracy after query 84: 0.8821
# Accuracy after query 85: 0.8818
# Accuracy after query 86: 0.8873
# Accuracy after query 87: 0.8870
# Accuracy after query 88: 0.8897
# Accuracy after query 89: 0.8916
# Accuracy after query 90: 0.8872
# Accuracy after query 91: 0.8900
# Accuracy after query 92: 0.8883
# Accuracy after query 93: 0.8901
# Accuracy after query 94: 0.8858
# Accuracy after query 95: 0.8979
# Accuracy after query 96: 0.8941
# Accuracy after query 97: 0.8921
# Accuracy after query 98: 0.8935
# Accuracy after query 1: 0.4437
# Accuracy after query 2: 0.4972
# Accuracy after query 3: 0.5027
# Accuracy after query 4: 0.5439
# Accuracy after query 5: 0.5664
# Accuracy after query 6: 0.5881
# Accuracy after query 7: 0.5966
# Accuracy after query 8: 0.6377
# Accuracy after query 9: 0.6584
# Accuracy after query 10: 0.6778
# Accuracy after query 11: 0.6856
# Accuracy after query 12: 0.6872
# Accuracy after query 13: 0.7086
# Accuracy after query 14: 0.7093
# Accuracy after query 15: 0.7087
# Accuracy after query 16: 0.7306
# Accuracy after query 17: 0.7304
# Accuracy after query 18: 0.7354
# Accuracy after query 19: 0.7293
# Accuracy after query 20: 0.7420
# Accuracy after query 21: 0.7467
# Accuracy after query 22: 0.7530
# Accuracy after query 23: 0.7623
# Accuracy after query 24: 0.7739
# Accuracy after query 25: 0.7951
# Accuracy after query 26: 0.7814
# Accuracy after query 27: 0.7781
# Accuracy after query 28: 0.7888
# Accuracy after query 29: 0.7935
# Accuracy after query 30: 0.8046
# Accuracy after query 31: 0.8049
# Accuracy after query 32: 0.8084
# Accuracy after query 33: 0.8183
# Accuracy after query 34: 0.8103
# Accuracy after query 35: 0.8170
# Accuracy after query 36: 0.8256
# Accuracy after query 37: 0.8315
# Accuracy after query 38: 0.8443
# Accuracy after query 39: 0.8389
# Accuracy after query 40: 0.8373
# Accuracy after query 41: 0.8432
# Accuracy after query 42: 0.8229
# Accuracy after query 43: 0.8276
# Accuracy after query 44: 0.8356
# Accuracy after query 45: 0.8364
# Accuracy after query 46: 0.8395
# Accuracy after query 47: 0.8386
# Accuracy after query 48: 0.8462
# Accuracy after query 49: 0.8473
# Accuracy after query 50: 0.8483
# Accuracy after query 51: 0.8519
# Accuracy after query 52: 0.8548
# Accuracy after query 53: 0.8480
# Accuracy after query 54: 0.8576
# Accuracy after query 55: 0.8553
# Accuracy after query 56: 0.8571
# Accuracy after query 57: 0.8603
# Accuracy after query 58: 0.8550
# Accuracy after query 59: 0.8699
# Accuracy after query 60: 0.8684
# Accuracy after query 61: 0.8685
# Accuracy after query 62: 0.8661
# Accuracy after query 63: 0.8644
# Accuracy after query 64: 0.8674
# Accuracy after query 65: 0.8665
# Accuracy after query 66: 0.8681
# Accuracy after query 67: 0.8591
# Accuracy after query 68: 0.8714
# Accuracy after query 69: 0.8615
# Accuracy after query 70: 0.8731
# Accuracy after query 71: 0.8741
# Accuracy after query 72: 0.8744
# Accuracy after query 73: 0.8772
# Accuracy after query 74: 0.8708
# Accuracy after query 75: 0.8756
# Accuracy after query 76: 0.8755
# Accuracy after query 77: 0.8758
# Accuracy after query 78: 0.8729
# Accuracy after query 79: 0.8727
# Accuracy after query 80: 0.8734
# Accuracy after query 81: 0.8781
# Accuracy after query 82: 0.8727
# Accuracy after query 83: 0.8729
# Accuracy after query 84: 0.8704
# Accuracy after query 85: 0.8700
# Accuracy after query 86: 0.8784
# Accuracy after query 87: 0.8749
# Accuracy after query 88: 0.8744
# Accuracy after query 89: 0.8858
# Accuracy after query 90: 0.8824
# Accuracy after query 91: 0.8846
# Accuracy after query 92: 0.8838
# Accuracy after query 93: 0.8842
# Accuracy after query 94: 0.8802
# Accuracy after query 95: 0.8778
# Accuracy after query 96: 0.8768
# Accuracy after query 97: 0.8787
# Accuracy after query 98: 0.8780
# Accuracy after query 1: 0.4497
# Accuracy after query 2: 0.4643
# Accuracy after query 3: 0.5020
# Accuracy after query 4: 0.5771
# Accuracy after query 5: 0.6302
# Accuracy after query 6: 0.6498
# Accuracy after query 7: 0.6675
# Accuracy after query 8: 0.6539
# Accuracy after query 9: 0.6792
# Accuracy after query 10: 0.6892
# Accuracy after query 11: 0.6878
# Accuracy after query 12: 0.6912
# Accuracy after query 13: 0.7001
# Accuracy after query 14: 0.7099
# Accuracy after query 15: 0.7450
# Accuracy after query 16: 0.7394
# Accuracy after query 17: 0.7302
# Accuracy after query 18: 0.7270
# Accuracy after query 19: 0.7413
# Accuracy after query 20: 0.7502
# Accuracy after query 21: 0.7655
# Accuracy after query 22: 0.7473
# Accuracy after query 23: 0.7657
# Accuracy after query 24: 0.7733
# Accuracy after query 25: 0.7825
# Accuracy after query 26: 0.7673
# Accuracy after query 27: 0.7817
# Accuracy after query 28: 0.7788
# Accuracy after query 29: 0.7883
# Accuracy after query 30: 0.7901
# Accuracy after query 31: 0.7910
# Accuracy after query 32: 0.7962
# Accuracy after query 33: 0.7998
# Accuracy after query 34: 0.8023
# Accuracy after query 35: 0.7889
# Accuracy after query 36: 0.8110
# Accuracy after query 37: 0.8169
# Accuracy after query 38: 0.8160
# Accuracy after query 39: 0.8084
# Accuracy after query 40: 0.8116
# Accuracy after query 41: 0.8159
# Accuracy after query 42: 0.8157
# Accuracy after query 43: 0.8111
# Accuracy after query 44: 0.8121
# Accuracy after query 45: 0.8253
# Accuracy after query 46: 0.8208
# Accuracy after query 47: 0.8192
# Accuracy after query 48: 0.8266
# Accuracy after query 49: 0.8343
# Accuracy after query 50: 0.8338
# Accuracy after query 51: 0.8412
# Accuracy after query 52: 0.8416
# Accuracy after query 53: 0.8376
# Accuracy after query 54: 0.8384
# Accuracy after query 55: 0.8467
# Accuracy after query 56: 0.8474
# Accuracy after query 57: 0.8452
# Accuracy after query 58: 0.8468
# Accuracy after query 59: 0.8460
# Accuracy after query 60: 0.8562
# Accuracy after query 61: 0.8503
# Accuracy after query 62: 0.8592
# Accuracy after query 63: 0.8604
# Accuracy after query 64: 0.8575
# Accuracy after query 65: 0.8651
# Accuracy after query 66: 0.8659
# Accuracy after query 67: 0.8633
# Accuracy after query 68: 0.8675
# Accuracy after query 69: 0.8620
# Accuracy after query 70: 0.8600
# Accuracy after query 71: 0.8642
# Accuracy after query 72: 0.8646
# Accuracy after query 73: 0.8632
# Accuracy after query 74: 0.8641
# Accuracy after query 75: 0.8680
# Accuracy after query 76: 0.8729
# Accuracy after query 77: 0.8769
# Accuracy after query 78: 0.8810
# Accuracy after query 79: 0.8756
# Accuracy after query 80: 0.8763
# Accuracy after query 81: 0.8793
# Accuracy after query 82: 0.8774
# Accuracy after query 83: 0.8817
# Accuracy after query 84: 0.8709
# Accuracy after query 85: 0.8783
# Accuracy after query 86: 0.8813
# Accuracy after query 87: 0.8924
# Accuracy after query 88: 0.8907
# Accuracy after query 89: 0.8843
# Accuracy after query 90: 0.8830
# Accuracy after query 91: 0.8819
# Accuracy after query 92: 0.8862
# Accuracy after query 93: 0.8885
# Accuracy after query 94: 0.8874
# Accuracy after query 95: 0.8890
# Accuracy after query 96: 0.8835
# Accuracy after query 97: 0.8904
# Accuracy after query 98: 0.8869
# Accuracy after query 1: 0.4227
# Accuracy after query 2: 0.4325
# Accuracy after query 3: 0.4616
# Accuracy after query 4: 0.4791
# Accuracy after query 5: 0.5287
# Accuracy after query 6: 0.5449
# Accuracy after query 7: 0.5698
# Accuracy after query 8: 0.6019
# Accuracy after query 9: 0.6124
# Accuracy after query 10: 0.6232
# Accuracy after query 11: 0.6492
# Accuracy after query 12: 0.6807
# Accuracy after query 13: 0.6808
# Accuracy after query 14: 0.7071
# Accuracy after query 15: 0.7042
# Accuracy after query 16: 0.7031
# Accuracy after query 17: 0.7205
# Accuracy after query 18: 0.7155
# Accuracy after query 19: 0.7216
# Accuracy after query 20: 0.7366
# Accuracy after query 21: 0.7339
# Accuracy after query 22: 0.7330
# Accuracy after query 23: 0.7453
# Accuracy after query 24: 0.7410
# Accuracy after query 25: 0.7475
# Accuracy after query 26: 0.7689
# Accuracy after query 27: 0.7671
# Accuracy after query 28: 0.7827
# Accuracy after query 29: 0.7845
# Accuracy after query 30: 0.7963
# Accuracy after query 31: 0.7990
# Accuracy after query 32: 0.8023
# Accuracy after query 33: 0.8117
# Accuracy after query 34: 0.7984
# Accuracy after query 35: 0.8236
# Accuracy after query 36: 0.8116
# Accuracy after query 37: 0.8124
# Accuracy after query 38: 0.8171
# Accuracy after query 39: 0.8331
# Accuracy after query 40: 0.8299
# Accuracy after query 41: 0.8271
# Accuracy after query 42: 0.8311
# Accuracy after query 43: 0.8378
# Accuracy after query 44: 0.8342
# Accuracy after query 45: 0.8357
# Accuracy after query 46: 0.8429
# Accuracy after query 47: 0.8463
# Accuracy after query 48: 0.8503
# Accuracy after query 49: 0.8405
# Accuracy after query 50: 0.8459
# Accuracy after query 51: 0.8585
# Accuracy after query 52: 0.8521
# Accuracy after query 53: 0.8623
# Accuracy after query 54: 0.8557
# Accuracy after query 55: 0.8548
# Accuracy after query 56: 0.8588
# Accuracy after query 57: 0.8550
# Accuracy after query 58: 0.8569
# Accuracy after query 59: 0.8537
# Accuracy after query 60: 0.8611
# Accuracy after query 61: 0.8631
# Accuracy after query 62: 0.8642
# Accuracy after query 63: 0.8599
# Accuracy after query 64: 0.8743
# Accuracy after query 65: 0.8680
# Accuracy after query 66: 0.8728
# Accuracy after query 67: 0.8687
# Accuracy after query 68: 0.8685
# Accuracy after query 69: 0.8706
# Accuracy after query 70: 0.8718
# Accuracy after query 71: 0.8750
# Accuracy after query 72: 0.8834
# Accuracy after query 73: 0.8756
# Accuracy after query 74: 0.8781
# Accuracy after query 75: 0.8794
# Accuracy after query 76: 0.8825
# Accuracy after query 77: 0.8752
# Accuracy after query 78: 0.8796
# Accuracy after query 79: 0.8816
# Accuracy after query 80: 0.8883
# Accuracy after query 81: 0.8762
# Accuracy after query 82: 0.8838
# Accuracy after query 83: 0.8798
# Accuracy after query 84: 0.8699
# Accuracy after query 85: 0.8816
# Accuracy after query 86: 0.8721
# Accuracy after query 87: 0.8800
# Accuracy after query 88: 0.8789
# Accuracy after query 89: 0.8800
# Accuracy after query 90: 0.8785
# Accuracy after query 91: 0.8763
# Accuracy after query 92: 0.8736
# Accuracy after query 93: 0.8772
# Accuracy after query 94: 0.8770
# Accuracy after query 95: 0.8757
# Accuracy after query 96: 0.8738
# Accuracy after query 97: 0.8712
# Accuracy after query 98: 0.8832
# Accuracy after query 1: 0.4436
# Accuracy after query 2: 0.4712
# Accuracy after query 3: 0.5451
# Accuracy after query 4: 0.5856
# Accuracy after query 5: 0.6337
# Accuracy after query 6: 0.6466
# Accuracy after query 7: 0.6376
# Accuracy after query 8: 0.6557
# Accuracy after query 9: 0.6718
# Accuracy after query 10: 0.6810
# Accuracy after query 11: 0.6862
# Accuracy after query 12: 0.6844
# Accuracy after query 13: 0.7026
# Accuracy after query 14: 0.7029
# Accuracy after query 15: 0.7183
# Accuracy after query 16: 0.7252
# Accuracy after query 17: 0.7338
# Accuracy after query 18: 0.7344
# Accuracy after query 19: 0.7427
# Accuracy after query 20: 0.7594
# Accuracy after query 21: 0.7646
# Accuracy after query 22: 0.7824
# Accuracy after query 23: 0.7741
# Accuracy after query 24: 0.7511
# Accuracy after query 25: 0.7729
# Accuracy after query 26: 0.7832
# Accuracy after query 27: 0.7842
# Accuracy after query 28: 0.7983
# Accuracy after query 29: 0.7993
# Accuracy after query 30: 0.7961
# Accuracy after query 31: 0.7972
# Accuracy after query 32: 0.8033
# Accuracy after query 33: 0.7973
# Accuracy after query 34: 0.7995
# Accuracy after query 35: 0.8000
# Accuracy after query 36: 0.7929
# Accuracy after query 37: 0.8100
# Accuracy after query 38: 0.8086
# Accuracy after query 39: 0.8091
# Accuracy after query 40: 0.8220
# Accuracy after query 41: 0.8212
# Accuracy after query 42: 0.8188
# Accuracy after query 43: 0.8068
# Accuracy after query 44: 0.8121
# Accuracy after query 45: 0.8192
# Accuracy after query 46: 0.8239
# Accuracy after query 47: 0.8250
# Accuracy after query 48: 0.8249
# Accuracy after query 49: 0.8225
# Accuracy after query 50: 0.8236
# Accuracy after query 51: 0.8339
# Accuracy after query 52: 0.8332
# Accuracy after query 53: 0.8280
# Accuracy after query 54: 0.8281
# Accuracy after query 55: 0.8422
# Accuracy after query 56: 0.8407
# Accuracy after query 57: 0.8439
# Accuracy after query 58: 0.8391
# Accuracy after query 59: 0.8398
# Accuracy after query 60: 0.8395
# Accuracy after query 61: 0.8518
# Accuracy after query 62: 0.8469
# Accuracy after query 63: 0.8521
# Accuracy after query 64: 0.8578
# Accuracy after query 65: 0.8555
# Accuracy after query 66: 0.8569
# Accuracy after query 67: 0.8582
# Accuracy after query 68: 0.8529
# Accuracy after query 69: 0.8594
# Accuracy after query 70: 0.8592
# Accuracy after query 71: 0.8531
# Accuracy after query 72: 0.8464
# Accuracy after query 73: 0.8531
# Accuracy after query 74: 0.8606
# Accuracy after query 75: 0.8625
# Accuracy after query 76: 0.8566
# Accuracy after query 77: 0.8578
# Accuracy after query 78: 0.8581
# Accuracy after query 79: 0.8564
# Accuracy after query 80: 0.8663
# Accuracy after query 81: 0.8581
# Accuracy after query 82: 0.8664
# Accuracy after query 83: 0.8595
# Accuracy after query 84: 0.8647
# Accuracy after query 85: 0.8645
# Accuracy after query 86: 0.8671
# Accuracy after query 87: 0.8651
# Accuracy after query 88: 0.8669
# Accuracy after query 89: 0.8630
# Accuracy after query 90: 0.8665
# Accuracy after query 91: 0.8632
# Accuracy after query 92: 0.8657
# Accuracy after query 93: 0.8667
# Accuracy after query 94: 0.8703
# Accuracy after query 95: 0.8680
# Accuracy after query 96: 0.8680
# Accuracy after query 97: 0.8699
# Accuracy after query 98: 0.8691
# Accuracy after query 1: 0.4224
# Accuracy after query 2: 0.5252
# Accuracy after query 3: 0.5745
# Accuracy after query 4: 0.5958
# Accuracy after query 5: 0.6411
# Accuracy after query 6: 0.6516
# Accuracy after query 7: 0.6659
# Accuracy after query 8: 0.6657
# Accuracy after query 9: 0.6745
# Accuracy after query 10: 0.6716
# Accuracy after query 11: 0.6892
# Accuracy after query 12: 0.7138
# Accuracy after query 13: 0.7199
# Accuracy after query 14: 0.7353
# Accuracy after query 15: 0.7250
# Accuracy after query 16: 0.7319
# Accuracy after query 17: 0.7386
# Accuracy after query 18: 0.7443
# Accuracy after query 19: 0.7528
# Accuracy after query 20: 0.7487
# Accuracy after query 21: 0.7726
# Accuracy after query 22: 0.7864
# Accuracy after query 23: 0.7681
# Accuracy after query 24: 0.7749
# Accuracy after query 25: 0.7995
# Accuracy after query 26: 0.7889
# Accuracy after query 27: 0.8029
# Accuracy after query 28: 0.8057
# Accuracy after query 29: 0.8005
# Accuracy after query 30: 0.7879
# Accuracy after query 31: 0.8137
# Accuracy after query 32: 0.8240
# Accuracy after query 33: 0.8055
# Accuracy after query 34: 0.8213
# Accuracy after query 35: 0.8314
# Accuracy after query 36: 0.8331
# Accuracy after query 37: 0.8367
# Accuracy after query 38: 0.8364
# Accuracy after query 39: 0.8346
# Accuracy after query 40: 0.8303
# Accuracy after query 41: 0.8417
# Accuracy after query 42: 0.8453
# Accuracy after query 43: 0.8457
# Accuracy after query 44: 0.8555
# Accuracy after query 45: 0.8550
# Accuracy after query 46: 0.8470
# Accuracy after query 47: 0.8459
# Accuracy after query 48: 0.8489
# Accuracy after query 49: 0.8558
# Accuracy after query 50: 0.8585
# Accuracy after query 51: 0.8571
# Accuracy after query 52: 0.8675
# Accuracy after query 53: 0.8634
# Accuracy after query 54: 0.8673
# Accuracy after query 55: 0.8734
# Accuracy after query 56: 0.8707
# Accuracy after query 57: 0.8664
# Accuracy after query 58: 0.8730
# Accuracy after query 59: 0.8723
# Accuracy after query 60: 0.8647
# Accuracy after query 61: 0.8727
# Accuracy after query 62: 0.8718
# Accuracy after query 63: 0.8732
# Accuracy after query 64: 0.8678
# Accuracy after query 65: 0.8714
# Accuracy after query 66: 0.8724
# Accuracy after query 67: 0.8658
# Accuracy after query 68: 0.8747
# Accuracy after query 69: 0.8774
# Accuracy after query 70: 0.8764
# Accuracy after query 71: 0.8815
# Accuracy after query 72: 0.8774
# Accuracy after query 73: 0.8869
# Accuracy after query 74: 0.8886
# Accuracy after query 75: 0.8900
# Accuracy after query 76: 0.8912
# Accuracy after query 77: 0.8776
# Accuracy after query 78: 0.8880
# Accuracy after query 79: 0.8900
# Accuracy after query 80: 0.8910
# Accuracy after query 81: 0.8810
# Accuracy after query 82: 0.8794
# Accuracy after query 83: 0.8870
# Accuracy after query 84: 0.8886
# Accuracy after query 85: 0.8857
# Accuracy after query 86: 0.8843
# Accuracy after query 87: 0.8889
# Accuracy after query 88: 0.8834
# Accuracy after query 89: 0.8839
# Accuracy after query 90: 0.8862
# Accuracy after query 91: 0.8930
# Accuracy after query 92: 0.8889
# Accuracy after query 93: 0.8968
# Accuracy after query 94: 0.8926
# Accuracy after query 95: 0.8922
# Accuracy after query 96: 0.8956
# Accuracy after query 97: 0.8934
# Accuracy after query 98: 0.8912
# Accuracy after query 1: 0.4408
# Accuracy after query 2: 0.4600
# Accuracy after query 3: 0.4929
# Accuracy after query 4: 0.5244
# Accuracy after query 5: 0.5269
# Accuracy after query 6: 0.5628
# Accuracy after query 7: 0.5988
# Accuracy after query 8: 0.6532
# Accuracy after query 9: 0.6754
# Accuracy after query 10: 0.6916
# Accuracy after query 11: 0.6944
# Accuracy after query 12: 0.7056
# Accuracy after query 13: 0.7189
# Accuracy after query 14: 0.7238
# Accuracy after query 15: 0.7381
# Accuracy after query 16: 0.7476
# Accuracy after query 17: 0.7368
# Accuracy after query 18: 0.7461
# Accuracy after query 19: 0.7553
# Accuracy after query 20: 0.7637
# Accuracy after query 21: 0.7715
# Accuracy after query 22: 0.7694
# Accuracy after query 23: 0.7676
# Accuracy after query 24: 0.7689
# Accuracy after query 25: 0.7856
# Accuracy after query 26: 0.7841
# Accuracy after query 27: 0.7814
# Accuracy after query 28: 0.8003
# Accuracy after query 29: 0.8125
# Accuracy after query 30: 0.8106
# Accuracy after query 31: 0.8139
# Accuracy after query 32: 0.8221
# Accuracy after query 33: 0.8196
# Accuracy after query 34: 0.8179
# Accuracy after query 35: 0.8105
# Accuracy after query 36: 0.8292
# Accuracy after query 37: 0.8329
# Accuracy after query 38: 0.8406
# Accuracy after query 39: 0.8298
# Accuracy after query 40: 0.8432
# Accuracy after query 41: 0.8354
# Accuracy after query 42: 0.8495
# Accuracy after query 43: 0.8439
# Accuracy after query 44: 0.8538
# Accuracy after query 45: 0.8530
# Accuracy after query 46: 0.8554
# Accuracy after query 47: 0.8440
# Accuracy after query 48: 0.8549
# Accuracy after query 49: 0.8563
# Accuracy after query 50: 0.8480
# Accuracy after query 51: 0.8633
# Accuracy after query 52: 0.8506
# Accuracy after query 53: 0.8645
# Accuracy after query 54: 0.8569
# Accuracy after query 55: 0.8641
# Accuracy after query 56: 0.8675
# Accuracy after query 57: 0.8689
# Accuracy after query 58: 0.8618
# Accuracy after query 59: 0.8721
# Accuracy after query 60: 0.8592
# Accuracy after query 61: 0.8672
# Accuracy after query 62: 0.8677
# Accuracy after query 63: 0.8714
# Accuracy after query 64: 0.8731
# Accuracy after query 65: 0.8602
# Accuracy after query 66: 0.8722
# Accuracy after query 67: 0.8805
# Accuracy after query 68: 0.8774
# Accuracy after query 69: 0.8748
# Accuracy after query 70: 0.8633
# Accuracy after query 71: 0.8727
# Accuracy after query 72: 0.8756
# Accuracy after query 73: 0.8750
# Accuracy after query 74: 0.8742
# Accuracy after query 75: 0.8821
# Accuracy after query 76: 0.8772
# Accuracy after query 77: 0.8804
# Accuracy after query 78: 0.8742
# Accuracy after query 79: 0.8757
# Accuracy after query 80: 0.8808
# Accuracy after query 81: 0.8779
# Accuracy after query 82: 0.8721
# Accuracy after query 83: 0.8842
# Accuracy after query 84: 0.8838
# Accuracy after query 85: 0.8824
# Accuracy after query 86: 0.8859
# Accuracy after query 87: 0.8873
# Accuracy after query 88: 0.8856
# Accuracy after query 89: 0.8828
# Accuracy after query 90: 0.8907
# Accuracy after query 91: 0.8849
# Accuracy after query 92: 0.8861
# Accuracy after query 93: 0.8862
# Accuracy after query 94: 0.8885
# Accuracy after query 95: 0.8793
# Accuracy after query 96: 0.8810
# Accuracy after query 97: 0.8871
# Accuracy after query 98: 0.8777
# Accuracy after query 1: 0.4500
# Accuracy after query 2: 0.4909
# Accuracy after query 3: 0.5176
# Accuracy after query 4: 0.5450
# Accuracy after query 5: 0.5813
# Accuracy after query 6: 0.6033
# Accuracy after query 7: 0.6098
# Accuracy after query 8: 0.6336
# Accuracy after query 9: 0.6595
# Accuracy after query 10: 0.6673
# Accuracy after query 11: 0.6846
# Accuracy after query 12: 0.6899
# Accuracy after query 13: 0.7047
# Accuracy after query 14: 0.7185
# Accuracy after query 15: 0.7294
# Accuracy after query 16: 0.7192
# Accuracy after query 17: 0.7352
# Accuracy after query 18: 0.7372
# Accuracy after query 19: 0.7421
# Accuracy after query 20: 0.7457
# Accuracy after query 21: 0.7538
# Accuracy after query 22: 0.7534
# Accuracy after query 23: 0.7769
# Accuracy after query 24: 0.7878
# Accuracy after query 25: 0.7913
# Accuracy after query 26: 0.7933
# Accuracy after query 27: 0.7811
# Accuracy after query 28: 0.7901
# Accuracy after query 29: 0.7926
# Accuracy after query 30: 0.7994
# Accuracy after query 31: 0.8102
# Accuracy after query 32: 0.8077
# Accuracy after query 33: 0.8138
# Accuracy after query 34: 0.8178
# Accuracy after query 35: 0.8259
# Accuracy after query 36: 0.8231
# Accuracy after query 37: 0.8284
# Accuracy after query 38: 0.8288
# Accuracy after query 39: 0.8229
# Accuracy after query 40: 0.8181
# Accuracy after query 41: 0.8288
# Accuracy after query 42: 0.8393
# Accuracy after query 43: 0.8396
# Accuracy after query 44: 0.8464
# Accuracy after query 45: 0.8485
# Accuracy after query 46: 0.8349
# Accuracy after query 47: 0.8455
# Accuracy after query 48: 0.8561
# Accuracy after query 49: 0.8534
# Accuracy after query 50: 0.8579
# Accuracy after query 51: 0.8543
# Accuracy after query 52: 0.8509
# Accuracy after query 53: 0.8562
# Accuracy after query 54: 0.8556
# Accuracy after query 55: 0.8660
# Accuracy after query 56: 0.8635
# Accuracy after query 57: 0.8628
# Accuracy after query 58: 0.8694
# Accuracy after query 59: 0.8668
# Accuracy after query 60: 0.8756
# Accuracy after query 61: 0.8659
# Accuracy after query 62: 0.8651
# Accuracy after query 63: 0.8641
# Accuracy after query 64: 0.8734
# Accuracy after query 65: 0.8728
# Accuracy after query 66: 0.8699
# Accuracy after query 67: 0.8639
# Accuracy after query 68: 0.8701
# Accuracy after query 69: 0.8695
# Accuracy after query 70: 0.8723
# Accuracy after query 71: 0.8643
# Accuracy after query 72: 0.8717
# Accuracy after query 73: 0.8778
# Accuracy after query 74: 0.8737
# Accuracy after query 75: 0.8749
# Accuracy after query 76: 0.8736
# Accuracy after query 77: 0.8689
# Accuracy after query 78: 0.8753
# Accuracy after query 79: 0.8760
# Accuracy after query 80: 0.8813
# Accuracy after query 81: 0.8812
# Accuracy after query 82: 0.8833
# Accuracy after query 83: 0.8826
# Accuracy after query 84: 0.8821
# Accuracy after query 85: 0.8822
# Accuracy after query 86: 0.8873
# Accuracy after query 87: 0.8861
# Accuracy after query 88: 0.8857
# Accuracy after query 89: 0.8900
# Accuracy after query 90: 0.8898
# Accuracy after query 91: 0.8821
# Accuracy after query 92: 0.8786
# Accuracy after query 93: 0.8869
# Accuracy after query 94: 0.8835
# Accuracy after query 95: 0.8899
# Accuracy after query 96: 0.8868
# Accuracy after query 97: 0.8947
# Accuracy after query 98: 0.8860
# Accuracy after query 1: 0.3880
# Accuracy after query 2: 0.4230
# Accuracy after query 3: 0.4434
# Accuracy after query 4: 0.5087
# Accuracy after query 5: 0.5106
# Accuracy after query 6: 0.5413
# Accuracy after query 7: 0.6013
# Accuracy after query 8: 0.6075
# Accuracy after query 9: 0.6510
# Accuracy after query 10: 0.6734
# Accuracy after query 11: 0.6854
# Accuracy after query 12: 0.6940
# Accuracy after query 13: 0.7101
# Accuracy after query 14: 0.7451
# Accuracy after query 15: 0.7321
# Accuracy after query 16: 0.7442
# Accuracy after query 17: 0.7647
# Accuracy after query 18: 0.7639
# Accuracy after query 19: 0.7687
# Accuracy after query 20: 0.7745
# Accuracy after query 21: 0.7745
# Accuracy after query 22: 0.7810
# Accuracy after query 23: 0.7944
# Accuracy after query 24: 0.7983
# Accuracy after query 25: 0.7979
# Accuracy after query 26: 0.7975
# Accuracy after query 27: 0.8002
# Accuracy after query 28: 0.7990
# Accuracy after query 29: 0.7955
# Accuracy after query 30: 0.8078
# Accuracy after query 31: 0.8124
# Accuracy after query 32: 0.8114
# Accuracy after query 33: 0.8154
# Accuracy after query 34: 0.8079
# Accuracy after query 35: 0.8147
# Accuracy after query 36: 0.8105
# Accuracy after query 37: 0.8151
# Accuracy after query 38: 0.8369
# Accuracy after query 39: 0.8289
# Accuracy after query 40: 0.8326
# Accuracy after query 41: 0.8272
# Accuracy after query 42: 0.8248
# Accuracy after query 43: 0.8379
# Accuracy after query 44: 0.8407
# Accuracy after query 45: 0.8443
# Accuracy after query 46: 0.8382
# Accuracy after query 47: 0.8521
# Accuracy after query 48: 0.8477
# Accuracy after query 49: 0.8451
# Accuracy after query 50: 0.8493
# Accuracy after query 51: 0.8569
# Accuracy after query 52: 0.8558
# Accuracy after query 53: 0.8559
# Accuracy after query 54: 0.8574
# Accuracy after query 55: 0.8641
# Accuracy after query 56: 0.8628
# Accuracy after query 57: 0.8608
# Accuracy after query 58: 0.8647
# Accuracy after query 59: 0.8604
# Accuracy after query 60: 0.8666
# Accuracy after query 61: 0.8668
# Accuracy after query 62: 0.8738
# Accuracy after query 63: 0.8771
# Accuracy after query 64: 0.8796
# Accuracy after query 65: 0.8804
# Accuracy after query 66: 0.8815
# Accuracy after query 67: 0.8759
# Accuracy after query 68: 0.8742
# Accuracy after query 69: 0.8788
# Accuracy after query 70: 0.8818
# Accuracy after query 71: 0.8807
# Accuracy after query 72: 0.8727
# Accuracy after query 73: 0.8755
# Accuracy after query 74: 0.8841
# Accuracy after query 75: 0.8866
# Accuracy after query 76: 0.8861
# Accuracy after query 77: 0.8798
# Accuracy after query 78: 0.8769
# Accuracy after query 79: 0.8806
# Accuracy after query 80: 0.8799
# Accuracy after query 81: 0.8709
# Accuracy after query 82: 0.8733
# Accuracy after query 83: 0.8793
# Accuracy after query 84: 0.8748
# Accuracy after query 85: 0.8757
# Accuracy after query 86: 0.8764
# Accuracy after query 87: 0.8731
# Accuracy after query 88: 0.8814
# Accuracy after query 89: 0.8765
# Accuracy after query 90: 0.8773
# Accuracy after query 91: 0.8792
# Accuracy after query 92: 0.8676
# Accuracy after query 93: 0.8795
# Accuracy after query 94: 0.8766
# Accuracy after query 95: 0.8832
# Accuracy after query 96: 0.8777
# Accuracy after query 97: 0.8725
# Accuracy after query 98: 0.8744
# Accuracy after query 1: 0.4551
# Accuracy after query 2: 0.5363
# Accuracy after query 3: 0.5561
# Accuracy after query 4: 0.5759
# Accuracy after query 5: 0.6092
# Accuracy after query 6: 0.6219
# Accuracy after query 7: 0.6432
# Accuracy after query 8: 0.6431
# Accuracy after query 9: 0.6618
# Accuracy after query 10: 0.6675
# Accuracy after query 11: 0.6870
# Accuracy after query 12: 0.6859
# Accuracy after query 13: 0.6861
# Accuracy after query 14: 0.6869
# Accuracy after query 15: 0.7035
# Accuracy after query 16: 0.7147
# Accuracy after query 17: 0.7094
# Accuracy after query 18: 0.7229
# Accuracy after query 19: 0.7507
# Accuracy after query 20: 0.7493
# Accuracy after query 21: 0.7540
# Accuracy after query 22: 0.7613
# Accuracy after query 23: 0.7529
# Accuracy after query 24: 0.7640
# Accuracy after query 25: 0.7720
# Accuracy after query 26: 0.7753
# Accuracy after query 27: 0.7695
# Accuracy after query 28: 0.7548
# Accuracy after query 29: 0.7903
# Accuracy after query 30: 0.7837
# Accuracy after query 31: 0.7868
# Accuracy after query 32: 0.7888
# Accuracy after query 33: 0.7892
# Accuracy after query 34: 0.7979
# Accuracy after query 35: 0.8010
# Accuracy after query 36: 0.8072
# Accuracy after query 37: 0.8020
# Accuracy after query 38: 0.8104
# Accuracy after query 39: 0.8132
# Accuracy after query 40: 0.7968
# Accuracy after query 41: 0.8141
# Accuracy after query 42: 0.8056
# Accuracy after query 43: 0.8032
# Accuracy after query 44: 0.8115
# Accuracy after query 45: 0.8071
# Accuracy after query 46: 0.8140
# Accuracy after query 47: 0.8173
# Accuracy after query 48: 0.8111
# Accuracy after query 49: 0.8206
# Accuracy after query 50: 0.8289
# Accuracy after query 51: 0.8210
# Accuracy after query 52: 0.8316
# Accuracy after query 53: 0.8264
# Accuracy after query 54: 0.8278
# Accuracy after query 55: 0.8265
# Accuracy after query 56: 0.8228
# Accuracy after query 57: 0.8253
# Accuracy after query 58: 0.8261
# Accuracy after query 59: 0.8289
# Accuracy after query 60: 0.8309
# Accuracy after query 61: 0.8369
# Accuracy after query 62: 0.8325
# Accuracy after query 63: 0.8351
# Accuracy after query 64: 0.8409
# Accuracy after query 65: 0.8455
# Accuracy after query 66: 0.8438
# Accuracy after query 67: 0.8408
# Accuracy after query 68: 0.8310
# Accuracy after query 69: 0.8421
# Accuracy after query 70: 0.8429
# Accuracy after query 71: 0.8470
# Accuracy after query 72: 0.8523
# Accuracy after query 73: 0.8608
# Accuracy after query 74: 0.8598
# Accuracy after query 75: 0.8560
# Accuracy after query 76: 0.8606
# Accuracy after query 77: 0.8592
# Accuracy after query 78: 0.8556
# Accuracy after query 79: 0.8606
# Accuracy after query 80: 0.8527
# Accuracy after query 81: 0.8531
# Accuracy after query 82: 0.8489
# Accuracy after query 83: 0.8529
# Accuracy after query 84: 0.8504
# Accuracy after query 85: 0.8535
# Accuracy after query 86: 0.8564
# Accuracy after query 87: 0.8620
# Accuracy after query 88: 0.8602
# Accuracy after query 89: 0.8648
# Accuracy after query 90: 0.8636
# Accuracy after query 91: 0.8626
# Accuracy after query 92: 0.8674
# Accuracy after query 93: 0.8665
# Accuracy after query 94: 0.8672
# Accuracy after query 95: 0.8670
# Accuracy after query 96: 0.8697
# Accuracy after query 97: 0.8666
# Accuracy after query 98: 0.8690
# Accuracy after query 1: 0.4970
# Accuracy after query 2: 0.5206
# Accuracy after query 3: 0.5518
# Accuracy after query 4: 0.5815
# Accuracy after query 5: 0.6197
# Accuracy after query 6: 0.6411
# Accuracy after query 7: 0.6680
# Accuracy after query 8: 0.6659
# Accuracy after query 9: 0.6964
# Accuracy after query 10: 0.7011
# Accuracy after query 11: 0.7198
# Accuracy after query 12: 0.7235
# Accuracy after query 13: 0.7235
# Accuracy after query 14: 0.7335
# Accuracy after query 15: 0.7364
# Accuracy after query 16: 0.7582
# Accuracy after query 17: 0.7700
# Accuracy after query 18: 0.7467
# Accuracy after query 19: 0.7642
# Accuracy after query 20: 0.7870
# Accuracy after query 21: 0.7823
# Accuracy after query 22: 0.7967
# Accuracy after query 23: 0.7985
# Accuracy after query 24: 0.8085
# Accuracy after query 25: 0.8035
# Accuracy after query 26: 0.8092
# Accuracy after query 27: 0.8132
# Accuracy after query 28: 0.8160
# Accuracy after query 29: 0.8233
# Accuracy after query 30: 0.8210
# Accuracy after query 31: 0.8290
# Accuracy after query 32: 0.8268
# Accuracy after query 33: 0.8277
# Accuracy after query 34: 0.8289
# Accuracy after query 35: 0.8365
# Accuracy after query 36: 0.8321
# Accuracy after query 37: 0.8499
# Accuracy after query 38: 0.8446
# Accuracy after query 39: 0.8435
# Accuracy after query 40: 0.8332
# Accuracy after query 41: 0.8436
# Accuracy after query 42: 0.8572
# Accuracy after query 43: 0.8611
# Accuracy after query 44: 0.8531
# Accuracy after query 45: 0.8493
# Accuracy after query 46: 0.8609
# Accuracy after query 47: 0.8572
# Accuracy after query 48: 0.8627
# Accuracy after query 49: 0.8660
# Accuracy after query 50: 0.8682
# Accuracy after query 51: 0.8655
# Accuracy after query 52: 0.8657
# Accuracy after query 53: 0.8685
# Accuracy after query 54: 0.8721
# Accuracy after query 55: 0.8745
# Accuracy after query 56: 0.8741
# Accuracy after query 57: 0.8871
# Accuracy after query 58: 0.8819
# Accuracy after query 59: 0.8818
# Accuracy after query 60: 0.8817
# Accuracy after query 61: 0.8831
# Accuracy after query 62: 0.8757
# Accuracy after query 63: 0.8786
# Accuracy after query 64: 0.8790
# Accuracy after query 65: 0.8814
# Accuracy after query 66: 0.8851
# Accuracy after query 67: 0.8867
# Accuracy after query 68: 0.8851
# Accuracy after query 69: 0.8868
# Accuracy after query 70: 0.8897
# Accuracy after query 71: 0.8872
# Accuracy after query 72: 0.8830
# Accuracy after query 73: 0.8915
# Accuracy after query 74: 0.8873
# Accuracy after query 75: 0.8935
# Accuracy after query 76: 0.8904
# Accuracy after query 77: 0.8906
# Accuracy after query 78: 0.8920
# Accuracy after query 79: 0.8938
# Accuracy after query 80: 0.8893
# Accuracy after query 81: 0.8933
# Accuracy after query 82: 0.8883
# Accuracy after query 83: 0.8881
# Accuracy after query 84: 0.8951
# Accuracy after query 85: 0.8936
# Accuracy after query 86: 0.8955
# Accuracy after query 87: 0.8969
# Accuracy after query 88: 0.8970
# Accuracy after query 89: 0.8950
# Accuracy after query 90: 0.8939
# Accuracy after query 91: 0.8935
# Accuracy after query 92: 0.8946
# Accuracy after query 93: 0.8990
# Accuracy after query 94: 0.8961
# Accuracy after query 95: 0.8934
# Accuracy after query 96: 0.8926
# Accuracy after query 97: 0.8931
# Accuracy after query 98: 0.8971
# Accuracy after query 1: 0.4422
# Accuracy after query 2: 0.4695
# Accuracy after query 3: 0.4878
# Accuracy after query 4: 0.5091
# Accuracy after query 5: 0.5377
# Accuracy after query 6: 0.5701
# Accuracy after query 7: 0.5911
# Accuracy after query 8: 0.6200
# Accuracy after query 9: 0.6324
# Accuracy after query 10: 0.6490
# Accuracy after query 11: 0.6713
# Accuracy after query 12: 0.6744
# Accuracy after query 13: 0.6754
# Accuracy after query 14: 0.6934
# Accuracy after query 15: 0.6951
# Accuracy after query 16: 0.7226
# Accuracy after query 17: 0.7402
# Accuracy after query 18: 0.7347
# Accuracy after query 19: 0.7252
# Accuracy after query 20: 0.7356
# Accuracy after query 21: 0.7385
# Accuracy after query 22: 0.7364
# Accuracy after query 23: 0.7523
# Accuracy after query 24: 0.7493
# Accuracy after query 25: 0.7653
# Accuracy after query 26: 0.7767
# Accuracy after query 27: 0.7827
# Accuracy after query 28: 0.7863
# Accuracy after query 29: 0.7899
# Accuracy after query 30: 0.7971
# Accuracy after query 31: 0.8014
# Accuracy after query 32: 0.7844
# Accuracy after query 33: 0.7991
# Accuracy after query 34: 0.8001
# Accuracy after query 35: 0.8089
# Accuracy after query 36: 0.7978
# Accuracy after query 37: 0.8197
# Accuracy after query 38: 0.8234
# Accuracy after query 39: 0.8317
# Accuracy after query 40: 0.8272
# Accuracy after query 41: 0.8300
# Accuracy after query 42: 0.8249
# Accuracy after query 43: 0.8269
# Accuracy after query 44: 0.8358
# Accuracy after query 45: 0.8466
# Accuracy after query 46: 0.8453
# Accuracy after query 47: 0.8437
# Accuracy after query 48: 0.8398
# Accuracy after query 49: 0.8405
# Accuracy after query 50: 0.8357
# Accuracy after query 51: 0.8383
# Accuracy after query 52: 0.8399
# Accuracy after query 53: 0.8441
# Accuracy after query 54: 0.8610
# Accuracy after query 55: 0.8571
# Accuracy after query 56: 0.8540
# Accuracy after query 57: 0.8550
# Accuracy after query 58: 0.8628
# Accuracy after query 59: 0.8607
# Accuracy after query 60: 0.8539
# Accuracy after query 61: 0.8643
# Accuracy after query 62: 0.8623
# Accuracy after query 63: 0.8693
# Accuracy after query 64: 0.8651
# Accuracy after query 65: 0.8724
# Accuracy after query 66: 0.8691
# Accuracy after query 67: 0.8786
# Accuracy after query 68: 0.8731
# Accuracy after query 69: 0.8619
# Accuracy after query 70: 0.8700
# Accuracy after query 71: 0.8740
# Accuracy after query 72: 0.8723
# Accuracy after query 73: 0.8741
# Accuracy after query 74: 0.8807
# Accuracy after query 75: 0.8789
# Accuracy after query 76: 0.8803
# Accuracy after query 77: 0.8712
# Accuracy after query 78: 0.8693
# Accuracy after query 79: 0.8780
# Accuracy after query 80: 0.8763
# Accuracy after query 81: 0.8790
# Accuracy after query 82: 0.8781
# Accuracy after query 83: 0.8761
# Accuracy after query 84: 0.8739
# Accuracy after query 85: 0.8688
# Accuracy after query 86: 0.8763
# Accuracy after query 87: 0.8736
# Accuracy after query 88: 0.8761
# Accuracy after query 89: 0.8808
# Accuracy after query 90: 0.8752
# Accuracy after query 91: 0.8753
# Accuracy after query 92: 0.8861
# Accuracy after query 93: 0.8701
# Accuracy after query 94: 0.8711
# Accuracy after query 95: 0.8840
# Accuracy after query 96: 0.8783
# Accuracy after query 97: 0.8787
# Accuracy after query 98: 0.8830
# Accuracy after query 1: 0.4795
# Accuracy after query 2: 0.5305
# Accuracy after query 3: 0.5706
# Accuracy after query 4: 0.5942
# Accuracy after query 5: 0.6375
# Accuracy after query 6: 0.6726
# Accuracy after query 7: 0.6691
# Accuracy after query 8: 0.6674
# Accuracy after query 9: 0.6850
# Accuracy after query 10: 0.6772
# Accuracy after query 11: 0.7195
# Accuracy after query 12: 0.7056
# Accuracy after query 13: 0.7127
# Accuracy after query 14: 0.7507
# Accuracy after query 15: 0.7305
# Accuracy after query 16: 0.7412
# Accuracy after query 17: 0.7507
# Accuracy after query 18: 0.7599
# Accuracy after query 19: 0.7533
# Accuracy after query 20: 0.7657
# Accuracy after query 21: 0.7764
# Accuracy after query 22: 0.7843
# Accuracy after query 23: 0.7798
# Accuracy after query 24: 0.7835
# Accuracy after query 25: 0.7898
# Accuracy after query 26: 0.7973
# Accuracy after query 27: 0.7960
# Accuracy after query 28: 0.8060
# Accuracy after query 29: 0.7976
# Accuracy after query 30: 0.8014
# Accuracy after query 31: 0.8201
# Accuracy after query 32: 0.8166
# Accuracy after query 33: 0.8195
# Accuracy after query 34: 0.8223
# Accuracy after query 35: 0.8116
# Accuracy after query 36: 0.8189
# Accuracy after query 37: 0.8256
# Accuracy after query 38: 0.8302
# Accuracy after query 39: 0.8266
# Accuracy after query 40: 0.8303
# Accuracy after query 41: 0.8208
# Accuracy after query 42: 0.8110
# Accuracy after query 43: 0.8361
# Accuracy after query 44: 0.8309
# Accuracy after query 45: 0.8393
# Accuracy after query 46: 0.8397
# Accuracy after query 47: 0.8369
# Accuracy after query 48: 0.8453
# Accuracy after query 49: 0.8429
# Accuracy after query 50: 0.8444
# Accuracy after query 51: 0.8519
# Accuracy after query 52: 0.8553
# Accuracy after query 53: 0.8500
# Accuracy after query 54: 0.8528
# Accuracy after query 55: 0.8510
# Accuracy after query 56: 0.8562
# Accuracy after query 57: 0.8501
# Accuracy after query 58: 0.8602
# Accuracy after query 59: 0.8585
# Accuracy after query 60: 0.8610
# Accuracy after query 61: 0.8568
# Accuracy after query 62: 0.8582
# Accuracy after query 63: 0.8576
# Accuracy after query 64: 0.8606
# Accuracy after query 65: 0.8619
# Accuracy after query 66: 0.8615
# Accuracy after query 67: 0.8630
# Accuracy after query 68: 0.8646
# Accuracy after query 69: 0.8723
# Accuracy after query 70: 0.8573
# Accuracy after query 71: 0.8638
# Accuracy after query 72: 0.8646
# Accuracy after query 73: 0.8655
# Accuracy after query 74: 0.8673
# Accuracy after query 75: 0.8724
# Accuracy after query 76: 0.8770
# Accuracy after query 77: 0.8753
# Accuracy after query 78: 0.8692
# Accuracy after query 79: 0.8791
# Accuracy after query 80: 0.8737
# Accuracy after query 81: 0.8817
# Accuracy after query 82: 0.8731
# Accuracy after query 83: 0.8760
# Accuracy after query 84: 0.8842
# Accuracy after query 85: 0.8801
# Accuracy after query 86: 0.8811
# Accuracy after query 87: 0.8795
# Accuracy after query 88: 0.8802
# Accuracy after query 89: 0.8856
# Accuracy after query 90: 0.8829
# Accuracy after query 91: 0.8761
# Accuracy after query 92: 0.8799
# Accuracy after query 93: 0.8801
# Accuracy after query 94: 0.8854
# Accuracy after query 95: 0.8880
# Accuracy after query 96: 0.8878
# Accuracy after query 97: 0.8740
# Accuracy after query 98: 0.8811
# Accuracy after query 1: 0.4275
# Accuracy after query 2: 0.4741
# Accuracy after query 3: 0.4892
# Accuracy after query 4: 0.5464
# Accuracy after query 5: 0.5782
# Accuracy after query 6: 0.6148
# Accuracy after query 7: 0.6654
# Accuracy after query 8: 0.6789
# Accuracy after query 9: 0.7017
# Accuracy after query 10: 0.7142
# Accuracy after query 11: 0.7196
# Accuracy after query 12: 0.7453
# Accuracy after query 13: 0.7372
# Accuracy after query 14: 0.7548
# Accuracy after query 15: 0.7651
# Accuracy after query 16: 0.7759
# Accuracy after query 17: 0.7693
# Accuracy after query 18: 0.7971
# Accuracy after query 19: 0.7909
# Accuracy after query 20: 0.7885
# Accuracy after query 21: 0.7826
# Accuracy after query 22: 0.7887
# Accuracy after query 23: 0.7921
# Accuracy after query 24: 0.7963
# Accuracy after query 25: 0.7982
# Accuracy after query 26: 0.8078
# Accuracy after query 27: 0.7932
# Accuracy after query 28: 0.8205
# Accuracy after query 29: 0.8186
# Accuracy after query 30: 0.8293
# Accuracy after query 31: 0.8216
# Accuracy after query 32: 0.8278
# Accuracy after query 33: 0.8388
# Accuracy after query 34: 0.8396
# Accuracy after query 35: 0.8364
# Accuracy after query 36: 0.8449
# Accuracy after query 37: 0.8459
# Accuracy after query 38: 0.8439
# Accuracy after query 39: 0.8559
# Accuracy after query 40: 0.8565
# Accuracy after query 41: 0.8563
# Accuracy after query 42: 0.8516
# Accuracy after query 43: 0.8631
# Accuracy after query 44: 0.8557
# Accuracy after query 45: 0.8640
# Accuracy after query 46: 0.8705
# Accuracy after query 47: 0.8607
# Accuracy after query 48: 0.8658
# Accuracy after query 49: 0.8604
# Accuracy after query 50: 0.8668
# Accuracy after query 51: 0.8674
# Accuracy after query 52: 0.8708
# Accuracy after query 53: 0.8727
# Accuracy after query 54: 0.8785
# Accuracy after query 55: 0.8760
# Accuracy after query 56: 0.8807
# Accuracy after query 57: 0.8820
# Accuracy after query 58: 0.8788
# Accuracy after query 59: 0.8831
# Accuracy after query 60: 0.8842
# Accuracy after query 61: 0.8780
# Accuracy after query 62: 0.8863
# Accuracy after query 63: 0.8839
# Accuracy after query 64: 0.8822
# Accuracy after query 65: 0.8795
# Accuracy after query 66: 0.8847
# Accuracy after query 67: 0.8846
# Accuracy after query 68: 0.8814
# Accuracy after query 69: 0.8858
# Accuracy after query 70: 0.8816
# Accuracy after query 71: 0.8834
# Accuracy after query 72: 0.8885
# Accuracy after query 73: 0.8882
# Accuracy after query 74: 0.8785
# Accuracy after query 75: 0.8909
# Accuracy after query 76: 0.8840
# Accuracy after query 77: 0.8915
# Accuracy after query 78: 0.8846
# Accuracy after query 79: 0.8814
# Accuracy after query 80: 0.8842
# Accuracy after query 81: 0.8776
# Accuracy after query 82: 0.8889
# Accuracy after query 83: 0.8809
# Accuracy after query 84: 0.8835
# Accuracy after query 85: 0.8846
# Accuracy after query 86: 0.8820
# Accuracy after query 87: 0.8757
# Accuracy after query 88: 0.8724
# Accuracy after query 89: 0.8773
# Accuracy after query 90: 0.8798
# Accuracy after query 91: 0.8826
# Accuracy after query 92: 0.8763
# Accuracy after query 93: 0.8717
# Accuracy after query 94: 0.8772
# Accuracy after query 95: 0.8719
# Accuracy after query 96: 0.8793
# Accuracy after query 97: 0.8752
# Accuracy after query 98: 0.8764
# Accuracy after query 1: 0.4371
# Accuracy after query 2: 0.4890
# Accuracy after query 3: 0.5194
# Accuracy after query 4: 0.5474
# Accuracy after query 5: 0.5601
# Accuracy after query 6: 0.6082
# Accuracy after query 7: 0.6285
# Accuracy after query 8: 0.6489
# Accuracy after query 9: 0.6589
# Accuracy after query 10: 0.6805
# Accuracy after query 11: 0.6805
# Accuracy after query 12: 0.7026
# Accuracy after query 13: 0.7203
# Accuracy after query 14: 0.7156
# Accuracy after query 15: 0.7290
# Accuracy after query 16: 0.7282
# Accuracy after query 17: 0.7323
# Accuracy after query 18: 0.7436
# Accuracy after query 19: 0.7559
# Accuracy after query 20: 0.7483
# Accuracy after query 21: 0.7507
# Accuracy after query 22: 0.7763
# Accuracy after query 23: 0.7887
# Accuracy after query 24: 0.7908
# Accuracy after query 25: 0.7943
# Accuracy after query 26: 0.8013
# Accuracy after query 27: 0.7811
# Accuracy after query 28: 0.7972
# Accuracy after query 29: 0.7957
# Accuracy after query 30: 0.7966
# Accuracy after query 31: 0.7984
# Accuracy after query 32: 0.7979
# Accuracy after query 33: 0.8103
# Accuracy after query 34: 0.8014
# Accuracy after query 35: 0.7986
# Accuracy after query 36: 0.8068
# Accuracy after query 37: 0.8220
# Accuracy after query 38: 0.8131
# Accuracy after query 39: 0.8169
# Accuracy after query 40: 0.8150
# Accuracy after query 41: 0.8173
# Accuracy after query 42: 0.8009
# Accuracy after query 43: 0.8096
# Accuracy after query 44: 0.8221
# Accuracy after query 45: 0.8312
# Accuracy after query 46: 0.8237
# Accuracy after query 47: 0.8162
# Accuracy after query 48: 0.8271
# Accuracy after query 49: 0.8268
# Accuracy after query 50: 0.8344
# Accuracy after query 51: 0.8413
# Accuracy after query 52: 0.8368
# Accuracy after query 53: 0.8395
# Accuracy after query 54: 0.8396
# Accuracy after query 55: 0.8378
# Accuracy after query 56: 0.8371
# Accuracy after query 57: 0.8478
# Accuracy after query 58: 0.8414
# Accuracy after query 59: 0.8389
# Accuracy after query 60: 0.8481
# Accuracy after query 61: 0.8509
# Accuracy after query 62: 0.8531
# Accuracy after query 63: 0.8510
# Accuracy after query 64: 0.8533
# Accuracy after query 65: 0.8512
# Accuracy after query 66: 0.8533
# Accuracy after query 67: 0.8516
# Accuracy after query 68: 0.8582
# Accuracy after query 69: 0.8560
# Accuracy after query 70: 0.8620
# Accuracy after query 71: 0.8555
# Accuracy after query 72: 0.8548
# Accuracy after query 73: 0.8618
# Accuracy after query 74: 0.8572
# Accuracy after query 75: 0.8623
# Accuracy after query 76: 0.8622
# Accuracy after query 77: 0.8675
# Accuracy after query 78: 0.8651
# Accuracy after query 79: 0.8681
# Accuracy after query 80: 0.8698
# Accuracy after query 81: 0.8669
# Accuracy after query 82: 0.8659
# Accuracy after query 83: 0.8619
# Accuracy after query 84: 0.8681
# Accuracy after query 85: 0.8710
# Accuracy after query 86: 0.8713
# Accuracy after query 87: 0.8686
# Accuracy after query 88: 0.8678
# Accuracy after query 89: 0.8637
# Accuracy after query 90: 0.8696
# Accuracy after query 91: 0.8781
# Accuracy after query 92: 0.8698
# Accuracy after query 93: 0.8760
# Accuracy after query 94: 0.8742
# Accuracy after query 95: 0.8718
# Accuracy after query 96: 0.8809
# Accuracy after query 97: 0.8839
# Accuracy after query 98: 0.8834
