# %%
import torch
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from batchbald_redux import batchbald
from acquisition_functions import *
import os
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
import keras
from keras.datasets import mnist

# %%
LATENT_DIMS = [64]
LATENT_DIM = 64
MAX_EPOCHS = 200
BATCH_SIZE = 128
LEARNING_RATE = 0.001
EXPERIMENT_COUNT = 3
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 512
ORIGINAL_DIM = 784
results_path = 'results\\mnist_infovae_dbal'
epsilon_std = 1.0

if not os.path.exists(results_path):
    os.makedirs(results_path)

ACQ_FUNCS = {
    "var_ratios": var_ratios,
    "mean_std": mean_std,
    "max_entropy": max_entropy,
    "bald": bald,
    "uniform": uniform,
#     "batch_bald": batch_bald
}

# %%
class MLP_REG(nn.Module):
    def __init__(self, latent_dim):
        super(MLP_REG, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 10),)
        
        
    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### read training data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 28, 28, 1).astype('float32') / 255.
X_test = X_test.reshape(10000, 28, 28, 1).astype('float32') / 255.

# %%
X_train_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_train_enhanced_infovae.npy")
X_test_enhanced = np.load(r"C:\Users\pinar\OneDrive\Masaüstü\masterthesis\src\Generative Models\mnist\x_test_enhanced_infovae.npy")

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
def active_learning_procedure(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=98,
                              n_instances=10):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    active_pool_size = [len(X_initial)]
    pool_size = len(X_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        pool_size = pool_size + n_instances
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
        active_pool_size.append(pool_size)
    return perf_hist, active_pool_size

# %%
for latent_dim in LATENT_DIMS:
    for exp_iter in range(EXPERIMENT_COUNT):
        np.random.seed(exp_iter)
        initial_idx = np.array([],dtype=int)
        for i in range(10):
            idx = np.random.choice(np.where(y_train==i)[0], size=2, replace=False)
            initial_idx = np.concatenate((initial_idx, idx))

        for func_name, acquisition_func in ACQ_FUNCS.items():  

            X_initial = X_train_enhanced[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train_enhanced, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = MLP_REG(latent_dim).to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test_enhanced,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join(results_path, "{func_name}_latent_dim_{latent_dim}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter, latent_dim=latent_dim))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
        for func_name, acquisition_func in ACQ_FUNCS.items():  
            X_initial = X_train[initial_idx]
            y_initial = y_train[initial_idx]

            X_pool = np.delete(X_train, initial_idx, axis=0)
            y_pool = np.delete(y_train, initial_idx, axis=0)

            model = MLP_REG(ORIGINAL_DIM).to(DEVICE)

            estimator = NeuralNetClassifier(model,
                                          max_epochs=MAX_EPOCHS,
                                          batch_size=BATCH_SIZE,
                                          lr=LEARNING_RATE,
                                          optimizer=torch.optim.Adam,
                                          criterion=torch.nn.CrossEntropyLoss,
                                          train_split=None,
                                          verbose=0,
                                          device=DEVICE)



            acc_arr, dataset_size_arr = active_learning_procedure(acquisition_func,
                                                              X_test,
                                                              y_test,
                                                              X_pool,
                                                              y_pool,
                                                              X_initial,
                                                              y_initial,
                                                              estimator,)
            file_name = os.path.join("results\\mnist_dbal", "{func_name}_exp_{exp_iter}.npy".format(func_name=func_name, exp_iter=exp_iter))
            np.save(file_name, (acc_arr, dataset_size_arr))
        '''
# Out:
# Accuracy after query 1: 0.6432
# Accuracy after query 2: 0.6934
# Accuracy after query 3: 0.7153
# Accuracy after query 4: 0.7229
# Accuracy after query 5: 0.7318
# Accuracy after query 6: 0.7767
# Accuracy after query 7: 0.7925
# Accuracy after query 8: 0.7949
# Accuracy after query 9: 0.8046
# Accuracy after query 10: 0.8079
# Accuracy after query 11: 0.8037
# Accuracy after query 12: 0.8442
# Accuracy after query 13: 0.8534
# Accuracy after query 14: 0.8594
# Accuracy after query 15: 0.8662
# Accuracy after query 16: 0.8703
# Accuracy after query 17: 0.8820
# Accuracy after query 18: 0.8910
# Accuracy after query 19: 0.8948
# Accuracy after query 20: 0.8923
# Accuracy after query 21: 0.9064
# Accuracy after query 22: 0.9019
# Accuracy after query 23: 0.9149
# Accuracy after query 24: 0.9204
# Accuracy after query 25: 0.9153
# Accuracy after query 26: 0.9230
# Accuracy after query 27: 0.9083
# Accuracy after query 28: 0.9157
# Accuracy after query 29: 0.9240
# Accuracy after query 30: 0.9257
# Accuracy after query 31: 0.9276
# Accuracy after query 32: 0.9302
# Accuracy after query 33: 0.9335
# Accuracy after query 34: 0.9330
# Accuracy after query 35: 0.9362
# Accuracy after query 36: 0.9364
# Accuracy after query 37: 0.9360
# Accuracy after query 38: 0.9371
# Accuracy after query 39: 0.9387
# Accuracy after query 40: 0.9334
# Accuracy after query 41: 0.9412
# Accuracy after query 42: 0.9385
# Accuracy after query 43: 0.9399
# Accuracy after query 44: 0.9418
# Accuracy after query 45: 0.9482
# Accuracy after query 46: 0.9394
# Accuracy after query 47: 0.9443
# Accuracy after query 48: 0.9477
# Accuracy after query 49: 0.9411
# Accuracy after query 50: 0.9495
# Accuracy after query 51: 0.9483
# Accuracy after query 52: 0.9493
# Accuracy after query 53: 0.9492
# Accuracy after query 54: 0.9472
# Accuracy after query 55: 0.9496
# Accuracy after query 56: 0.9452
# Accuracy after query 57: 0.9486
# Accuracy after query 58: 0.9451
# Accuracy after query 59: 0.9495
# Accuracy after query 60: 0.9536
# Accuracy after query 61: 0.9509
# Accuracy after query 62: 0.9555
# Accuracy after query 63: 0.9566
# Accuracy after query 64: 0.9567
# Accuracy after query 65: 0.9574
# Accuracy after query 66: 0.9526
# Accuracy after query 67: 0.9513
# Accuracy after query 68: 0.9565
# Accuracy after query 69: 0.9544
# Accuracy after query 70: 0.9566
# Accuracy after query 71: 0.9567
# Accuracy after query 72: 0.9578
# Accuracy after query 73: 0.9561
# Accuracy after query 74: 0.9569
# Accuracy after query 75: 0.9609
# Accuracy after query 76: 0.9601
# Accuracy after query 77: 0.9608
# Accuracy after query 78: 0.9611
# Accuracy after query 79: 0.9626
# Accuracy after query 80: 0.9603
# Accuracy after query 81: 0.9614
# Accuracy after query 82: 0.9590
# Accuracy after query 83: 0.9622
# Accuracy after query 84: 0.9672
# Accuracy after query 85: 0.9636
# Accuracy after query 86: 0.9635
# Accuracy after query 87: 0.9632
# Accuracy after query 88: 0.9628
# Accuracy after query 89: 0.9653
# Accuracy after query 90: 0.9653
# Accuracy after query 91: 0.9639
# Accuracy after query 92: 0.9656
# Accuracy after query 93: 0.9641
# Accuracy after query 94: 0.9648
# Accuracy after query 95: 0.9646
# Accuracy after query 96: 0.9637
# Accuracy after query 97: 0.9665
# Accuracy after query 98: 0.9675
# Accuracy after query 1: 0.6603
# Accuracy after query 2: 0.6847
# Accuracy after query 3: 0.6876
# Accuracy after query 4: 0.7033
# Accuracy after query 5: 0.7375
# Accuracy after query 6: 0.7601
# Accuracy after query 7: 0.7939
# Accuracy after query 8: 0.7952
# Accuracy after query 9: 0.8168
# Accuracy after query 10: 0.8289
# Accuracy after query 11: 0.8418
# Accuracy after query 12: 0.8377
# Accuracy after query 13: 0.8348
# Accuracy after query 14: 0.8630
# Accuracy after query 15: 0.8611
# Accuracy after query 16: 0.8801
# Accuracy after query 17: 0.8622
# Accuracy after query 18: 0.8807
# Accuracy after query 19: 0.8949
# Accuracy after query 20: 0.9008
# Accuracy after query 21: 0.9105
# Accuracy after query 22: 0.9034
# Accuracy after query 23: 0.9070
# Accuracy after query 24: 0.9043
# Accuracy after query 25: 0.9120
# Accuracy after query 26: 0.9192
# Accuracy after query 27: 0.9193
# Accuracy after query 28: 0.9143
# Accuracy after query 29: 0.9159
# Accuracy after query 30: 0.9254
# Accuracy after query 31: 0.9244
# Accuracy after query 32: 0.9236
# Accuracy after query 33: 0.9297
# Accuracy after query 34: 0.9258
# Accuracy after query 35: 0.9272
# Accuracy after query 36: 0.9263
# Accuracy after query 37: 0.9381
# Accuracy after query 38: 0.9369
# Accuracy after query 39: 0.9325
# Accuracy after query 40: 0.9274
# Accuracy after query 41: 0.9333
# Accuracy after query 42: 0.9346
# Accuracy after query 43: 0.9280
# Accuracy after query 44: 0.9352
# Accuracy after query 45: 0.9382
# Accuracy after query 46: 0.9374
# Accuracy after query 47: 0.9405
# Accuracy after query 48: 0.9290
# Accuracy after query 49: 0.9399
# Accuracy after query 50: 0.9454
# Accuracy after query 51: 0.9445
# Accuracy after query 52: 0.9437
# Accuracy after query 53: 0.9486
# Accuracy after query 54: 0.9485
# Accuracy after query 55: 0.9439
# Accuracy after query 56: 0.9461
# Accuracy after query 57: 0.9458
# Accuracy after query 58: 0.9511
# Accuracy after query 59: 0.9471
# Accuracy after query 60: 0.9552
# Accuracy after query 61: 0.9457
# Accuracy after query 62: 0.9487
# Accuracy after query 63: 0.9557
# Accuracy after query 64: 0.9548
# Accuracy after query 65: 0.9493
# Accuracy after query 66: 0.9540
# Accuracy after query 67: 0.9519
# Accuracy after query 68: 0.9514
# Accuracy after query 69: 0.9503
# Accuracy after query 70: 0.9578
# Accuracy after query 71: 0.9562
# Accuracy after query 72: 0.9549
# Accuracy after query 73: 0.9557
# Accuracy after query 74: 0.9585
# Accuracy after query 75: 0.9560
# Accuracy after query 76: 0.9558
# Accuracy after query 77: 0.9590
# Accuracy after query 78: 0.9584
# Accuracy after query 79: 0.9590
# Accuracy after query 80: 0.9583
# Accuracy after query 81: 0.9578
# Accuracy after query 82: 0.9537
# Accuracy after query 83: 0.9541
# Accuracy after query 84: 0.9555
# Accuracy after query 85: 0.9485
# Accuracy after query 86: 0.9550
# Accuracy after query 87: 0.9601
# Accuracy after query 88: 0.9618
# Accuracy after query 89: 0.9575
# Accuracy after query 90: 0.9587
# Accuracy after query 91: 0.9606
# Accuracy after query 92: 0.9631
# Accuracy after query 93: 0.9615
# Accuracy after query 94: 0.9648
# Accuracy after query 95: 0.9642
# Accuracy after query 96: 0.9620
# Accuracy after query 97: 0.9642
# Accuracy after query 98: 0.9616
# Accuracy after query 1: 0.6581
# Accuracy after query 2: 0.6684
# Accuracy after query 3: 0.6935
# Accuracy after query 4: 0.7317
# Accuracy after query 5: 0.7528
# Accuracy after query 6: 0.7767
# Accuracy after query 7: 0.7759
# Accuracy after query 8: 0.7981
# Accuracy after query 9: 0.8203
# Accuracy after query 10: 0.8363
# Accuracy after query 11: 0.8442
# Accuracy after query 12: 0.8501
# Accuracy after query 13: 0.8688
# Accuracy after query 14: 0.8701
# Accuracy after query 15: 0.8745
# Accuracy after query 16: 0.8860
# Accuracy after query 17: 0.8846
# Accuracy after query 18: 0.8844
# Accuracy after query 19: 0.8813
# Accuracy after query 20: 0.8904
# Accuracy after query 21: 0.8886
# Accuracy after query 22: 0.8848
# Accuracy after query 23: 0.8818
# Accuracy after query 24: 0.9002
# Accuracy after query 25: 0.8936
# Accuracy after query 26: 0.9025
# Accuracy after query 27: 0.8968
# Accuracy after query 28: 0.9022
# Accuracy after query 29: 0.9024
# Accuracy after query 30: 0.9099
# Accuracy after query 31: 0.8986
# Accuracy after query 32: 0.9110
# Accuracy after query 33: 0.9066
# Accuracy after query 34: 0.9165
# Accuracy after query 35: 0.9213
# Accuracy after query 36: 0.9159
# Accuracy after query 37: 0.9231
# Accuracy after query 38: 0.9251
# Accuracy after query 39: 0.9265
# Accuracy after query 40: 0.9291
# Accuracy after query 41: 0.9326
# Accuracy after query 42: 0.9366
# Accuracy after query 43: 0.9253
# Accuracy after query 44: 0.9378
# Accuracy after query 45: 0.9338
# Accuracy after query 46: 0.9403
# Accuracy after query 47: 0.9404
# Accuracy after query 48: 0.9370
# Accuracy after query 49: 0.9383
# Accuracy after query 50: 0.9381
# Accuracy after query 51: 0.9353
# Accuracy after query 52: 0.9387
# Accuracy after query 53: 0.9430
# Accuracy after query 54: 0.9446
# Accuracy after query 55: 0.9447
# Accuracy after query 56: 0.9438
# Accuracy after query 57: 0.9476
# Accuracy after query 58: 0.9501
# Accuracy after query 59: 0.9515
# Accuracy after query 60: 0.9484
# Accuracy after query 61: 0.9511
# Accuracy after query 62: 0.9510
# Accuracy after query 63: 0.9528
# Accuracy after query 64: 0.9460
# Accuracy after query 65: 0.9531
# Accuracy after query 66: 0.9555
# Accuracy after query 67: 0.9544
# Accuracy after query 68: 0.9512
# Accuracy after query 69: 0.9517
# Accuracy after query 70: 0.9517
# Accuracy after query 71: 0.9538
# Accuracy after query 72: 0.9533
# Accuracy after query 73: 0.9551
# Accuracy after query 74: 0.9593
# Accuracy after query 75: 0.9574
# Accuracy after query 76: 0.9536
# Accuracy after query 77: 0.9560
# Accuracy after query 78: 0.9593
# Accuracy after query 79: 0.9573
# Accuracy after query 80: 0.9574
# Accuracy after query 81: 0.9608
# Accuracy after query 82: 0.9608
# Accuracy after query 83: 0.9594
# Accuracy after query 84: 0.9493
# Accuracy after query 85: 0.9595
# Accuracy after query 86: 0.9608
# Accuracy after query 87: 0.9524
# Accuracy after query 88: 0.9646
# Accuracy after query 89: 0.9645
# Accuracy after query 90: 0.9601
# Accuracy after query 91: 0.9641
# Accuracy after query 92: 0.9631
# Accuracy after query 93: 0.9632
# Accuracy after query 94: 0.9618
# Accuracy after query 95: 0.9602
# Accuracy after query 96: 0.9580
# Accuracy after query 97: 0.9644
# Accuracy after query 98: 0.9649
# Accuracy after query 1: 0.6430
# Accuracy after query 2: 0.6778
# Accuracy after query 3: 0.7116
# Accuracy after query 4: 0.7383
# Accuracy after query 5: 0.7427
# Accuracy after query 6: 0.7703
# Accuracy after query 7: 0.8012
# Accuracy after query 8: 0.8248
# Accuracy after query 9: 0.8210
# Accuracy after query 10: 0.8324
# Accuracy after query 11: 0.8487
# Accuracy after query 12: 0.8550
# Accuracy after query 13: 0.8638
# Accuracy after query 14: 0.8639
# Accuracy after query 15: 0.8705
# Accuracy after query 16: 0.8820
# Accuracy after query 17: 0.8875
# Accuracy after query 18: 0.8888
# Accuracy after query 19: 0.8951
# Accuracy after query 20: 0.8974
# Accuracy after query 21: 0.9042
# Accuracy after query 22: 0.9010
# Accuracy after query 23: 0.9024
# Accuracy after query 24: 0.9063
# Accuracy after query 25: 0.9151
# Accuracy after query 26: 0.9120
# Accuracy after query 27: 0.9182
# Accuracy after query 28: 0.9230
# Accuracy after query 29: 0.9195
# Accuracy after query 30: 0.9172
# Accuracy after query 31: 0.9306
# Accuracy after query 32: 0.9128
# Accuracy after query 33: 0.9282
# Accuracy after query 34: 0.9273
# Accuracy after query 35: 0.9296
# Accuracy after query 36: 0.9316
# Accuracy after query 37: 0.9373
# Accuracy after query 38: 0.9365
# Accuracy after query 39: 0.9365
# Accuracy after query 40: 0.9388
# Accuracy after query 41: 0.9305
# Accuracy after query 42: 0.9332
# Accuracy after query 43: 0.9335
# Accuracy after query 44: 0.9384
# Accuracy after query 45: 0.9408
# Accuracy after query 46: 0.9415
# Accuracy after query 47: 0.9375
# Accuracy after query 48: 0.9384
# Accuracy after query 49: 0.9429
# Accuracy after query 50: 0.9485
# Accuracy after query 51: 0.9462
# Accuracy after query 52: 0.9487
# Accuracy after query 53: 0.9532
# Accuracy after query 54: 0.9479
# Accuracy after query 55: 0.9493
# Accuracy after query 56: 0.9514
# Accuracy after query 57: 0.9483
# Accuracy after query 58: 0.9539
# Accuracy after query 59: 0.9561
# Accuracy after query 60: 0.9498
# Accuracy after query 61: 0.9550
# Accuracy after query 62: 0.9518
# Accuracy after query 63: 0.9497
# Accuracy after query 64: 0.9524
# Accuracy after query 65: 0.9445
# Accuracy after query 66: 0.9525
# Accuracy after query 67: 0.9548
# Accuracy after query 68: 0.9619
# Accuracy after query 69: 0.9582
# Accuracy after query 70: 0.9571
# Accuracy after query 71: 0.9600
# Accuracy after query 72: 0.9600
# Accuracy after query 73: 0.9604
# Accuracy after query 74: 0.9606
# Accuracy after query 75: 0.9607
# Accuracy after query 76: 0.9627
# Accuracy after query 77: 0.9572
# Accuracy after query 78: 0.9584
# Accuracy after query 79: 0.9611
# Accuracy after query 80: 0.9626
# Accuracy after query 81: 0.9578
# Accuracy after query 82: 0.9610
# Accuracy after query 83: 0.9578
# Accuracy after query 84: 0.9594
# Accuracy after query 85: 0.9621
# Accuracy after query 86: 0.9638
# Accuracy after query 87: 0.9599
# Accuracy after query 88: 0.9636
# Accuracy after query 89: 0.9618
# Accuracy after query 90: 0.9644
# Accuracy after query 91: 0.9604
# Accuracy after query 92: 0.9625
# Accuracy after query 93: 0.9621
# Accuracy after query 94: 0.9645
# Accuracy after query 95: 0.9618
# Accuracy after query 96: 0.9655
# Accuracy after query 97: 0.9633
# Accuracy after query 98: 0.9646
# Accuracy after query 1: 0.5986
# Accuracy after query 2: 0.6562
# Accuracy after query 3: 0.6944
# Accuracy after query 4: 0.7375
# Accuracy after query 5: 0.7774
# Accuracy after query 6: 0.7911
# Accuracy after query 7: 0.7876
# Accuracy after query 8: 0.7933
# Accuracy after query 9: 0.8024
# Accuracy after query 10: 0.8191
# Accuracy after query 11: 0.8126
# Accuracy after query 12: 0.8181
# Accuracy after query 13: 0.8393
# Accuracy after query 14: 0.8091
# Accuracy after query 15: 0.8379
# Accuracy after query 16: 0.8604
# Accuracy after query 17: 0.8659
# Accuracy after query 18: 0.8540
# Accuracy after query 19: 0.8716
# Accuracy after query 20: 0.8658
# Accuracy after query 21: 0.8676
# Accuracy after query 22: 0.8743
# Accuracy after query 23: 0.8688
# Accuracy after query 24: 0.8792
# Accuracy after query 25: 0.8764
# Accuracy after query 26: 0.8729
# Accuracy after query 27: 0.8774
# Accuracy after query 28: 0.8865
# Accuracy after query 29: 0.8809
# Accuracy after query 30: 0.8917
# Accuracy after query 31: 0.8884
# Accuracy after query 32: 0.8969
# Accuracy after query 33: 0.8876
# Accuracy after query 34: 0.8928
# Accuracy after query 35: 0.9023
# Accuracy after query 36: 0.9059
# Accuracy after query 37: 0.9029
# Accuracy after query 38: 0.9068
# Accuracy after query 39: 0.9003
# Accuracy after query 40: 0.9054
# Accuracy after query 41: 0.8980
# Accuracy after query 42: 0.9070
# Accuracy after query 43: 0.9023
# Accuracy after query 44: 0.9058
# Accuracy after query 45: 0.9061
# Accuracy after query 46: 0.9097
# Accuracy after query 47: 0.9069
# Accuracy after query 48: 0.9085
# Accuracy after query 49: 0.9141
# Accuracy after query 50: 0.9136
# Accuracy after query 51: 0.9020
# Accuracy after query 52: 0.9125
# Accuracy after query 53: 0.9117
# Accuracy after query 54: 0.9178
# Accuracy after query 55: 0.9140
# Accuracy after query 56: 0.9215
# Accuracy after query 57: 0.9166
# Accuracy after query 58: 0.9238
# Accuracy after query 59: 0.9247
# Accuracy after query 60: 0.9179
# Accuracy after query 61: 0.9192
# Accuracy after query 62: 0.9168
# Accuracy after query 63: 0.9234
# Accuracy after query 64: 0.9219
# Accuracy after query 65: 0.9231
# Accuracy after query 66: 0.9221
# Accuracy after query 67: 0.9246
# Accuracy after query 68: 0.9242
# Accuracy after query 69: 0.9220
# Accuracy after query 70: 0.9234
# Accuracy after query 71: 0.9216
# Accuracy after query 72: 0.9233
# Accuracy after query 73: 0.9242
# Accuracy after query 74: 0.9188
# Accuracy after query 75: 0.9255
# Accuracy after query 76: 0.9309
# Accuracy after query 77: 0.9288
# Accuracy after query 78: 0.9333
# Accuracy after query 79: 0.9322
# Accuracy after query 80: 0.9276
# Accuracy after query 81: 0.9335
# Accuracy after query 82: 0.9329
# Accuracy after query 83: 0.9356
# Accuracy after query 84: 0.9330
# Accuracy after query 85: 0.9355
# Accuracy after query 86: 0.9364
# Accuracy after query 87: 0.9346
# Accuracy after query 88: 0.9339
# Accuracy after query 89: 0.9353
# Accuracy after query 90: 0.9307
# Accuracy after query 91: 0.9337
# Accuracy after query 92: 0.9308
# Accuracy after query 93: 0.9341
# Accuracy after query 94: 0.9351
# Accuracy after query 95: 0.9356
# Accuracy after query 96: 0.9332
# Accuracy after query 97: 0.9345
# Accuracy after query 98: 0.9377
# (2000,)
# Accuracy after query 1: 0.5844
# (2000,)
# Accuracy after query 2: 0.6050
# (2000,)
# Accuracy after query 3: 0.6509
# (2000,)
# Accuracy after query 4: 0.6712
# (2000,)
# Accuracy after query 5: 0.6975
# (2000,)
# Accuracy after query 6: 0.7253
# (2000,)
# Accuracy after query 7: 0.7497
# (2000,)
# Accuracy after query 8: 0.7582
# (2000,)
# Accuracy after query 9: 0.7701
# (2000,)
# Accuracy after query 10: 0.7676
# (2000,)
# Accuracy after query 11: 0.7735
# (2000,)
# Accuracy after query 12: 0.7659
# (2000,)
# Accuracy after query 13: 0.7835
# (2000,)
# Accuracy after query 14: 0.8208
# (2000,)
# Accuracy after query 15: 0.8019
# (2000,)
# Accuracy after query 16: 0.8223
# (2000,)
# Accuracy after query 17: 0.8219
# (2000,)
# Accuracy after query 18: 0.8270
# (2000,)
# Accuracy after query 19: 0.8336
# (2000,)
# Accuracy after query 20: 0.8196
# (2000,)
# Accuracy after query 21: 0.8469
# (2000,)
# Accuracy after query 22: 0.8515
# (2000,)
# Accuracy after query 23: 0.8490
# (2000,)
# Accuracy after query 24: 0.8538
# (2000,)
# Accuracy after query 25: 0.8536
# (2000,)
# Accuracy after query 26: 0.8616
# (2000,)
# Accuracy after query 27: 0.8584
# (2000,)
# Accuracy after query 28: 0.8624
# (2000,)
# Accuracy after query 29: 0.8473
# (2000,)
# Accuracy after query 30: 0.8608
# (2000,)
# Accuracy after query 31: 0.8642
# (2000,)
# Accuracy after query 32: 0.8664
# (2000,)
# Accuracy after query 33: 0.8841
# (2000,)
# Accuracy after query 34: 0.8863
# (2000,)
# Accuracy after query 35: 0.8756
# (2000,)
# Accuracy after query 36: 0.8892
# (2000,)
# Accuracy after query 37: 0.8838
# (2000,)
# Accuracy after query 38: 0.8880
# (2000,)
# Accuracy after query 39: 0.8919
# (2000,)
# Accuracy after query 40: 0.8884
# (2000,)
# Accuracy after query 41: 0.8919
# (2000,)
# Accuracy after query 42: 0.8967
# (2000,)
# Accuracy after query 43: 0.8917
# (2000,)
# Accuracy after query 44: 0.8966
# (2000,)
# Accuracy after query 45: 0.8996
# (2000,)
# Accuracy after query 46: 0.8923
# (2000,)
# Accuracy after query 47: 0.9044
# (2000,)
# Accuracy after query 48: 0.8986
# (2000,)
# Accuracy after query 49: 0.9040
# (2000,)
# Accuracy after query 50: 0.9069
# (2000,)
# Accuracy after query 51: 0.9055
# (2000,)
# Accuracy after query 52: 0.9121
# (2000,)
# Accuracy after query 53: 0.9086
# (2000,)
# Accuracy after query 54: 0.9115
# (2000,)
# Accuracy after query 55: 0.9141
# (2000,)
# Accuracy after query 56: 0.9092
# (2000,)
# Accuracy after query 57: 0.9147
# (2000,)
# Accuracy after query 58: 0.9132
# (2000,)
# Accuracy after query 59: 0.9131
# (2000,)
# Accuracy after query 60: 0.9088
# (2000,)
# Accuracy after query 61: 0.9172
# (2000,)
# Accuracy after query 62: 0.9148
# (2000,)
# Accuracy after query 63: 0.9130
# (2000,)
# Accuracy after query 64: 0.9149
# (2000,)
# Accuracy after query 65: 0.9130
# (2000,)
# Accuracy after query 66: 0.9133
# (2000,)
# Accuracy after query 67: 0.9101
# (2000,)
# Accuracy after query 68: 0.9138
# (2000,)
# Accuracy after query 69: 0.9131
# (2000,)
# Accuracy after query 70: 0.9175
# (2000,)
# Accuracy after query 71: 0.9226
# (2000,)
# Accuracy after query 72: 0.9224
# (2000,)
# Accuracy after query 73: 0.9187
# (2000,)
# Accuracy after query 74: 0.9210
# (2000,)
# Accuracy after query 75: 0.9280
# (2000,)
# Accuracy after query 76: 0.9304
# (2000,)
# Accuracy after query 77: 0.9250
# (2000,)
# Accuracy after query 78: 0.9242
# (2000,)
# Accuracy after query 79: 0.9252
# (2000,)
# Accuracy after query 80: 0.9213
# (2000,)
# Accuracy after query 81: 0.9238
# (2000,)
# Accuracy after query 82: 0.9291
# (2000,)
# Accuracy after query 83: 0.9265
# (2000,)
# Accuracy after query 84: 0.9272
# (2000,)
# Accuracy after query 85: 0.9268
# (2000,)
# Accuracy after query 86: 0.9279
# (2000,)
# Accuracy after query 87: 0.9238
# (2000,)
# Accuracy after query 88: 0.9343
# (2000,)
# Accuracy after query 89: 0.9294
# (2000,)
# Accuracy after query 90: 0.9314
# (2000,)
# Accuracy after query 91: 0.9298
# (2000,)
# Accuracy after query 92: 0.9299
# (2000,)
# Accuracy after query 93: 0.9343
# (2000,)
# Accuracy after query 94: 0.9338
# (2000,)
# Accuracy after query 95: 0.9365
# (2000,)
# Accuracy after query 96: 0.9349
# (2000,)
# Accuracy after query 97: 0.9367
# (2000,)
# Accuracy after query 98: 0.9350
# Accuracy after query 1: 0.6237
# Accuracy after query 2: 0.6667
# Accuracy after query 3: 0.7411
# Accuracy after query 4: 0.7496
# Accuracy after query 5: 0.7682
# Accuracy after query 6: 0.7812
# Accuracy after query 7: 0.7705
# Accuracy after query 8: 0.7901
# Accuracy after query 9: 0.8127
# Accuracy after query 10: 0.8200
# Accuracy after query 11: 0.8422
# Accuracy after query 12: 0.8467
# Accuracy after query 13: 0.8623
# Accuracy after query 14: 0.8665
# Accuracy after query 15: 0.8493
# Accuracy after query 16: 0.8715
# Accuracy after query 17: 0.8790
# Accuracy after query 18: 0.8832
# Accuracy after query 19: 0.8964
# Accuracy after query 20: 0.9008
# Accuracy after query 21: 0.9047
# Accuracy after query 22: 0.9105
# Accuracy after query 23: 0.9108
# Accuracy after query 24: 0.9136
# Accuracy after query 25: 0.9175
# Accuracy after query 26: 0.9222
# Accuracy after query 27: 0.9166
# Accuracy after query 28: 0.9251
# Accuracy after query 29: 0.9195
# Accuracy after query 30: 0.9130
# Accuracy after query 31: 0.9315
# Accuracy after query 32: 0.9287
# Accuracy after query 33: 0.9249
# Accuracy after query 34: 0.9249
# Accuracy after query 35: 0.9267
# Accuracy after query 36: 0.9386
# Accuracy after query 37: 0.9370
# Accuracy after query 38: 0.9327
# Accuracy after query 39: 0.9404
# Accuracy after query 40: 0.9418
# Accuracy after query 41: 0.9392
# Accuracy after query 42: 0.9417
# Accuracy after query 43: 0.9455
# Accuracy after query 44: 0.9476
# Accuracy after query 45: 0.9508
# Accuracy after query 46: 0.9486
# Accuracy after query 47: 0.9497
# Accuracy after query 48: 0.9485
# Accuracy after query 49: 0.9515
# Accuracy after query 50: 0.9522
# Accuracy after query 51: 0.9562
# Accuracy after query 52: 0.9520
# Accuracy after query 53: 0.9503
# Accuracy after query 54: 0.9519
# Accuracy after query 55: 0.9530
# Accuracy after query 56: 0.9495
# Accuracy after query 57: 0.9523
# Accuracy after query 58: 0.9458
# Accuracy after query 59: 0.9522
# Accuracy after query 60: 0.9565
# Accuracy after query 61: 0.9532
# Accuracy after query 62: 0.9564
# Accuracy after query 63: 0.9596
# Accuracy after query 64: 0.9571
# Accuracy after query 65: 0.9594
# Accuracy after query 66: 0.9565
# Accuracy after query 67: 0.9600
# Accuracy after query 68: 0.9598
# Accuracy after query 69: 0.9622
# Accuracy after query 70: 0.9560
# Accuracy after query 71: 0.9584
# Accuracy after query 72: 0.9615
# Accuracy after query 73: 0.9583
# Accuracy after query 74: 0.9598
# Accuracy after query 75: 0.9608
# Accuracy after query 76: 0.9641
# Accuracy after query 77: 0.9645
# Accuracy after query 78: 0.9615
# Accuracy after query 79: 0.9620
# Accuracy after query 80: 0.9620
# Accuracy after query 81: 0.9614
# Accuracy after query 82: 0.9624
# Accuracy after query 83: 0.9633
# Accuracy after query 84: 0.9651
# Accuracy after query 85: 0.9620
# Accuracy after query 86: 0.9665
# Accuracy after query 87: 0.9628
# Accuracy after query 88: 0.9676
# Accuracy after query 89: 0.9665
# Accuracy after query 90: 0.9672
# Accuracy after query 91: 0.9672
# Accuracy after query 92: 0.9675
# Accuracy after query 93: 0.9662
# Accuracy after query 94: 0.9674
# Accuracy after query 95: 0.9670
# Accuracy after query 96: 0.9674
# Accuracy after query 97: 0.9688
# Accuracy after query 98: 0.9662
# Accuracy after query 1: 0.5721
# Accuracy after query 2: 0.6451
# Accuracy after query 3: 0.6987
# Accuracy after query 4: 0.7486
# Accuracy after query 5: 0.7714
# Accuracy after query 6: 0.8005
# Accuracy after query 7: 0.7990
# Accuracy after query 8: 0.8170
# Accuracy after query 9: 0.8200
# Accuracy after query 10: 0.8328
# Accuracy after query 11: 0.8432
# Accuracy after query 12: 0.8464
# Accuracy after query 13: 0.8391
# Accuracy after query 14: 0.8538
# Accuracy after query 15: 0.8610
# Accuracy after query 16: 0.8731
# Accuracy after query 17: 0.8882
# Accuracy after query 18: 0.8915
# Accuracy after query 19: 0.8915
# Accuracy after query 20: 0.8901
# Accuracy after query 21: 0.9032
# Accuracy after query 22: 0.8960
# Accuracy after query 23: 0.9005
# Accuracy after query 24: 0.9126
# Accuracy after query 25: 0.9165
# Accuracy after query 26: 0.9080
# Accuracy after query 27: 0.9130
# Accuracy after query 28: 0.9016
# Accuracy after query 29: 0.9092
# Accuracy after query 30: 0.9123
# Accuracy after query 31: 0.9201
# Accuracy after query 32: 0.9185
# Accuracy after query 33: 0.9294
# Accuracy after query 34: 0.9336
# Accuracy after query 35: 0.9345
# Accuracy after query 36: 0.9315
# Accuracy after query 37: 0.9342
# Accuracy after query 38: 0.9350
# Accuracy after query 39: 0.9337
# Accuracy after query 40: 0.9386
# Accuracy after query 41: 0.9361
# Accuracy after query 42: 0.9329
# Accuracy after query 43: 0.9405
# Accuracy after query 44: 0.9421
# Accuracy after query 45: 0.9471
# Accuracy after query 46: 0.9453
# Accuracy after query 47: 0.9474
# Accuracy after query 48: 0.9486
# Accuracy after query 49: 0.9482
# Accuracy after query 50: 0.9484
# Accuracy after query 51: 0.9493
# Accuracy after query 52: 0.9470
# Accuracy after query 53: 0.9486
# Accuracy after query 54: 0.9496
# Accuracy after query 55: 0.9484
# Accuracy after query 56: 0.9515
# Accuracy after query 57: 0.9528
# Accuracy after query 58: 0.9532
# Accuracy after query 59: 0.9558
# Accuracy after query 60: 0.9541
# Accuracy after query 61: 0.9530
# Accuracy after query 62: 0.9537
# Accuracy after query 63: 0.9558
# Accuracy after query 64: 0.9565
# Accuracy after query 65: 0.9521
# Accuracy after query 66: 0.9592
# Accuracy after query 67: 0.9566
# Accuracy after query 68: 0.9581
# Accuracy after query 69: 0.9620
# Accuracy after query 70: 0.9583
# Accuracy after query 71: 0.9629
# Accuracy after query 72: 0.9611
# Accuracy after query 73: 0.9625
# Accuracy after query 74: 0.9634
# Accuracy after query 75: 0.9619
# Accuracy after query 76: 0.9639
# Accuracy after query 77: 0.9647
# Accuracy after query 78: 0.9638
# Accuracy after query 79: 0.9639
# Accuracy after query 80: 0.9617
# Accuracy after query 81: 0.9613
# Accuracy after query 82: 0.9631
# Accuracy after query 83: 0.9651
# Accuracy after query 84: 0.9607
# Accuracy after query 85: 0.9616
# Accuracy after query 86: 0.9600
# Accuracy after query 87: 0.9627
# Accuracy after query 88: 0.9676
# Accuracy after query 89: 0.9677
# Accuracy after query 90: 0.9653
# Accuracy after query 91: 0.9636
# Accuracy after query 92: 0.9640
# Accuracy after query 93: 0.9689
# Accuracy after query 94: 0.9684
# Accuracy after query 95: 0.9675
# Accuracy after query 96: 0.9678
# Accuracy after query 97: 0.9656
# Accuracy after query 98: 0.9641
# Accuracy after query 1: 0.6437
# Accuracy after query 2: 0.6656
# Accuracy after query 3: 0.6747
# Accuracy after query 4: 0.6966
# Accuracy after query 5: 0.7341
# Accuracy after query 6: 0.7507
# Accuracy after query 7: 0.7690
# Accuracy after query 8: 0.8103
# Accuracy after query 9: 0.8163
# Accuracy after query 10: 0.8224
# Accuracy after query 11: 0.8069
# Accuracy after query 12: 0.8155
# Accuracy after query 13: 0.8204
# Accuracy after query 14: 0.8341
# Accuracy after query 15: 0.8415
# Accuracy after query 16: 0.8593
# Accuracy after query 17: 0.8763
# Accuracy after query 18: 0.8796
# Accuracy after query 19: 0.8717
# Accuracy after query 20: 0.8785
# Accuracy after query 21: 0.8785
# Accuracy after query 22: 0.8840
# Accuracy after query 23: 0.8987
# Accuracy after query 24: 0.9053
# Accuracy after query 25: 0.9052
# Accuracy after query 26: 0.9079
# Accuracy after query 27: 0.9100
# Accuracy after query 28: 0.8981
# Accuracy after query 29: 0.9137
# Accuracy after query 30: 0.9094
# Accuracy after query 31: 0.9073
# Accuracy after query 32: 0.9126
# Accuracy after query 33: 0.9207
# Accuracy after query 34: 0.9184
# Accuracy after query 35: 0.9232
# Accuracy after query 36: 0.9233
# Accuracy after query 37: 0.9213
# Accuracy after query 38: 0.9242
# Accuracy after query 39: 0.9258
# Accuracy after query 40: 0.9214
# Accuracy after query 41: 0.9291
# Accuracy after query 42: 0.9185
# Accuracy after query 43: 0.9244
# Accuracy after query 44: 0.9363
# Accuracy after query 45: 0.9336
# Accuracy after query 46: 0.9373
# Accuracy after query 47: 0.9334
# Accuracy after query 48: 0.9324
# Accuracy after query 49: 0.9400
# Accuracy after query 50: 0.9387
# Accuracy after query 51: 0.9364
# Accuracy after query 52: 0.9362
# Accuracy after query 53: 0.9393
# Accuracy after query 54: 0.9428
# Accuracy after query 55: 0.9417
# Accuracy after query 56: 0.9459
# Accuracy after query 57: 0.9434
# Accuracy after query 58: 0.9505
# Accuracy after query 59: 0.9487
# Accuracy after query 60: 0.9496
# Accuracy after query 61: 0.9413
# Accuracy after query 62: 0.9537
# Accuracy after query 63: 0.9532
# Accuracy after query 64: 0.9539
# Accuracy after query 65: 0.9503
# Accuracy after query 66: 0.9530
# Accuracy after query 67: 0.9481
# Accuracy after query 68: 0.9509
# Accuracy after query 69: 0.9502
# Accuracy after query 70: 0.9531
# Accuracy after query 71: 0.9545
# Accuracy after query 72: 0.9561
# Accuracy after query 73: 0.9533
# Accuracy after query 74: 0.9532
# Accuracy after query 75: 0.9558
# Accuracy after query 76: 0.9543
# Accuracy after query 77: 0.9544
# Accuracy after query 78: 0.9607
# Accuracy after query 79: 0.9557
# Accuracy after query 80: 0.9559
# Accuracy after query 81: 0.9584
# Accuracy after query 82: 0.9597
# Accuracy after query 83: 0.9551
# Accuracy after query 84: 0.9570
# Accuracy after query 85: 0.9581
# Accuracy after query 86: 0.9597
# Accuracy after query 87: 0.9607
# Accuracy after query 88: 0.9628
# Accuracy after query 89: 0.9637
# Accuracy after query 90: 0.9603
# Accuracy after query 91: 0.9632
# Accuracy after query 92: 0.9618
# Accuracy after query 93: 0.9635
# Accuracy after query 94: 0.9649
# Accuracy after query 95: 0.9618
# Accuracy after query 96: 0.9650
# Accuracy after query 97: 0.9642
# Accuracy after query 98: 0.9659
# Accuracy after query 1: 0.5458
# Accuracy after query 2: 0.5924
# Accuracy after query 3: 0.6273
# Accuracy after query 4: 0.6701
# Accuracy after query 5: 0.6835
# Accuracy after query 6: 0.6905
# Accuracy after query 7: 0.7083
# Accuracy after query 8: 0.7563
# Accuracy after query 9: 0.7655
# Accuracy after query 10: 0.7802
# Accuracy after query 11: 0.8322
# Accuracy after query 12: 0.8313
# Accuracy after query 13: 0.8584
# Accuracy after query 14: 0.8703
# Accuracy after query 15: 0.8579
# Accuracy after query 16: 0.8525
# Accuracy after query 17: 0.8696
# Accuracy after query 18: 0.8832
# Accuracy after query 19: 0.8752
# Accuracy after query 20: 0.8748
# Accuracy after query 21: 0.8849
# Accuracy after query 22: 0.8959
# Accuracy after query 23: 0.8929
# Accuracy after query 24: 0.8925
# Accuracy after query 25: 0.9009
# Accuracy after query 26: 0.8935
# Accuracy after query 27: 0.9029
# Accuracy after query 28: 0.9051
# Accuracy after query 29: 0.9062
# Accuracy after query 30: 0.9099
# Accuracy after query 31: 0.9150
# Accuracy after query 32: 0.9166
# Accuracy after query 33: 0.9201
# Accuracy after query 34: 0.9276
# Accuracy after query 35: 0.9267
# Accuracy after query 36: 0.9293
# Accuracy after query 37: 0.9293
# Accuracy after query 38: 0.9207
# Accuracy after query 39: 0.9302
# Accuracy after query 40: 0.9293
# Accuracy after query 41: 0.9357
# Accuracy after query 42: 0.9387
# Accuracy after query 43: 0.9350
# Accuracy after query 44: 0.9409
# Accuracy after query 45: 0.9409
# Accuracy after query 46: 0.9463
# Accuracy after query 47: 0.9435
# Accuracy after query 48: 0.9402
# Accuracy after query 49: 0.9483
# Accuracy after query 50: 0.9351
# Accuracy after query 51: 0.9417
# Accuracy after query 52: 0.9459
# Accuracy after query 53: 0.9431
# Accuracy after query 54: 0.9492
# Accuracy after query 55: 0.9524
# Accuracy after query 56: 0.9445
# Accuracy after query 57: 0.9512
# Accuracy after query 58: 0.9501
# Accuracy after query 59: 0.9503
# Accuracy after query 60: 0.9526
# Accuracy after query 61: 0.9527
# Accuracy after query 62: 0.9559
# Accuracy after query 63: 0.9531
# Accuracy after query 64: 0.9498
# Accuracy after query 65: 0.9555
# Accuracy after query 66: 0.9577
# Accuracy after query 67: 0.9540
# Accuracy after query 68: 0.9585
# Accuracy after query 69: 0.9559
# Accuracy after query 70: 0.9563
# Accuracy after query 71: 0.9553
# Accuracy after query 72: 0.9523
# Accuracy after query 73: 0.9564
# Accuracy after query 74: 0.9555
# Accuracy after query 75: 0.9597
# Accuracy after query 76: 0.9554
# Accuracy after query 77: 0.9577
# Accuracy after query 78: 0.9569
# Accuracy after query 79: 0.9586
# Accuracy after query 80: 0.9626
# Accuracy after query 81: 0.9585
# Accuracy after query 82: 0.9626
# Accuracy after query 83: 0.9620
# Accuracy after query 84: 0.9641
# Accuracy after query 85: 0.9633
# Accuracy after query 86: 0.9627
# Accuracy after query 87: 0.9626
# Accuracy after query 88: 0.9651
# Accuracy after query 89: 0.9616
# Accuracy after query 90: 0.9622
# Accuracy after query 91: 0.9669
# Accuracy after query 92: 0.9649
# Accuracy after query 93: 0.9628
# Accuracy after query 94: 0.9629
# Accuracy after query 95: 0.9676
# Accuracy after query 96: 0.9652
# Accuracy after query 97: 0.9635
# Accuracy after query 98: 0.9621
# Accuracy after query 1: 0.6372
# Accuracy after query 2: 0.6909
# Accuracy after query 3: 0.7058
# Accuracy after query 4: 0.7064
# Accuracy after query 5: 0.7204
# Accuracy after query 6: 0.7276
# Accuracy after query 7: 0.7357
# Accuracy after query 8: 0.7518
# Accuracy after query 9: 0.7683
# Accuracy after query 10: 0.7791
# Accuracy after query 11: 0.7820
# Accuracy after query 12: 0.7704
# Accuracy after query 13: 0.7621
# Accuracy after query 14: 0.7708
# Accuracy after query 15: 0.7936
# Accuracy after query 16: 0.8043
# Accuracy after query 17: 0.8184
# Accuracy after query 18: 0.8157
# Accuracy after query 19: 0.8468
# Accuracy after query 20: 0.8411
# Accuracy after query 21: 0.8579
# Accuracy after query 22: 0.8461
# Accuracy after query 23: 0.8468
# Accuracy after query 24: 0.8613
# Accuracy after query 25: 0.8654
# Accuracy after query 26: 0.8503
# Accuracy after query 27: 0.8600
# Accuracy after query 28: 0.8575
# Accuracy after query 29: 0.8556
# Accuracy after query 30: 0.8619
# Accuracy after query 31: 0.8658
# Accuracy after query 32: 0.8632
# Accuracy after query 33: 0.8716
# Accuracy after query 34: 0.8831
# Accuracy after query 35: 0.8828
# Accuracy after query 36: 0.8822
# Accuracy after query 37: 0.8887
# Accuracy after query 38: 0.8911
# Accuracy after query 39: 0.8856
# Accuracy after query 40: 0.8953
# Accuracy after query 41: 0.8867
# Accuracy after query 42: 0.8779
# Accuracy after query 43: 0.8958
# Accuracy after query 44: 0.8965
# Accuracy after query 45: 0.8857
# Accuracy after query 46: 0.9009
# Accuracy after query 47: 0.9059
# Accuracy after query 48: 0.9099
# Accuracy after query 49: 0.9037
# Accuracy after query 50: 0.9126
# Accuracy after query 51: 0.9074
# Accuracy after query 52: 0.9177
# Accuracy after query 53: 0.9112
# Accuracy after query 54: 0.9148
# Accuracy after query 55: 0.9061
# Accuracy after query 56: 0.9115
# Accuracy after query 57: 0.9163
# Accuracy after query 58: 0.9179
# Accuracy after query 59: 0.9162
# Accuracy after query 60: 0.9170
# Accuracy after query 61: 0.9107
# Accuracy after query 62: 0.9163
# Accuracy after query 63: 0.9216
# Accuracy after query 64: 0.9129
# Accuracy after query 65: 0.9147
# Accuracy after query 66: 0.9197
# Accuracy after query 67: 0.9180
# Accuracy after query 68: 0.9264
# Accuracy after query 69: 0.9190
# Accuracy after query 70: 0.9257
# Accuracy after query 71: 0.9195
# Accuracy after query 72: 0.9279
# Accuracy after query 73: 0.9247
# Accuracy after query 74: 0.9248
# Accuracy after query 75: 0.9233
# Accuracy after query 76: 0.9226
# Accuracy after query 77: 0.9272
# Accuracy after query 78: 0.9269
# Accuracy after query 79: 0.9190
# Accuracy after query 80: 0.9240
# Accuracy after query 81: 0.9259
# Accuracy after query 82: 0.9268
# Accuracy after query 83: 0.9211
# Accuracy after query 84: 0.9284
# Accuracy after query 85: 0.9260
# Accuracy after query 86: 0.9241
# Accuracy after query 87: 0.9273
# Accuracy after query 88: 0.9308
# Accuracy after query 89: 0.9282
# Accuracy after query 90: 0.9297
# Accuracy after query 91: 0.9291
# Accuracy after query 92: 0.9302
# Accuracy after query 93: 0.9318
# Accuracy after query 94: 0.9286
# Accuracy after query 95: 0.9338
# Accuracy after query 96: 0.9311
# Accuracy after query 97: 0.9318
# Accuracy after query 98: 0.9352
# (2000,)
# Accuracy after query 1: 0.6080
# (2000,)
# Accuracy after query 2: 0.6549
# (2000,)
# Accuracy after query 3: 0.6817
# (2000,)
# Accuracy after query 4: 0.6929
# (2000,)
# Accuracy after query 5: 0.7289
# (2000,)
# Accuracy after query 6: 0.7486
# (2000,)
# Accuracy after query 7: 0.7695
# (2000,)
# Accuracy after query 8: 0.7705
# (2000,)
# Accuracy after query 9: 0.7727
# (2000,)
# Accuracy after query 10: 0.7836
# (2000,)
# Accuracy after query 11: 0.7890
# (2000,)
# Accuracy after query 12: 0.8044
# (2000,)
# Accuracy after query 13: 0.8134
# (2000,)
# Accuracy after query 14: 0.8265
# (2000,)
# Accuracy after query 15: 0.8264
# (2000,)
# Accuracy after query 16: 0.8273
# (2000,)
# Accuracy after query 17: 0.8047
# (2000,)
# Accuracy after query 18: 0.8401
# (2000,)
# Accuracy after query 19: 0.8425
# (2000,)
# Accuracy after query 20: 0.8491
# (2000,)
# Accuracy after query 21: 0.8510
# (2000,)
# Accuracy after query 22: 0.8601
# (2000,)
# Accuracy after query 23: 0.8625
# (2000,)
# Accuracy after query 24: 0.8490
# (2000,)
# Accuracy after query 25: 0.8692
# (2000,)
# Accuracy after query 26: 0.8553
# (2000,)
# Accuracy after query 27: 0.8635
# (2000,)
# Accuracy after query 28: 0.8746
# (2000,)
# Accuracy after query 29: 0.8748
# (2000,)
# Accuracy after query 30: 0.8783
# (2000,)
# Accuracy after query 31: 0.8739
# (2000,)
# Accuracy after query 32: 0.8762
# (2000,)
# Accuracy after query 33: 0.8765
# (2000,)
# Accuracy after query 34: 0.8846
# (2000,)
# Accuracy after query 35: 0.8873
# (2000,)
# Accuracy after query 36: 0.8936
# (2000,)
# Accuracy after query 37: 0.8965
# (2000,)
# Accuracy after query 38: 0.8830
# (2000,)
# Accuracy after query 39: 0.8900
# (2000,)
# Accuracy after query 40: 0.8922
# (2000,)
# Accuracy after query 41: 0.8866
# (2000,)
# Accuracy after query 42: 0.8817
# (2000,)
# Accuracy after query 43: 0.8978
# (2000,)
# Accuracy after query 44: 0.8967
# (2000,)
# Accuracy after query 45: 0.8958
# (2000,)
# Accuracy after query 46: 0.8880
# (2000,)
# Accuracy after query 47: 0.8969
# (2000,)
# Accuracy after query 48: 0.8948
# (2000,)
# Accuracy after query 49: 0.8996
# (2000,)
# Accuracy after query 50: 0.8998
# (2000,)
# Accuracy after query 51: 0.9083
# (2000,)
# Accuracy after query 52: 0.9032
# (2000,)
# Accuracy after query 53: 0.9087
# (2000,)
# Accuracy after query 54: 0.9156
# (2000,)
# Accuracy after query 55: 0.9078
# (2000,)
# Accuracy after query 56: 0.9136
# (2000,)
# Accuracy after query 57: 0.9162
# (2000,)
# Accuracy after query 58: 0.9120
# (2000,)
# Accuracy after query 59: 0.9172
# (2000,)
# Accuracy after query 60: 0.9177
# (2000,)
# Accuracy after query 61: 0.9223
# (2000,)
# Accuracy after query 62: 0.9231
# (2000,)
# Accuracy after query 63: 0.9205
# (2000,)
# Accuracy after query 64: 0.9243
# (2000,)
# Accuracy after query 65: 0.9263
# (2000,)
# Accuracy after query 66: 0.9185
# (2000,)
# Accuracy after query 67: 0.9276
# (2000,)
# Accuracy after query 68: 0.9258
# (2000,)
# Accuracy after query 69: 0.9285
# (2000,)
# Accuracy after query 70: 0.9279
# (2000,)
# Accuracy after query 71: 0.9279
# (2000,)
# Accuracy after query 72: 0.9318
# (2000,)
# Accuracy after query 73: 0.9265
# (2000,)
# Accuracy after query 74: 0.9291
# (2000,)
# Accuracy after query 75: 0.9303
# (2000,)
# Accuracy after query 76: 0.9198
# (2000,)
# Accuracy after query 77: 0.9271
# (2000,)
# Accuracy after query 78: 0.9306
# (2000,)
# Accuracy after query 79: 0.9324
# (2000,)
# Accuracy after query 80: 0.9304
# (2000,)
# Accuracy after query 81: 0.9316
# (2000,)
# Accuracy after query 82: 0.9338
# (2000,)
# Accuracy after query 83: 0.9352
# (2000,)
# Accuracy after query 84: 0.9345
# (2000,)
# Accuracy after query 85: 0.9348
# (2000,)
# Accuracy after query 86: 0.9354
# (2000,)
# Accuracy after query 87: 0.9360
# (2000,)
# Accuracy after query 88: 0.9368
# (2000,)
# Accuracy after query 89: 0.9358
# (2000,)
# Accuracy after query 90: 0.9390
# (2000,)
# Accuracy after query 91: 0.9356
# (2000,)
# Accuracy after query 92: 0.9379
# (2000,)
# Accuracy after query 93: 0.9355
# (2000,)
# Accuracy after query 94: 0.9354
# (2000,)
# Accuracy after query 95: 0.9358
# (2000,)
# Accuracy after query 96: 0.9367
# (2000,)
# Accuracy after query 97: 0.9395
# (2000,)
# Accuracy after query 98: 0.9420
# Accuracy after query 1: 0.6228
# Accuracy after query 2: 0.6886
# Accuracy after query 3: 0.7316
# Accuracy after query 4: 0.7805
# Accuracy after query 5: 0.7902
# Accuracy after query 6: 0.7899
# Accuracy after query 7: 0.8180
# Accuracy after query 8: 0.8341
# Accuracy after query 9: 0.8481
# Accuracy after query 10: 0.8423
# Accuracy after query 11: 0.8467
# Accuracy after query 12: 0.8526
# Accuracy after query 13: 0.8518
# Accuracy after query 14: 0.8636
# Accuracy after query 15: 0.8831
# Accuracy after query 16: 0.8823
# Accuracy after query 17: 0.8793
# Accuracy after query 18: 0.8798
# Accuracy after query 19: 0.8848
# Accuracy after query 20: 0.8941
# Accuracy after query 21: 0.9087
# Accuracy after query 22: 0.9063
# Accuracy after query 23: 0.9087
# Accuracy after query 24: 0.9113
# Accuracy after query 25: 0.9096
# Accuracy after query 26: 0.9068
# Accuracy after query 27: 0.9163
# Accuracy after query 28: 0.9113
# Accuracy after query 29: 0.9109
# Accuracy after query 30: 0.9164
# Accuracy after query 31: 0.9115
# Accuracy after query 32: 0.9213
# Accuracy after query 33: 0.9220
# Accuracy after query 34: 0.9208
# Accuracy after query 35: 0.9265
# Accuracy after query 36: 0.9288
# Accuracy after query 37: 0.9330
# Accuracy after query 38: 0.9413
# Accuracy after query 39: 0.9406
# Accuracy after query 40: 0.9418
# Accuracy after query 41: 0.9374
# Accuracy after query 42: 0.9369
# Accuracy after query 43: 0.9415
# Accuracy after query 44: 0.9394
# Accuracy after query 45: 0.9440
# Accuracy after query 46: 0.9438
# Accuracy after query 47: 0.9526
# Accuracy after query 48: 0.9481
# Accuracy after query 49: 0.9493
# Accuracy after query 50: 0.9492
# Accuracy after query 51: 0.9499
# Accuracy after query 52: 0.9435
# Accuracy after query 53: 0.9489
# Accuracy after query 54: 0.9515
# Accuracy after query 55: 0.9499
# Accuracy after query 56: 0.9504
# Accuracy after query 57: 0.9545
# Accuracy after query 58: 0.9540
# Accuracy after query 59: 0.9553
# Accuracy after query 60: 0.9542
# Accuracy after query 61: 0.9551
# Accuracy after query 62: 0.9526
# Accuracy after query 63: 0.9559
# Accuracy after query 64: 0.9568
# Accuracy after query 65: 0.9537
# Accuracy after query 66: 0.9586
# Accuracy after query 67: 0.9604
# Accuracy after query 68: 0.9585
# Accuracy after query 69: 0.9573
# Accuracy after query 70: 0.9573
# Accuracy after query 71: 0.9609
# Accuracy after query 72: 0.9588
# Accuracy after query 73: 0.9566
# Accuracy after query 74: 0.9620
# Accuracy after query 75: 0.9594
# Accuracy after query 76: 0.9598
# Accuracy after query 77: 0.9607
# Accuracy after query 78: 0.9618
# Accuracy after query 79: 0.9653
# Accuracy after query 80: 0.9648
# Accuracy after query 81: 0.9599
# Accuracy after query 82: 0.9621
# Accuracy after query 83: 0.9631
# Accuracy after query 84: 0.9641
# Accuracy after query 85: 0.9683
# Accuracy after query 86: 0.9635
# Accuracy after query 87: 0.9642
# Accuracy after query 88: 0.9678
# Accuracy after query 89: 0.9638
# Accuracy after query 90: 0.9683
# Accuracy after query 91: 0.9643
# Accuracy after query 92: 0.9643
# Accuracy after query 93: 0.9677
# Accuracy after query 94: 0.9675
# Accuracy after query 95: 0.9680
# Accuracy after query 96: 0.9668
# Accuracy after query 97: 0.9657
# Accuracy after query 98: 0.9653
# Accuracy after query 1: 0.6021
# Accuracy after query 2: 0.6525
# Accuracy after query 3: 0.6791
# Accuracy after query 4: 0.6963
# Accuracy after query 5: 0.7366
# Accuracy after query 6: 0.7621
# Accuracy after query 7: 0.7826
# Accuracy after query 8: 0.8200
# Accuracy after query 9: 0.8284
# Accuracy after query 10: 0.8454
# Accuracy after query 11: 0.8536
# Accuracy after query 12: 0.8558
# Accuracy after query 13: 0.8638
# Accuracy after query 14: 0.8496
# Accuracy after query 15: 0.8777
# Accuracy after query 16: 0.8649
# Accuracy after query 17: 0.8859
# Accuracy after query 18: 0.8859
# Accuracy after query 19: 0.8926
# Accuracy after query 20: 0.8949
# Accuracy after query 21: 0.8858
# Accuracy after query 22: 0.9044
# Accuracy after query 23: 0.9134
# Accuracy after query 24: 0.9102
# Accuracy after query 25: 0.9060
# Accuracy after query 26: 0.8982
# Accuracy after query 27: 0.9141
# Accuracy after query 28: 0.9169
# Accuracy after query 29: 0.9252
# Accuracy after query 30: 0.9212
# Accuracy after query 31: 0.9228
# Accuracy after query 32: 0.9252
# Accuracy after query 33: 0.9311
# Accuracy after query 34: 0.9267
# Accuracy after query 35: 0.9158
# Accuracy after query 36: 0.9305
# Accuracy after query 37: 0.9321
# Accuracy after query 38: 0.9337
# Accuracy after query 39: 0.9379
# Accuracy after query 40: 0.9373
# Accuracy after query 41: 0.9402
# Accuracy after query 42: 0.9387
# Accuracy after query 43: 0.9356
# Accuracy after query 44: 0.9412
# Accuracy after query 45: 0.9423
# Accuracy after query 46: 0.9357
# Accuracy after query 47: 0.9335
# Accuracy after query 48: 0.9387
# Accuracy after query 49: 0.9385
# Accuracy after query 50: 0.9346
# Accuracy after query 51: 0.9373
# Accuracy after query 52: 0.9344
# Accuracy after query 53: 0.9417
# Accuracy after query 54: 0.9392
# Accuracy after query 55: 0.9450
# Accuracy after query 56: 0.9408
# Accuracy after query 57: 0.9475
# Accuracy after query 58: 0.9389
# Accuracy after query 59: 0.9416
# Accuracy after query 60: 0.9485
# Accuracy after query 61: 0.9479
# Accuracy after query 62: 0.9542
# Accuracy after query 63: 0.9493
# Accuracy after query 64: 0.9504
# Accuracy after query 65: 0.9458
# Accuracy after query 66: 0.9481
# Accuracy after query 67: 0.9474
# Accuracy after query 68: 0.9485
# Accuracy after query 69: 0.9481
# Accuracy after query 70: 0.9491
# Accuracy after query 71: 0.9542
# Accuracy after query 72: 0.9525
# Accuracy after query 73: 0.9464
# Accuracy after query 74: 0.9505
# Accuracy after query 75: 0.9556
# Accuracy after query 76: 0.9557
# Accuracy after query 77: 0.9554
# Accuracy after query 78: 0.9490
# Accuracy after query 79: 0.9531
# Accuracy after query 80: 0.9492
# Accuracy after query 81: 0.9520
# Accuracy after query 82: 0.9501
# Accuracy after query 83: 0.9518
# Accuracy after query 84: 0.9516
# Accuracy after query 85: 0.9493
# Accuracy after query 86: 0.9553
# Accuracy after query 87: 0.9545
# Accuracy after query 88: 0.9495
# Accuracy after query 89: 0.9521
# Accuracy after query 90: 0.9539
# Accuracy after query 91: 0.9545
# Accuracy after query 92: 0.9553
# Accuracy after query 93: 0.9586
# Accuracy after query 94: 0.9597
# Accuracy after query 95: 0.9591
# Accuracy after query 96: 0.9573
# Accuracy after query 97: 0.9582
# Accuracy after query 98: 0.9593
# Accuracy after query 1: 0.6152
# Accuracy after query 2: 0.6343
# Accuracy after query 3: 0.7025
# Accuracy after query 4: 0.7274
# Accuracy after query 5: 0.7643
# Accuracy after query 6: 0.7638
# Accuracy after query 7: 0.7927
# Accuracy after query 8: 0.8203
# Accuracy after query 9: 0.8246
# Accuracy after query 10: 0.8340
# Accuracy after query 11: 0.8326
# Accuracy after query 12: 0.8409
# Accuracy after query 13: 0.8564
# Accuracy after query 14: 0.8611
# Accuracy after query 15: 0.8572
# Accuracy after query 16: 0.8802
# Accuracy after query 17: 0.8805
# Accuracy after query 18: 0.8920
# Accuracy after query 19: 0.8860
# Accuracy after query 20: 0.8878
# Accuracy after query 21: 0.8855
# Accuracy after query 22: 0.8887
# Accuracy after query 23: 0.8749
# Accuracy after query 24: 0.9053
# Accuracy after query 25: 0.8971
# Accuracy after query 26: 0.9122
# Accuracy after query 27: 0.9088
# Accuracy after query 28: 0.9087
# Accuracy after query 29: 0.8944
# Accuracy after query 30: 0.9106
# Accuracy after query 31: 0.9125
# Accuracy after query 32: 0.9248
# Accuracy after query 33: 0.9237
# Accuracy after query 34: 0.9215
# Accuracy after query 35: 0.9296
# Accuracy after query 36: 0.9268
# Accuracy after query 37: 0.9318
# Accuracy after query 38: 0.9331
# Accuracy after query 39: 0.9278
# Accuracy after query 40: 0.9375
# Accuracy after query 41: 0.9394
# Accuracy after query 42: 0.9405
# Accuracy after query 43: 0.9398
# Accuracy after query 44: 0.9394
# Accuracy after query 45: 0.9435
# Accuracy after query 46: 0.9485
# Accuracy after query 47: 0.9408
# Accuracy after query 48: 0.9485
# Accuracy after query 49: 0.9522
# Accuracy after query 50: 0.9502
# Accuracy after query 51: 0.9473
# Accuracy after query 52: 0.9482
# Accuracy after query 53: 0.9505
# Accuracy after query 54: 0.9520
# Accuracy after query 55: 0.9508
# Accuracy after query 56: 0.9537
# Accuracy after query 57: 0.9580
# Accuracy after query 58: 0.9571
# Accuracy after query 59: 0.9533
# Accuracy after query 60: 0.9507
# Accuracy after query 61: 0.9533
# Accuracy after query 62: 0.9537
# Accuracy after query 63: 0.9511
# Accuracy after query 64: 0.9567
# Accuracy after query 65: 0.9572
# Accuracy after query 66: 0.9588
# Accuracy after query 67: 0.9574
# Accuracy after query 68: 0.9573
# Accuracy after query 69: 0.9587
# Accuracy after query 70: 0.9589
# Accuracy after query 71: 0.9573
# Accuracy after query 72: 0.9553
# Accuracy after query 73: 0.9568
# Accuracy after query 74: 0.9541
# Accuracy after query 75: 0.9599
# Accuracy after query 76: 0.9632
# Accuracy after query 77: 0.9614
# Accuracy after query 78: 0.9595
# Accuracy after query 79: 0.9594
# Accuracy after query 80: 0.9625
# Accuracy after query 81: 0.9632
# Accuracy after query 82: 0.9608
# Accuracy after query 83: 0.9616
# Accuracy after query 84: 0.9601
# Accuracy after query 85: 0.9598
# Accuracy after query 86: 0.9631
# Accuracy after query 87: 0.9611
# Accuracy after query 88: 0.9608
# Accuracy after query 89: 0.9661
# Accuracy after query 90: 0.9636
# Accuracy after query 91: 0.9633
# Accuracy after query 92: 0.9654
# Accuracy after query 93: 0.9659
# Accuracy after query 94: 0.9621
# Accuracy after query 95: 0.9647
# Accuracy after query 96: 0.9671
# Accuracy after query 97: 0.9646
# Accuracy after query 98: 0.9658
# Accuracy after query 1: 0.6608
# Accuracy after query 2: 0.6988
# Accuracy after query 3: 0.7166
# Accuracy after query 4: 0.7476
# Accuracy after query 5: 0.7565
# Accuracy after query 6: 0.7828
# Accuracy after query 7: 0.7892
# Accuracy after query 8: 0.7892
# Accuracy after query 9: 0.8026
# Accuracy after query 10: 0.8286
# Accuracy after query 11: 0.8247
# Accuracy after query 12: 0.8521
# Accuracy after query 13: 0.8533
# Accuracy after query 14: 0.8687
# Accuracy after query 15: 0.8759
# Accuracy after query 16: 0.8782
# Accuracy after query 17: 0.8856
# Accuracy after query 18: 0.8746
# Accuracy after query 19: 0.8885
# Accuracy after query 20: 0.8844
# Accuracy after query 21: 0.8955
# Accuracy after query 22: 0.8995
# Accuracy after query 23: 0.9099
# Accuracy after query 24: 0.9149
# Accuracy after query 25: 0.9161
# Accuracy after query 26: 0.9094
# Accuracy after query 27: 0.9173
# Accuracy after query 28: 0.9227
# Accuracy after query 29: 0.9207
# Accuracy after query 30: 0.9265
# Accuracy after query 31: 0.9277
# Accuracy after query 32: 0.9302
# Accuracy after query 33: 0.9322
# Accuracy after query 34: 0.9343
# Accuracy after query 35: 0.9369
# Accuracy after query 36: 0.9349
# Accuracy after query 37: 0.9423
# Accuracy after query 38: 0.9341
# Accuracy after query 39: 0.9425
# Accuracy after query 40: 0.9449
# Accuracy after query 41: 0.9408
# Accuracy after query 42: 0.9378
# Accuracy after query 43: 0.9404
# Accuracy after query 44: 0.9435
# Accuracy after query 45: 0.9476
# Accuracy after query 46: 0.9501
# Accuracy after query 47: 0.9523
# Accuracy after query 48: 0.9473
# Accuracy after query 49: 0.9511
# Accuracy after query 50: 0.9521
# Accuracy after query 51: 0.9497
# Accuracy after query 52: 0.9504
# Accuracy after query 53: 0.9463
# Accuracy after query 54: 0.9552
# Accuracy after query 55: 0.9514
# Accuracy after query 56: 0.9522
# Accuracy after query 57: 0.9520
# Accuracy after query 58: 0.9539
# Accuracy after query 59: 0.9522
# Accuracy after query 60: 0.9526
# Accuracy after query 61: 0.9565
# Accuracy after query 62: 0.9547
# Accuracy after query 63: 0.9594
# Accuracy after query 64: 0.9570
# Accuracy after query 65: 0.9567
# Accuracy after query 66: 0.9572
# Accuracy after query 67: 0.9583
# Accuracy after query 68: 0.9578
# Accuracy after query 69: 0.9548
# Accuracy after query 70: 0.9550
# Accuracy after query 71: 0.9589
# Accuracy after query 72: 0.9570
# Accuracy after query 73: 0.9566
# Accuracy after query 74: 0.9590
# Accuracy after query 75: 0.9573
# Accuracy after query 76: 0.9564
# Accuracy after query 77: 0.9599
# Accuracy after query 78: 0.9588
# Accuracy after query 79: 0.9596
# Accuracy after query 80: 0.9586
# Accuracy after query 81: 0.9584
# Accuracy after query 82: 0.9609
# Accuracy after query 83: 0.9635
# Accuracy after query 84: 0.9609
# Accuracy after query 85: 0.9644
# Accuracy after query 86: 0.9635
# Accuracy after query 87: 0.9635
# Accuracy after query 88: 0.9636
# Accuracy after query 89: 0.9629
# Accuracy after query 90: 0.9682
# Accuracy after query 91: 0.9672
# Accuracy after query 92: 0.9648
# Accuracy after query 93: 0.9651
# Accuracy after query 94: 0.9669
# Accuracy after query 95: 0.9649
# Accuracy after query 96: 0.9653
# Accuracy after query 97: 0.9661
# Accuracy after query 98: 0.9677
# Accuracy after query 1: 0.5768
# Accuracy after query 2: 0.6712
# Accuracy after query 3: 0.7106
# Accuracy after query 4: 0.7213
# Accuracy after query 5: 0.7428
# Accuracy after query 6: 0.7365
# Accuracy after query 7: 0.7625
# Accuracy after query 8: 0.7967
# Accuracy after query 9: 0.8102
# Accuracy after query 10: 0.8250
# Accuracy after query 11: 0.8170
# Accuracy after query 12: 0.8302
# Accuracy after query 13: 0.8462
# Accuracy after query 14: 0.8459
# Accuracy after query 15: 0.8531
# Accuracy after query 16: 0.8602
# Accuracy after query 17: 0.8418
# Accuracy after query 18: 0.8570
# Accuracy after query 19: 0.8619
# Accuracy after query 20: 0.8627
# Accuracy after query 21: 0.8504
# Accuracy after query 22: 0.8662
# Accuracy after query 23: 0.8683
# Accuracy after query 24: 0.8850
# Accuracy after query 25: 0.8799
# Accuracy after query 26: 0.8871
# Accuracy after query 27: 0.8854
# Accuracy after query 28: 0.8839
# Accuracy after query 29: 0.8823
# Accuracy after query 30: 0.8891
# Accuracy after query 31: 0.8861
# Accuracy after query 32: 0.8788
# Accuracy after query 33: 0.8900
# Accuracy after query 34: 0.8827
# Accuracy after query 35: 0.8927
# Accuracy after query 36: 0.8950
# Accuracy after query 37: 0.9004
# Accuracy after query 38: 0.9017
# Accuracy after query 39: 0.8999
# Accuracy after query 40: 0.8932
# Accuracy after query 41: 0.9046
# Accuracy after query 42: 0.8969
# Accuracy after query 43: 0.8998
# Accuracy after query 44: 0.9010
# Accuracy after query 45: 0.9001
# Accuracy after query 46: 0.9099
# Accuracy after query 47: 0.9183
# Accuracy after query 48: 0.9133
# Accuracy after query 49: 0.9116
# Accuracy after query 50: 0.9101
# Accuracy after query 51: 0.9127
# Accuracy after query 52: 0.9128
# Accuracy after query 53: 0.9168
# Accuracy after query 54: 0.9114
# Accuracy after query 55: 0.9206
# Accuracy after query 56: 0.9180
# Accuracy after query 57: 0.9165
# Accuracy after query 58: 0.9200
# Accuracy after query 59: 0.9224
# Accuracy after query 60: 0.9222
# Accuracy after query 61: 0.9250
# Accuracy after query 62: 0.9251
# Accuracy after query 63: 0.9291
# Accuracy after query 64: 0.9254
# Accuracy after query 65: 0.9255
# Accuracy after query 66: 0.9342
# Accuracy after query 67: 0.9328
# Accuracy after query 68: 0.9307
# Accuracy after query 69: 0.9287
# Accuracy after query 70: 0.9261
# Accuracy after query 71: 0.9334
# Accuracy after query 72: 0.9341
# Accuracy after query 73: 0.9282
# Accuracy after query 74: 0.9325
# Accuracy after query 75: 0.9315
# Accuracy after query 76: 0.9333
# Accuracy after query 77: 0.9363
# Accuracy after query 78: 0.9337
# Accuracy after query 79: 0.9348
# Accuracy after query 80: 0.9331
# Accuracy after query 81: 0.9296
# Accuracy after query 82: 0.9349
# Accuracy after query 83: 0.9367
# Accuracy after query 84: 0.9377
# Accuracy after query 85: 0.9388
# Accuracy after query 86: 0.9375
# Accuracy after query 87: 0.9401
# Accuracy after query 88: 0.9366
# Accuracy after query 89: 0.9412
# Accuracy after query 90: 0.9376
# Accuracy after query 91: 0.9373
# Accuracy after query 92: 0.9397
# Accuracy after query 93: 0.9427
# Accuracy after query 94: 0.9405
# Accuracy after query 95: 0.9422
# Accuracy after query 96: 0.9433
# Accuracy after query 97: 0.9418
# Accuracy after query 98: 0.9400
# (2000,)
# Accuracy after query 1: 0.5718
# (2000,)
# Accuracy after query 2: 0.6392
# (2000,)
# Accuracy after query 3: 0.6804
# (2000,)
# Accuracy after query 4: 0.6949
# (2000,)
# Accuracy after query 5: 0.7154
# (2000,)
# Accuracy after query 6: 0.7453
# (2000,)
# Accuracy after query 7: 0.7639
# (2000,)
# Accuracy after query 8: 0.7750
# (2000,)
# Accuracy after query 9: 0.7643
# (2000,)
# Accuracy after query 10: 0.7751
# (2000,)
# Accuracy after query 11: 0.7782
# (2000,)
# Accuracy after query 12: 0.7774
# (2000,)
# Accuracy after query 13: 0.8032
# (2000,)
# Accuracy after query 14: 0.7985
# (2000,)
# Accuracy after query 15: 0.8037
# (2000,)
# Accuracy after query 16: 0.8242
# (2000,)
# Accuracy after query 17: 0.8309
# (2000,)
# Accuracy after query 18: 0.8356
# (2000,)
# Accuracy after query 19: 0.8475
# (2000,)
# Accuracy after query 20: 0.8514
# (2000,)
# Accuracy after query 21: 0.8471
# (2000,)
# Accuracy after query 22: 0.8632
# (2000,)
# Accuracy after query 23: 0.8714
# (2000,)
# Accuracy after query 24: 0.8562
# (2000,)
# Accuracy after query 25: 0.8575
# (2000,)
# Accuracy after query 26: 0.8696
# (2000,)
# Accuracy after query 27: 0.8669
# (2000,)
# Accuracy after query 28: 0.8624
# (2000,)
# Accuracy after query 29: 0.8758
# (2000,)
# Accuracy after query 30: 0.8794
# (2000,)
# Accuracy after query 31: 0.8939
# (2000,)
# Accuracy after query 32: 0.9020
# (2000,)
# Accuracy after query 33: 0.8981
# (2000,)
# Accuracy after query 34: 0.8963
# (2000,)
# Accuracy after query 35: 0.9084
# (2000,)
# Accuracy after query 36: 0.9003
# (2000,)
# Accuracy after query 37: 0.9102
# (2000,)
# Accuracy after query 38: 0.9051
# (2000,)
# Accuracy after query 39: 0.9039
# (2000,)
# Accuracy after query 40: 0.9107
# (2000,)
# Accuracy after query 41: 0.9126
# (2000,)
# Accuracy after query 42: 0.9067
# (2000,)
# Accuracy after query 43: 0.9103
# (2000,)
# Accuracy after query 44: 0.9155
# (2000,)
# Accuracy after query 45: 0.9165
# (2000,)
# Accuracy after query 46: 0.9115
# (2000,)
# Accuracy after query 47: 0.9136
# (2000,)
# Accuracy after query 48: 0.9078
# (2000,)
# Accuracy after query 49: 0.9118
# (2000,)
# Accuracy after query 50: 0.9121
# (2000,)
# Accuracy after query 51: 0.9152
# (2000,)
# Accuracy after query 52: 0.9185
# (2000,)
# Accuracy after query 53: 0.9171
# (2000,)
# Accuracy after query 54: 0.9132
# (2000,)
# Accuracy after query 55: 0.9202
# (2000,)
# Accuracy after query 56: 0.9215
# (2000,)
# Accuracy after query 57: 0.9211
# (2000,)
# Accuracy after query 58: 0.9212
# (2000,)
# Accuracy after query 59: 0.9234
# (2000,)
# Accuracy after query 60: 0.9227
# (2000,)
# Accuracy after query 61: 0.9245
# (2000,)
# Accuracy after query 62: 0.9289
# (2000,)
# Accuracy after query 63: 0.9283
# (2000,)
# Accuracy after query 64: 0.9254
# (2000,)
# Accuracy after query 65: 0.9289
# (2000,)
# Accuracy after query 66: 0.9278
# (2000,)
# Accuracy after query 67: 0.9282
# (2000,)
# Accuracy after query 68: 0.9286
# (2000,)
# Accuracy after query 69: 0.9252
# (2000,)
# Accuracy after query 70: 0.9287
# (2000,)
# Accuracy after query 71: 0.9296
# (2000,)
# Accuracy after query 72: 0.9264
# (2000,)
# Accuracy after query 73: 0.9286
# (2000,)
# Accuracy after query 74: 0.9300
# (2000,)
# Accuracy after query 75: 0.9303
# (2000,)
# Accuracy after query 76: 0.9292
# (2000,)
# Accuracy after query 77: 0.9349
# (2000,)
# Accuracy after query 78: 0.9386
# (2000,)
# Accuracy after query 79: 0.9340
# (2000,)
# Accuracy after query 80: 0.9348
# (2000,)
# Accuracy after query 81: 0.9332
# (2000,)
# Accuracy after query 82: 0.9353
# (2000,)
# Accuracy after query 83: 0.9350
# (2000,)
# Accuracy after query 84: 0.9336
# (2000,)
# Accuracy after query 85: 0.9342
# (2000,)
# Accuracy after query 86: 0.9385
# (2000,)
# Accuracy after query 87: 0.9396
# (2000,)
# Accuracy after query 88: 0.9379
# (2000,)
# Accuracy after query 89: 0.9395
# (2000,)
# Accuracy after query 90: 0.9408
# (2000,)
# Accuracy after query 91: 0.9412
# (2000,)
# Accuracy after query 92: 0.9378
# (2000,)
# Accuracy after query 93: 0.9382
# (2000,)
# Accuracy after query 94: 0.9419
# (2000,)
# Accuracy after query 95: 0.9426
# (2000,)
# Accuracy after query 96: 0.9412
# (2000,)
# Accuracy after query 97: 0.9442
# (2000,)
# Accuracy after query 98: 0.9433
